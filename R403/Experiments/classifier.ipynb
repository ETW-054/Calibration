# %% [markdown]
# # Used Packages

# %%
import os
import glob
import gc

import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
from tqdm import tqdm
import math

from scipy.spatial.transform import Rotation as R

from utils.MovingAverager import *
from collections import defaultdict
from torchinfo import summary

from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Global Variable

# %%
rotation = False
num_of_axis = 3

datapoint_per_second = 20
duration = 2
seq_len = 10

# %%
validation_traj = np.load(f'./npys/all_user_match_data.npy', allow_pickle=True)

# %%
parent_path = '/root/Calibration/R403/model'
tim = datetime.now().strftime("%b%d%Y")
path = os.path.join(parent_path, tim+'_Calibrate')
try:
    os.makedirs(path, exist_ok=True)
    print("Directory '%s' created successfully" % path)
except OSError as error:
    print("Directory '%s' can not be created")
# Out:
# Directory '/root/Calibration/R403/model/Jun052024_Calibrate' created successfully

# %%
class KalmanFilter:
    def __init__(self, dt, gyro_noise_std, acc_noise_std):
        self.dt = dt
        self.gyro_noise_std = gyro_noise_std
        self.acc_noise_std = acc_noise_std
        
        self.Q = np.eye(3) * gyro_noise_std**2
        self.R = np.eye(3) * acc_noise_std**2
        
        self.P = np.eye(3)
        self.x = np.zeros(3)
    
    def predict(self, gyro_measurements):
        F = np.eye(3) + self.dt * self.skew_symmetric(gyro_measurements)
        self.x = F @ self.x
        self.P = F @ self.P @ F.T + self.Q
    
    def update(self, acc_measurements, Rk):
        z = acc_measurements
        H = np.eye(3)
        y = z - H @ self.x
        S = H @ self.P @ H.T + Rk
        K = self.P @ H.T @ np.linalg.inv(S)
        self.x = self.x + K @ y
        self.P = (np.eye(3) - K @ H) @ self.P
    
    def skew_symmetric(self, v):
        return np.array([[0, -v[2], v[1]], [v[2], 0, -v[0]], [-v[1], v[0], 0]])

class AttitudeEstimator:
    def __init__(self, dt, gyro_noise_std, acc_noise_std, method='STF'):
        self.kf = KalmanFilter(dt, gyro_noise_std, acc_noise_std)
        self.method = method
    
    def estimate_attitude(self, gyro_measurements, acc_measurements):
        self.kf.predict(gyro_measurements)
        Rk = self.adaptive_measurement_noise_covariance(acc_measurements)
        self.kf.update(acc_measurements, Rk)
        return self.kf.x
    
    def adaptive_measurement_noise_covariance(self, acc_measurements):
        if self.method == 'STF':
            return self.adaptive_measurement_noise_covariance_stf(acc_measurements)
        elif self.method == 'MTF':
            return self.adaptive_measurement_noise_covariance_mtf(acc_measurements)
        else:
            raise ValueError("Method must be 'STF' or 'MTF'")
    
    def adaptive_measurement_noise_covariance_stf(self, acc_measurements):
        innovation = acc_measurements - self.kf.x
        St = np.sum(innovation**2) / 3 - np.trace(self.kf.R) / 3
        St = max(0, St)
        return np.eye(3) * St
    
    def adaptive_measurement_noise_covariance_mtf(self, acc_measurements):
        innovation = acc_measurements - self.kf.x
        St = np.zeros(3)
        for i in range(3):
            St[i] = max(0, innovation[i]**2 - self.kf.R[i, i])
        return np.diag(St)
    
    def get_roll_pitch(self):
        roll = np.arctan2(self.kf.x[1], self.kf.x[2])
        pitch = np.arctan2(-self.kf.x[0], np.sqrt(self.kf.x[1]**2 + self.kf.x[2]**2))
        return roll, pitch

class RotationMatrixCalculator:
    @staticmethod
    def from_roll_pitch(roll, pitch):
        R_x = np.array([
            [1, 0, 0],
            [0, np.cos(roll), -np.sin(roll)],
            [0, np.sin(roll), np.cos(roll)]
        ])
        
        R_y = np.array([
            [np.cos(pitch), 0, np.sin(pitch)],
            [0, 1, 0],
            [-np.sin(pitch), 0, np.cos(pitch)]
        ])
        
        R = R_x @ R_y
        return R

estimator = AttitudeEstimator(0.05, 0.01, 0.1, 'MTF')    

def process_sequence(gyro_data, acc_data, acc_lin_data, mag_data):
    rotation_matrices = []
    rotated_acc_data = []
    rotated_acc_lin_data = []
    rotated_mag_data = []
    rotated_gyro_data = []
    
    for gyro_measurements, acc_measurements, acc_lin_measurements, mag_measurements in zip(gyro_data, acc_data, acc_lin_data, mag_data):
        estimator.estimate_attitude(np.array(gyro_measurements), np.array(acc_measurements))
        roll, pitch = estimator.get_roll_pitch()
        R = RotationMatrixCalculator.from_roll_pitch(roll, pitch)
        
        rotated_acc = R @ np.array(acc_measurements)
        rotated_gyro = R @ np.array(gyro_measurements)
        rotated_acc_lin = R @ np.array(acc_lin_measurements)
        rotated_mag = R @ np.array(mag_measurements)
        
        rotation_matrices.append(R)
        rotated_acc_data.append(rotated_acc)
        rotated_acc_lin_data.append(rotated_acc_lin)
        rotated_gyro_data.append(rotated_gyro)
        rotated_mag_data.append(rotated_mag)
    
    return np.concatenate((np.array(rotated_acc_data), np.array(rotated_acc_lin_data), np.array(rotated_gyro_data)), axis=-1), np.array(rotated_mag_data),

# %%
def get_data(validation_traj, num_of_axis, rotation):    
    posture_data = defaultdict(list)

    valid_data = validation_traj.item()
    for user_name in valid_data.keys():
        for path_name in valid_data[user_name].keys():
            for posture_name in valid_data[user_name][path_name].keys():
                data = valid_data[user_name][path_name][posture_name]

                if posture_name == 'ref_mag':
                    if num_of_axis == 2:
                        posture_data[posture_name].append(data[:, [0, 1, 6, 7, 5]])
                    else:
                        posture_data[posture_name].append(data[:, [0, 1, 2, 3, 4, 6, 7, 5]])
                    continue

                pos = (data[:, [0, 1]] + np.array((1, 1))) * 0.6
                imu = data[:, [3, 4, 5, 6, 7, 8, 9, 10, 11]]
                imu[:, 0:6] *= 10
                imu[:, 6:9] = imu[:, 6:9] * 180 / np.pi
                mag = data[:, [12, 13, 14]]

                if rotation:
                    imu, mag = process_sequence(imu[:, 6:9], imu[:, 0:3], imu[:, 3:6], mag)
                if num_of_axis == 2: 
                    mag = np.column_stack((np.sqrt(np.sum(mag[:, :2]**2, axis=1)), mag[:, 2]))
                imu = imu[:, [0, 3, 6, 1, 4, 7, 2, 5, 8]]
                pos_mag = np.concatenate((pos, imu, mag, data[:, [15]]), axis=-1)            
                posture_data[posture_name].append(pos_mag)
    
    return posture_data

# %%
def split_traj(trajs, length=20):
    sp_traj = []
    for traj in trajs:
        for i in range(len(traj) - length + 1):
            sp_traj.append(traj[i:i+length])
    return np.array(sp_traj)

# %%
datapoint_per_second = 20
duration = 2
seq_len = 20

# %% [markdown]
# # Data Loader

# %%
class PairDataset(Dataset):
    def __init__(self, source_data, source_label, target_data, target_label):
        assert (source_data.shape[0] == source_label.shape[0] == target_data.shape[0] == target_label.shape[0]), f'{source_data.shape}, {source_label.shape}, {target_data.shape}, {target_label.shape}'
        self.source_data = source_data
        self.source_label = source_label
        self.target_data = target_data
        self.target_label = target_label

    def __len__(self):
        return len(self.source_data)

    def __getitem__(self, idx):
        return self.source_data[idx], self.source_label[idx], self.target_data[idx], self.target_label[idx]

# %%
def for_dataloaders(traj, gt='target'):
    t_data = 0
    t_label = 0
    t_target_data = 0
    v_data = 0
    v_label = 0
    v_target_data = 0
    label = 1
    label_dict = {}
    flag = False
    for key, value in traj.items():
        split = len(value) * 9 // 10
        tmp1, tmp2 = value[:split], value[split:]
        if key != gt: 
            t_data = np.concatenate((t_data, tmp1)) if flag else tmp1
            t_label = np.concatenate((t_label, np.full((tmp1.shape[0], ), label))) if flag else np.full((tmp1.shape[0], ), label)
            v_data = np.concatenate((v_data, tmp2)) if flag else tmp2
            v_label = np.concatenate((v_label, np.full((tmp2.shape[0], ), label))) if flag else np.full((tmp2.shape[0], ), label)
            flag = True
            label_dict[label] = key
            label += 1
        else:
            l = len(traj.values()) - 1
            t_target_data = np.tile(tmp1, (l, 1, 1))
            v_target_data = np.tile(tmp2, (l, 1, 1))
            label_dict[0] = key
    
    train_dataset = PairDataset(
                        source_data = torch.tensor(t_data, dtype=torch.float),
                        source_label = t_label,
                        target_data = torch.tensor(t_target_data, dtype=torch.float),
                        target_label = np.zeros((len(t_target_data), ))
                    )
    
    valid_dataset = PairDataset(
                        source_data = torch.tensor(v_data, dtype=torch.float),
                        source_label = v_label,
                        target_data = torch.tensor(v_target_data, dtype=torch.float),
                        target_label = np.zeros((len(v_target_data), ))
                    )

    print(label_dict)
    return label_dict, train_dataset, valid_dataset

# %% [markdown]
# # Model Declaration

# %%
class FirstDerivativeLoss(nn.Module):
    def __init__(self, weight=None, size_average=None, reduce=None, reduction='mean'):
        super(FirstDerivativeLoss, self).__init__()

    def forward(self, source, target):
        # calculate the first derivative
        source_o = torch.reshape(source, (len(source), -1))
        target_o = torch.reshape(target, (len(target), -1))
        d_source = source_o[1:] - source_o[:-1]
        d_target = target_o[1:] - target_o[:-1]

        # calculate the loss as the mean squared error of the derivative
        loss = mae_loss(d_source, d_target)

        return loss

# %%
def generator_loss(z_imu, target_imu, predict_mag, target_mag, source_total_mag, target_total_mag, epoch_ratio=None):
    imu_loss = mae_loss(z_imu, target_imu)
    mag_loss = torch.sqrt(mse_loss(predict_mag, target_mag))
    d1_loss = div_loss(predict_mag, target_mag)
    
    pred_total_mag = torch.sqrt(torch.sum(torch.pow(predict_mag, 2), dim=-1))
    
    smag_limitation_loss = mae_loss(pred_total_mag, source_total_mag)
    tmag_limitation_loss = mae_loss(pred_total_mag, target_total_mag)
    
    if epoch_ratio == None:
        total_loss = imu_loss + mag_loss + d1_loss + smag_limitation_loss * 0.25 + tmag_limitation_loss * 0.75
    else:
        total_loss = (imu_loss + mag_loss * (2 - epoch_ratio) + d1_loss * (1 + epoch_ratio)) / 4 + smag_limitation_loss * 0.25 + tmag_limitation_loss * 0.75
    return total_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss)

# %%
num_of_classes = 4
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
ce_loss = torch.nn.CrossEntropyLoss()
mse_loss = torch.nn.MSELoss()
mae_loss = torch.nn.L1Loss()
bce_loss = torch.nn.BCELoss()
div_loss = FirstDerivativeLoss()

# %%
def get_tgt_mask(size) -> torch.tensor:
    # Generates a squeare matrix where the each row allows one word more to be seen
    mask = torch.tril(torch.ones(size, size) == 1) # Lower triangular matrix
    mask = mask.float()
    mask = mask.masked_fill(mask == 0, float('-inf')) # Convert zeros to -inf
    mask = mask.masked_fill(mask == 1, float(0.0)) # Convert ones to 0

    return mask.to(device)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :].to(x.device)
        return self.dropout(x)
    

class NotSimpleTransformer(nn.Module):
    def __init__(self, seq_len=21, num_of_classes=2):
        super(NotSimpleTransformer, self).__init__()
        
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        self.mag_axis = num_of_axis
        
        self.imu_layer = nn.Sequential(
            nn.Linear(9, 16),
            nn.LeakyReLU(),
        )
        self.mag_layer = nn.Sequential(
            nn.Linear(self.mag_axis, 16),
            nn.LeakyReLU(),
        )
        self.pos_encoder = PositionalEncoding(16, 0.1)
        
        self.encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=16, nhead=4, dropout=0.1, batch_first=True), num_layers=1)
        self.mag_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=16, nhead=4, dropout=0.1, batch_first=True), num_layers=1)
        self.nn = nn.Linear(16, 9)
        
        self.decoder  = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=16, nhead=4, dropout=0.1, batch_first=True), num_layers=1)
#         self.decoder1 = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=2)
        
        self.mag_last = nn.Sequential(
            nn.Linear(16, self.mag_axis),
        )
        
    def forward(self, source_imu, target_imu, source_mag):
        
        ### step 1
        h_imu = self.imu_layer(source_imu)
        h_imu = self.pos_encoder(h_imu)
        
        h_t_imu = self.imu_layer(target_imu)
        h_t_imu = self.pos_encoder(h_t_imu)
        
        h_mag = self.mag_layer(source_mag)
        h_mag = self.pos_encoder(h_mag)
        h_mag = self.mag_encoder(h_mag)
        
        ### step 2
        z = self.encoder(h_imu)
        z_imu = self.nn(z)
        
        ### step 3
        
        pred_latent = self.decoder(z, h_mag, tgt_mask=get_tgt_mask(20))
        pred_mag = self.mag_last(pred_latent)
        
        return z_imu, pred_mag

# %%
def plot_result(result):
    pred_mag = result[0].reshape(-1, num_of_axis)
    targ_mag = result[1].reshape(-1, num_of_axis)
    x = np.arange(len(pred_mag))
    
    loss = torch.sqrt(mse_loss(torch.tensor(pred_mag), torch.tensor(targ_mag))).item()
    
    fig = plt.figure(figsize=(15, 5))
    
    for pm, tm, caxis, color in zip(pred_mag.T, targ_mag.T, ['x', 'y', 'z'][:num_of_axis], ['tab:blue', 'tab:orange', 'tab:green'][:num_of_axis]):
        plt.plot(x, pm, label=f'pred_{caxis}', color=color, linewidth=2.5, zorder=2)
        plt.plot(x, tm, '--', label=f'targ_{caxis}', color=color, linewidth=1, alpha=0.8, zorder=1)
    
    pred_total_mag = np.sqrt(np.sum(np.power(pred_mag, 2), axis=-1))
    targ_total_mag = np.sqrt(np.sum(np.power(targ_mag, 2), axis=-1))
    plt.plot(x, pred_total_mag, label=f'pred_t', color='tab:red', linewidth=2.5, zorder=2)
    plt.plot(x, targ_total_mag, '--', label=f'targ_t', color='tab:red', linewidth=1, alpha=0.8, zorder=1)
    
    plt.suptitle(f'Loss: {loss:.2f}')
    plt.legend()
    plt.show()

# %%
def train(dataloader, draw=False, epoch_ratio=1):
    model.train()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []
    lim_loss = []

    for source_data, source_label, target_data, target_label in dataloader:
        optimizer.zero_grad()

        source_data = source_data.to(device)
        source_imu = source_data[:, :, 2:11] + torch.randn_like(source_data[:, :, 2:11]) * 0.25
        source_mag = source_data[:, :, 11:(11 + num_of_axis)] + torch.randn_like(source_data[:, :, 11:(11 + num_of_axis)]) * 0.5
        source_total_mag = source_data[:, :, -1]
        
        target_data = target_data.to(device)
        target_imu = target_data[:, :, 2:11]
        target_mag = target_data[:, :, 11:(11 + num_of_axis)]
        target_total_mag = target_data[:, :, -1]

        # generate mag
        z_imu, predict_mag = model(source_imu, target_imu, source_mag)
        
        # generator loss
        gen_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss) = generator_loss(z_imu, target_imu, predict_mag, target_mag,
                                                                                              source_total_mag, target_total_mag, epoch_ratio)
        
        # backward
        gen_loss.backward()
        optimizer.step()
        
        # record loss
        g_losses.append(gen_loss.item())
        imu_losses.append(imu_loss.item())
        mag_losses.append(mag_loss.item())
        d1_losses.append(d1_loss.item())
        lim_loss.append([smag_limitation_loss.item(), tmag_limitation_loss.item()])
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses), np.mean(lim_loss, axis=0)

# %%
def evalute(dataloader, draw=False):
    model.eval()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []
    lim_loss = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_imu = source_data[:, :, 2:11]
            source_mag = source_data[:, :, 11:(11 + num_of_axis)]
            source_total_mag = source_data[:, :, -1]

            target_data = target_data.to(device)
            target_imu = target_data[:, :, 2:11]
            target_mag = target_data[:, :, 11:(11 + num_of_axis)]
            target_total_mag = target_data[:, :, -1]

            # generate mag
            z_imu, predict_mag = model(source_imu, target_imu, source_mag)

            # generator loss
            gen_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss) = generator_loss(z_imu, target_imu, predict_mag, target_mag,
                                                                                                  source_total_mag, target_total_mag)

            # record loss
            g_losses.append(gen_loss.item())
            imu_losses.append(imu_loss.item())
            mag_losses.append(mag_loss.item())
            d1_losses.append(d1_loss.item())
            lim_loss.append([smag_limitation_loss.item(), tmag_limitation_loss.item()])
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses), np.mean(lim_loss, axis=0)

# %%
def output_eval(model, dataloader):
    model.eval()
    
    results = []
    class_results = []
    class_labels = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_pos = source_data[:, :, :2]
            source_imu = source_data[:, :, 5:11]
            source_mag = source_data[:, :, 11:(11 + num_of_axis)]

            target_data = target_data.to(device)
            target_pos = target_data[:, :, :2]
            target_imu = target_data[:, :, 5:11]
            target_mag = target_data[:, :, 11:(11 + num_of_axis)]
            # generate mag
            z_imu, predict_mag = model(source_imu, target_imu, source_mag)
            # generator loss
#             gen_loss, imu_loss, mag_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)

            # record loss
            predict_mag = predict_mag.detach().cpu().numpy()
            target_pos = target_pos.detach().cpu().numpy()
            target_mag = target_mag.cpu().numpy()
            source_label = source_label.detach().cpu().numpy()
            
            results.extend(zip(predict_mag, target_mag, source_label, target_pos))
            
            diff = np.power(predict_mag.reshape(len(predict_mag), -1, num_of_axis) - target_mag.reshape(len(target_mag), -1, num_of_axis), 2).mean(axis=1)
            diff = np.sqrt(diff)
            class_results.extend(diff)
            class_labels.extend(source_label)
    
    return np.array(results, dtype=object), np.array(class_results), np.array(class_labels)

# %%
def show_result(model, dataloader):
    results, cres, clabel = output_eval(model, dataloader)
    print(results.shape, cres.shape, clabel.shape)

    if num_of_axis == 3:
        print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"diff z":>8} {"avg":>8}')
        for class_label, class_name in classes.items():
            if sum(clabel == class_label) <= 0:
                continue
            dx, dy, dz = cres[clabel == class_label].mean(axis=0)
            print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
        dx, dy, dz = cres.mean(axis=0)
        print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
    
    elif num_of_axis == 2:
        print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"avg":>8}')
        for class_label, class_name in classes.items():
            if sum(clabel == class_label) <= 0:
                continue
            dx, dy = cres[clabel == class_label].mean(axis=0)
            print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {np.mean([dx, dy]):>8.2f}')
        dx, dy = cres.mean(axis=0)
        print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {np.mean([dx, dy]):>8.2f}')

    for rs in results[::500]:
        plot_result(rs)

# %% [markdown]
# # Experiment 1
# rotation = False
# num_of_axis = 2Different final ground truth (最終姿態)

# %%
num_of_axis, rotation, gt = 3, False, 'target'

posture_data = get_data(validation_traj, num_of_axis, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
# prep_valid_traj['horizontal']   = split_traj(posture_data['horizontal'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
# Out:
# {1: 'front_pocket', 2: 'pocket', 3: 'swing', 0: 'target'}

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH+1):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    draw = ((epoch) % 20000 == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw, epoch / EPOCH)
    
    if epoch % 100 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>7.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>7.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')
# Out:
# 00000: train loss:  61.591, imu loss: 20.969, mag loss: 23.957, div loss: 21.998, slim: 39.059, tlim: 38.809
#        valid loss:  98.014, imu loss: 21.833, mag loss: 26.266, div loss:  6.951, slim: 43.427, tlim: 42.810
# 00100: train loss:  42.001, imu loss: 18.602, mag loss: 21.575, div loss: 21.880, slim: 21.283, tlim: 21.030
#        valid loss:  75.586, imu loss: 19.459, mag loss: 23.601, div loss:  6.937, slim: 26.051, tlim: 25.435
# 00200: train loss:  25.844, imu loss: 15.067, mag loss: 24.662, div loss: 21.610, slim:  4.769, tlim:  4.212
#        valid loss:  55.485, imu loss: 15.819, mag loss: 25.679, div loss:  6.929, slim:  8.019, tlim:  6.739
# 00300: train loss:  24.055, imu loss: 11.344, mag loss: 23.873, div loss: 21.471, slim:  4.371, tlim:  3.775
#        valid loss:  50.987, imu loss: 11.742, mag loss: 24.554, div loss:  6.937, slim:  8.687, tlim:  7.442
# 00400: train loss:  22.361, imu loss:  8.718, mag loss: 22.461, div loss: 20.629, slim:  4.249, tlim:  3.654
#        valid loss:  46.871, imu loss:  8.928, mag loss: 23.255, div loss:  6.935, slim:  8.624, tlim:  7.463
# 00500: train loss:  20.846, imu loss:  8.300, mag loss: 20.525, div loss: 19.085, slim:  4.212, tlim:  3.590
#        valid loss:  46.207, imu loss:  8.711, mag loss: 22.401, div loss:  7.262, slim:  8.761, tlim:  7.522
# 00600: train loss:  19.280, imu loss:  8.310, mag loss: 18.269, div loss: 17.385, slim:  4.237, tlim:  3.558
#        valid loss:  46.368, imu loss:  8.759, mag loss: 22.063, div loss:  8.146, slim:  8.371, tlim:  7.077
# 00700: train loss:  17.940, imu loss:  8.337, mag loss: 16.490, div loss: 15.900, slim:  4.134, tlim:  3.477
#        valid loss:  47.006, imu loss:  8.809, mag loss: 22.127, div loss:  8.880, slim:  8.183, tlim:  6.859
# 00800: train loss:  17.253, imu loss:  8.319, mag loss: 15.628, div loss: 15.108, slim:  4.121, tlim:  3.409
#        valid loss:  47.300, imu loss:  8.822, mag loss: 22.192, div loss:  9.244, slim:  8.065, tlim:  6.700
# 00900: train loss:  16.741, imu loss:  8.312, mag loss: 15.021, div loss: 14.605, slim:  4.064, tlim:  3.320
#        valid loss:  47.700, imu loss:  8.864, mag loss: 22.027, div loss:  9.486, slim:  8.329, tlim:  6.987
# 01000: train loss:  16.175, imu loss:  8.297, mag loss: 14.350, div loss: 13.899, slim:  4.030, tlim:  3.266
#        valid loss:  48.849, imu loss:  8.898, mag loss: 22.248, div loss: 10.036, slim:  8.628, tlim:  7.345
# 01100: train loss:  15.970, imu loss:  8.299, mag loss: 14.039, div loss: 13.695, slim:  4.044, tlim:  3.260
#        valid loss:  49.027, imu loss:  8.919, mag loss: 22.415, div loss: 10.330, slim:  8.397, tlim:  7.018
# 01200: train loss:  15.510, imu loss:  8.276, mag loss: 13.530, div loss: 13.133, slim:  4.017, tlim:  3.192
#        valid loss:  49.397, imu loss:  8.938, mag loss: 22.350, div loss: 10.789, slim:  8.299, tlim:  6.992
# 01300: train loss:  15.270, imu loss:  8.287, mag loss: 13.224, div loss: 12.825, slim:  3.999, tlim:  3.182
#        valid loss:  49.511, imu loss:  8.977, mag loss: 22.423, div loss: 10.974, slim:  8.144, tlim:  6.800
# 01400: train loss:  14.962, imu loss:  8.279, mag loss: 12.823, div loss: 12.502, slim:  3.997, tlim:  3.148
#        valid loss:  49.981, imu loss:  8.982, mag loss: 22.313, div loss: 11.227, slim:  8.375, tlim:  7.153
# 01500: train loss:  14.766, imu loss:  8.268, mag loss: 12.585, div loss: 12.263, slim:  3.978, tlim:  3.136
#        valid loss:  50.020, imu loss:  8.987, mag loss: 22.222, div loss: 11.293, slim:  8.448, tlim:  7.207
# 01600: train loss:  14.494, imu loss:  8.284, mag loss: 12.299, div loss: 11.888, slim:  3.982, tlim:  3.085
#        valid loss:  49.887, imu loss:  8.991, mag loss: 22.315, div loss: 11.486, slim:  8.093, tlim:  6.762
# 01700: train loss:  14.268, imu loss:  8.278, mag loss: 11.971, div loss: 11.660, slim:  3.964, tlim:  3.085
#        valid loss:  50.189, imu loss:  8.996, mag loss: 22.150, div loss: 11.705, slim:  8.249, tlim:  7.034
# 01800: train loss:  13.968, imu loss:  8.263, mag loss: 11.613, div loss: 11.357, slim:  3.931, tlim:  3.039
#        valid loss:  50.290, imu loss:  9.014, mag loss: 22.237, div loss: 11.906, slim:  8.108, tlim:  6.809
# 01900: train loss:  13.838, imu loss:  8.257, mag loss: 11.459, div loss: 11.176, slim:  3.929, tlim:  3.032
#        valid loss:  51.054, imu loss:  8.992, mag loss: 22.577, div loss: 12.287, slim:  8.236, tlim:  6.852
# 02000: train loss:  13.676, imu loss:  8.256, mag loss: 11.279, div loss: 10.919, slim:  3.919, tlim:  3.029
#        valid loss:  50.799, imu loss:  9.010, mag loss: 22.299, div loss: 12.289, slim:  8.146, tlim:  6.885
# 02100: train loss:  13.414, imu loss:  8.255, mag loss: 10.945, div loss: 10.671, slim:  3.911, tlim:  2.986
#        valid loss:  51.340, imu loss:  9.006, mag loss: 22.597, div loss: 12.528, slim:  8.233, tlim:  6.867
# 02200: train loss:  13.405, imu loss:  8.254, mag loss: 10.937, div loss: 10.671, slim:  3.908, tlim:  2.981
#        valid loss:  51.017, imu loss:  8.997, mag loss: 22.341, div loss: 12.456, slim:  8.167, tlim:  6.908
# 02300: train loss:  13.177, imu loss:  8.255, mag loss: 10.683, div loss: 10.375, slim:  3.896, tlim:  2.950
#        valid loss:  51.255, imu loss:  9.009, mag loss: 22.414, div loss: 12.679, slim:  8.107, tlim:  6.834
# 02400: train loss:  13.070, imu loss:  8.259, mag loss: 10.534, div loss: 10.286, slim:  3.881, tlim:  2.939
#        valid loss:  51.385, imu loss:  8.989, mag loss: 22.558, div loss: 12.822, slim:  8.012, tlim:  6.684
# 02500: train loss:  13.015, imu loss:  8.255, mag loss: 10.496, div loss: 10.190, slim:  3.855, tlim:  2.935
#        valid loss:  51.570, imu loss:  9.000, mag loss: 22.603, div loss: 12.920, slim:  8.040, tlim:  6.716
# 02600: train loss:  12.865, imu loss:  8.241, mag loss: 10.276, div loss: 10.027, slim:  3.889, tlim:  2.927
#        valid loss:  51.402, imu loss:  8.997, mag loss: 22.680, div loss: 12.886, slim:  7.936, tlim:  6.474
# 02700: train loss:  12.703, imu loss:  8.242, mag loss: 10.097, div loss:  9.836, slim:  3.896, tlim:  2.893
#        valid loss:  51.839, imu loss:  8.999, mag loss: 22.821, div loss: 13.065, slim:  8.009, tlim:  6.602
# 02800: train loss:  12.582, imu loss:  8.237, mag loss:  9.951, div loss:  9.744, slim:  3.858, tlim:  2.872
#        valid loss:  51.476, imu loss:  8.998, mag loss: 22.631, div loss: 13.131, slim:  7.807, tlim:  6.352
# 02900: train loss:  12.567, imu loss:  8.228, mag loss:  9.964, div loss:  9.705, slim:  3.865, tlim:  2.860
#        valid loss:  51.627, imu loss:  8.970, mag loss: 22.732, div loss: 12.961, slim:  8.020, tlim:  6.612
# 03000: train loss:  12.410, imu loss:  8.238, mag loss:  9.754, div loss:  9.531, slim:  3.862, tlim:  2.845
#        valid loss:  51.699, imu loss:  8.996, mag loss: 22.786, div loss: 13.089, slim:  7.909, tlim:  6.469
# 03100: train loss:  12.375, imu loss:  8.241, mag loss:  9.726, div loss:  9.528, slim:  3.833, tlim:  2.825
#        valid loss:  51.987, imu loss:  8.978, mag loss: 22.783, div loss: 13.201, slim:  8.077, tlim:  6.674
# 03200: train loss:  12.261, imu loss:  8.229, mag loss:  9.602, div loss:  9.339, slim:  3.856, tlim:  2.818
#        valid loss:  52.406, imu loss:  8.999, mag loss: 23.012, div loss: 13.319, slim:  8.167, tlim:  6.712
# 03300: train loss:  12.187, imu loss:  8.220, mag loss:  9.521, div loss:  9.279, slim:  3.844, tlim:  2.801
#        valid loss:  52.017, imu loss:  8.993, mag loss: 22.882, div loss: 13.254, slim:  7.971, tlim:  6.527
# 03400: train loss:  12.059, imu loss:  8.224, mag loss:  9.394, div loss:  9.095, slim:  3.836, tlim:  2.781
#        valid loss:  52.441, imu loss:  8.990, mag loss: 23.005, div loss: 13.480, slim:  8.035, tlim:  6.609
# 03500: train loss:  12.044, imu loss:  8.232, mag loss:  9.361, div loss:  9.111, slim:  3.826, tlim:  2.776
#        valid loss:  52.480, imu loss:  9.005, mag loss: 23.025, div loss: 13.446, slim:  8.051, tlim:  6.654
# 03600: train loss:  11.968, imu loss:  8.217, mag loss:  9.286, div loss:  9.014, slim:  3.827, tlim:  2.764
#        valid loss:  51.955, imu loss:  8.991, mag loss: 22.775, div loss: 13.371, slim:  7.887, tlim:  6.462
# 03700: train loss:  11.869, imu loss:  8.223, mag loss:  9.125, div loss:  8.918, slim:  3.831, tlim:  2.764
#        valid loss:  52.117, imu loss:  8.992, mag loss: 22.843, div loss: 13.395, slim:  7.961, tlim:  6.530
# 03800: train loss:  11.819, imu loss:  8.237, mag loss:  9.131, div loss:  8.852, slim:  3.819, tlim:  2.720
#        valid loss:  52.916, imu loss:  8.987, mag loss: 23.215, div loss: 13.541, slim:  8.273, tlim:  6.806
# 03900: train loss:  11.691, imu loss:  8.217, mag loss:  8.951, div loss:  8.704, slim:  3.822, tlim:  2.722
#        valid loss:  52.472, imu loss:  9.009, mag loss: 23.052, div loss: 13.488, slim:  8.057, tlim:  6.545
# 04000: train loss:  11.755, imu loss:  8.238, mag loss:  9.052, div loss:  8.769, slim:  3.811, tlim:  2.718
#        valid loss:  52.491, imu loss:  8.972, mag loss: 22.909, div loss: 13.468, slim:  8.204, tlim:  6.787
# 04100: train loss:  11.666, imu loss:  8.217, mag loss:  8.924, div loss:  8.672, slim:  3.843, tlim:  2.712
#        valid loss:  52.463, imu loss:  8.999, mag loss: 23.017, div loss: 13.498, slim:  8.026, tlim:  6.590
# 04200: train loss:  11.685, imu loss:  8.217, mag loss:  8.937, div loss:  8.691, slim:  3.846, tlim:  2.720
#        valid loss:  52.779, imu loss:  8.985, mag loss: 23.138, div loss: 13.569, slim:  8.139, tlim:  6.735
# 04300: train loss:  11.485, imu loss:  8.220, mag loss:  8.707, div loss:  8.428, slim:  3.820, tlim:  2.706
#        valid loss:  52.658, imu loss:  8.987, mag loss: 23.178, div loss: 13.674, slim:  7.966, tlim:  6.435
# 04400: train loss:  11.459, imu loss:  8.208, mag loss:  8.687, div loss:  8.435, slim:  3.806, tlim:  2.689
#        valid loss:  52.907, imu loss:  8.988, mag loss: 23.317, div loss: 13.736, slim:  7.968, tlim:  6.498
# 04500: train loss:  11.413, imu loss:  8.215, mag loss:  8.650, div loss:  8.379, slim:  3.797, tlim:  2.674
#        valid loss:  52.474, imu loss:  8.984, mag loss: 22.964, div loss: 13.506, slim:  8.083, tlim:  6.667
# 04600: train loss:  11.408, imu loss:  8.212, mag loss:  8.674, div loss:  8.350, slim:  3.810, tlim:  2.663
#        valid loss:  52.915, imu loss:  9.002, mag loss: 23.320, div loss: 13.589, slim:  8.105, tlim:  6.638
# 04700: train loss:  11.366, imu loss:  8.210, mag loss:  8.600, div loss:  8.333, slim:  3.812, tlim:  2.657
#        valid loss:  53.319, imu loss:  8.975, mag loss: 23.312, div loss: 14.142, slim:  8.011, tlim:  6.517
# 04800: train loss:  11.279, imu loss:  8.206, mag loss:  8.491, div loss:  8.244, slim:  3.783, tlim:  2.653
#        valid loss:  53.209, imu loss:  8.988, mag loss: 23.262, div loss: 13.908, slim:  8.146, tlim:  6.687
# 04900: train loss:  11.181, imu loss:  8.189, mag loss:  8.405, div loss:  8.143, slim:  3.787, tlim:  2.619
#        valid loss:  52.808, imu loss:  8.993, mag loss: 23.369, div loss: 13.552, slim:  8.008, tlim:  6.524
# 05000: train loss:  11.222, imu loss:  8.181, mag loss:  8.469, div loss:  8.195, slim:  3.790, tlim:  2.617
#        valid loss:  52.584, imu loss:  8.987, mag loss: 23.129, div loss: 13.599, slim:  7.975, tlim:  6.500
# 05100: train loss:  11.162, imu loss:  8.198, mag loss:  8.401, div loss:  8.108, slim:  3.799, tlim:  2.606
#        valid loss:  52.976, imu loss:  9.015, mag loss: 23.348, div loss: 13.623, slim:  8.085, tlim:  6.626
# 05200: train loss:  11.087, imu loss:  8.212, mag loss:  8.275, div loss:  7.994, slim:  3.814, tlim:  2.617
#        valid loss:  53.004, imu loss:  8.999, mag loss: 23.394, div loss: 13.836, slim:  7.918, tlim:  6.394
# 05300: train loss:  11.035, imu loss:  8.193, mag loss:  8.275, div loss:  7.958, slim:  3.767, tlim:  2.586
#        valid loss:  53.053, imu loss:  9.006, mag loss: 23.414, div loss: 13.590, slim:  8.134, tlim:  6.678
# 05400: train loss:  10.934, imu loss:  8.189, mag loss:  8.115, div loss:  7.835, slim:  3.771, tlim:  2.596
#        valid loss:  53.090, imu loss:  8.981, mag loss: 23.426, div loss: 13.739, slim:  8.034, tlim:  6.580
# 05500: train loss:  11.043, imu loss:  8.204, mag loss:  8.276, div loss:  7.969, slim:  3.780, tlim:  2.583
#        valid loss:  52.695, imu loss:  8.995, mag loss: 23.250, div loss: 13.522, slim:  8.028, tlim:  6.560
# 05600: train loss:  11.024, imu loss:  8.195, mag loss:  8.258, div loss:  7.932, slim:  3.773, tlim:  2.590
#        valid loss:  53.395, imu loss:  8.997, mag loss: 23.295, div loss: 13.991, slim:  8.199, tlim:  6.748
# 05700: train loss:  10.929, imu loss:  8.197, mag loss:  8.141, div loss:  7.838, slim:  3.803, tlim:  2.561
#        valid loss:  53.089, imu loss:  8.988, mag loss: 23.260, div loss: 13.682, slim:  8.213, tlim:  6.807
# 05800: train loss:  10.894, imu loss:  8.181, mag loss:  8.099, div loss:  7.801, slim:  3.772, tlim:  2.570
#        valid loss:  52.971, imu loss:  9.009, mag loss: 23.334, div loss: 13.836, slim:  7.911, tlim:  6.419
# 05900: train loss:  10.873, imu loss:  8.187, mag loss:  8.105, div loss:  7.774, slim:  3.766, tlim:  2.551
#        valid loss:  52.931, imu loss:  8.995, mag loss: 23.434, div loss: 13.662, slim:  7.982, tlim:  6.459
# 06000: train loss:  10.853, imu loss:  8.187, mag loss:  8.065, div loss:  7.742, slim:  3.780, tlim:  2.557
#        valid loss:  53.078, imu loss:  8.997, mag loss: 23.371, div loss: 13.822, slim:  8.022, tlim:  6.509
# 06100: train loss:  10.798, imu loss:  8.200, mag loss:  7.991, div loss:  7.666, slim:  3.805, tlim:  2.546
#        valid loss:  52.690, imu loss:  8.980, mag loss: 23.365, div loss: 13.457, slim:  8.056, tlim:  6.500
# 06200: train loss:  10.730, imu loss:  8.171, mag loss:  7.951, div loss:  7.615, slim:  3.760, tlim:  2.525
#        valid loss:  52.968, imu loss:  9.009, mag loss: 23.467, div loss: 13.681, slim:  7.972, tlim:  6.425
# 06300: train loss:  10.731, imu loss:  8.173, mag loss:  7.937, div loss:  7.642, slim:  3.769, tlim:  2.519
#        valid loss:  53.190, imu loss:  8.995, mag loss: 23.470, div loss: 13.848, slim:  7.996, tlim:  6.503
# 06400: train loss:  10.635, imu loss:  8.172, mag loss:  7.815, div loss:  7.522, slim:  3.764, tlim:  2.516
#        valid loss:  52.996, imu loss:  9.003, mag loss: 23.380, div loss: 13.697, slim:  8.059, tlim:  6.535
# 06500: train loss:  10.684, imu loss:  8.186, mag loss:  7.876, div loss:  7.546, slim:  3.771, tlim:  2.529
#        valid loss:  53.362, imu loss:  8.991, mag loss: 23.348, div loss: 13.958, slim:  8.166, tlim:  6.697
# 06600: train loss:  10.701, imu loss:  8.182, mag loss:  7.940, div loss:  7.596, slim:  3.759, tlim:  2.501
#        valid loss:  52.944, imu loss:  9.005, mag loss: 23.324, div loss: 13.767, slim:  8.020, tlim:  6.458
# 06700: train loss:  10.524, imu loss:  8.178, mag loss:  7.713, div loss:  7.430, slim:  3.751, tlim:  2.469
#        valid loss:  53.207, imu loss:  8.996, mag loss: 23.548, div loss: 13.865, slim:  8.017, tlim:  6.392
# 06800: train loss:  10.518, imu loss:  8.166, mag loss:  7.688, div loss:  7.388, slim:  3.762, tlim:  2.494
#        valid loss:  53.555, imu loss:  9.019, mag loss: 23.522, div loss: 13.966, slim:  8.172, tlim:  6.672
# 06900: train loss:  10.639, imu loss:  8.182, mag loss:  7.834, div loss:  7.514, slim:  3.765, tlim:  2.512
#        valid loss:  53.524, imu loss:  9.008, mag loss: 23.476, div loss: 14.058, slim:  8.116, tlim:  6.604
# 07000: train loss:  10.466, imu loss:  8.165, mag loss:  7.649, div loss:  7.330, slim:  3.746, tlim:  2.480
#        valid loss:  53.343, imu loss:  8.993, mag loss: 23.674, div loss: 13.932, slim:  7.954, tlim:  6.339
# 07100: train loss:  10.497, imu loss:  8.174, mag loss:  7.689, div loss:  7.369, slim:  3.765, tlim:  2.472
#        valid loss:  53.740, imu loss:  9.005, mag loss: 23.580, div loss: 14.185, slim:  8.105, tlim:  6.591
# 07200: train loss:  10.454, imu loss:  8.170, mag loss:  7.638, div loss:  7.303, slim:  3.742, tlim:  2.482
#        valid loss:  52.965, imu loss:  9.014, mag loss: 23.412, div loss: 13.700, slim:  8.001, tlim:  6.451
# 07300: train loss:  10.334, imu loss:  8.164, mag loss:  7.473, div loss:  7.173, slim:  3.762, tlim:  2.467
#        valid loss:  53.687, imu loss:  9.016, mag loss: 23.571, div loss: 14.048, slim:  8.172, tlim:  6.679
# 07400: train loss:  10.413, imu loss:  8.179, mag loss:  7.597, div loss:  7.262, slim:  3.774, tlim:  2.456
#        valid loss:  53.908, imu loss:  9.008, mag loss: 23.687, div loss: 14.178, slim:  8.150, tlim:  6.664
# 07500: train loss:  10.333, imu loss:  8.165, mag loss:  7.493, div loss:  7.182, slim:  3.741, tlim:  2.458
#        valid loss:  53.794, imu loss:  8.996, mag loss: 23.745, div loss: 14.161, slim:  8.075, tlim:  6.497
# 07600: train loss:  10.306, imu loss:  8.162, mag loss:  7.508, div loss:  7.124, slim:  3.745, tlim:  2.441
#        valid loss:  53.548, imu loss:  9.024, mag loss: 23.466, div loss: 14.162, slim:  8.044, tlim:  6.512
# 07700: train loss:  10.321, imu loss:  8.153, mag loss:  7.498, div loss:  7.190, slim:  3.769, tlim:  2.432
#        valid loss:  53.289, imu loss:  9.016, mag loss: 23.466, div loss: 13.850, slim:  8.096, tlim:  6.577
# 07800: train loss:  10.256, imu loss:  8.169, mag loss:  7.431, div loss:  7.118, slim:  3.742, tlim:  2.418
#        valid loss:  54.091, imu loss:  9.015, mag loss: 23.746, div loss: 14.221, slim:  8.260, tlim:  6.725
# 07900: train loss:  10.254, imu loss:  8.160, mag loss:  7.432, div loss:  7.087, slim:  3.749, tlim:  2.431
#        valid loss:  53.798, imu loss:  9.000, mag loss: 23.589, div loss: 14.130, slim:  8.230, tlim:  6.695
# 08000: train loss:  10.144, imu loss:  8.155, mag loss:  7.267, div loss:  6.983, slim:  3.751, tlim:  2.422
#        valid loss:  53.441, imu loss:  9.027, mag loss: 23.420, div loss: 13.990, slim:  8.168, tlim:  6.615
# 08100: train loss:  10.151, imu loss:  8.154, mag loss:  7.311, div loss:  6.980, slim:  3.734, tlim:  2.416
#        valid loss:  53.887, imu loss:  9.007, mag loss: 23.777, div loss: 14.243, slim:  8.031, tlim:  6.470
# 08200: train loss:  10.139, imu loss:  8.157, mag loss:  7.277, div loss:  6.966, slim:  3.733, tlim:  2.425
#        valid loss:  53.549, imu loss:  9.025, mag loss: 23.624, div loss: 14.032, slim:  8.055, tlim:  6.473
# 08300: train loss:  10.118, imu loss:  8.147, mag loss:  7.289, div loss:  6.921, slim:  3.764, tlim:  2.406
#        valid loss:  53.207, imu loss:  9.035, mag loss: 23.545, div loss: 13.834, slim:  7.977, tlim:  6.397
# 08400: train loss:  10.071, imu loss:  8.155, mag loss:  7.174, div loss:  6.889, slim:  3.766, tlim:  2.415
#        valid loss:  53.905, imu loss:  9.003, mag loss: 23.739, div loss: 14.344, slim:  8.001, tlim:  6.426
# 08500: train loss:  10.085, imu loss:  8.161, mag loss:  7.275, div loss:  6.910, slim:  3.740, tlim:  2.378
#        valid loss:  53.402, imu loss:  9.011, mag loss: 23.582, div loss: 13.993, slim:  8.039, tlim:  6.408
# 08600: train loss:  10.075, imu loss:  8.140, mag loss:  7.256, div loss:  6.904, slim:  3.736, tlim:  2.386
#        valid loss:  53.326, imu loss:  9.015, mag loss: 23.533, div loss: 13.909, slim:  8.056, tlim:  6.473
# 08700: train loss:  10.015, imu loss:  8.139, mag loss:  7.191, div loss:  6.847, slim:  3.724, tlim:  2.373
#        valid loss:  53.952, imu loss:  9.033, mag loss: 23.812, div loss: 14.273, slim:  8.033, tlim:  6.434
# 08800: train loss:  10.030, imu loss:  8.138, mag loss:  7.185, div loss:  6.830, slim:  3.739, tlim:  2.399
#        valid loss:  53.428, imu loss:  9.024, mag loss: 23.577, div loss: 14.038, slim:  8.002, tlim:  6.385
# 08900: train loss:  10.026, imu loss:  8.138, mag loss:  7.183, div loss:  6.859, slim:  3.736, tlim:  2.384
#        valid loss:  53.722, imu loss:  9.020, mag loss: 23.607, div loss: 14.281, slim:  7.987, tlim:  6.423
# 09000: train loss:  10.001, imu loss:  8.142, mag loss:  7.181, div loss:  6.782, slim:  3.758, tlim:  2.380
#        valid loss:  53.520, imu loss:  9.004, mag loss: 23.634, div loss: 14.037, slim:  8.059, tlim:  6.441
# 09100: train loss:  10.007, imu loss:  8.135, mag loss:  7.169, div loss:  6.823, slim:  3.758, tlim:  2.378
#        valid loss:  53.812, imu loss:  9.016, mag loss: 23.780, div loss: 14.298, slim:  7.932, tlim:  6.314
# 09200: train loss:   9.908, imu loss:  8.139, mag loss:  7.051, div loss:  6.708, slim:  3.728, tlim:  2.371
#        valid loss:  53.854, imu loss:  9.004, mag loss: 23.718, div loss: 14.090, slim:  8.202, tlim:  6.657
# 09300: train loss:   9.897, imu loss:  8.145, mag loss:  7.035, div loss:  6.702, slim:  3.741, tlim:  2.362
#        valid loss:  54.186, imu loss:  9.047, mag loss: 23.787, div loss: 14.398, slim:  8.129, tlim:  6.561
# 09400: train loss:   9.924, imu loss:  8.137, mag loss:  7.111, div loss:  6.719, slim:  3.753, tlim:  2.350
#        valid loss:  53.979, imu loss:  9.030, mag loss: 23.724, div loss: 14.189, slim:  8.186, tlim:  6.653
# 09500: train loss:   9.880, imu loss:  8.129, mag loss:  7.070, div loss:  6.683, slim:  3.773, tlim:  2.327
#        valid loss:  53.632, imu loss:  9.047, mag loss: 23.639, div loss: 14.145, slim:  8.008, tlim:  6.398
# 09600: train loss:   9.782, imu loss:  8.117, mag loss:  6.924, div loss:  6.569, slim:  3.738, tlim:  2.342
#        valid loss:  54.316, imu loss:  9.022, mag loss: 23.874, div loss: 14.358, slim:  8.225, tlim:  6.675
# 09700: train loss:   9.871, imu loss:  8.128, mag loss:  7.065, div loss:  6.669, slim:  3.747, tlim:  2.333
#        valid loss:  54.654, imu loss:  9.031, mag loss: 24.014, div loss: 14.535, slim:  8.248, tlim:  6.683
# 09800: train loss:   9.830, imu loss:  8.122, mag loss:  7.005, div loss:  6.640, slim:  3.731, tlim:  2.332
#        valid loss:  53.210, imu loss:  9.027, mag loss: 23.618, div loss: 13.858, slim:  7.934, tlim:  6.299
# 09900: train loss:   9.790, imu loss:  8.120, mag loss:  6.954, div loss:  6.597, slim:  3.723, tlim:  2.330
#        valid loss:  54.001, imu loss:  9.030, mag loss: 23.666, div loss: 14.327, slim:  8.163, tlim:  6.583
# 10000: train loss:   9.778, imu loss:  8.124, mag loss:  6.932, div loss:  6.586, slim:  3.753, tlim:  2.319
#        valid loss:  54.108, imu loss:  9.035, mag loss: 23.836, div loss: 14.257, slim:  8.142, tlim:  6.593
# 10100: train loss:   9.845, imu loss:  8.121, mag loss:  7.050, div loss:  6.652, slim:  3.732, tlim:  2.325
#        valid loss:  53.660, imu loss:  9.021, mag loss: 23.674, div loss: 14.176, slim:  7.992, tlim:  6.388
# 10200: train loss:   9.761, imu loss:  8.127, mag loss:  6.931, div loss:  6.538, slim:  3.753, tlim:  2.321
#        valid loss:  53.805, imu loss:  9.030, mag loss: 23.822, div loss: 14.182, slim:  8.024, tlim:  6.353
# 10300: train loss:   9.740, imu loss:  8.121, mag loss:  6.912, div loss:  6.521, slim:  3.738, tlim:  2.320
#        valid loss:  54.013, imu loss:  9.014, mag loss: 23.728, div loss: 14.288, slim:  8.121, tlim:  6.603
# 10400: train loss:   9.779, imu loss:  8.125, mag loss:  6.954, div loss:  6.564, slim:  3.744, tlim:  2.325
#        valid loss:  54.275, imu loss:  9.037, mag loss: 23.949, div loss: 14.478, slim:  8.027, tlim:  6.407
# 10500: train loss:   9.771, imu loss:  8.133, mag loss:  6.989, div loss:  6.567, slim:  3.717, tlim:  2.303
#        valid loss:  54.198, imu loss:  9.039, mag loss: 23.996, div loss: 14.508, slim:  7.858, tlim:  6.254
# 10600: train loss:   9.686, imu loss:  8.113, mag loss:  6.842, div loss:  6.494, slim:  3.728, tlim:  2.303
#        valid loss:  54.095, imu loss:  9.042, mag loss: 23.822, div loss: 14.285, slim:  8.132, tlim:  6.551
# 10700: train loss:   9.661, imu loss:  8.117, mag loss:  6.841, div loss:  6.463, slim:  3.742, tlim:  2.281
#        valid loss:  54.501, imu loss:  9.036, mag loss: 23.969, div loss: 14.578, slim:  8.121, tlim:  6.518
# 10800: train loss:   9.697, imu loss:  8.114, mag loss:  6.892, div loss:  6.504, slim:  3.743, tlim:  2.284
#        valid loss:  54.597, imu loss:  9.027, mag loss: 24.011, div loss: 14.519, slim:  8.205, tlim:  6.651
# 10900: train loss:   9.636, imu loss:  8.104, mag loss:  6.850, div loss:  6.436, slim:  3.710, tlim:  2.273
#        valid loss:  53.866, imu loss:  9.031, mag loss: 23.764, div loss: 14.428, slim:  7.914, tlim:  6.220
# 11000: train loss:   9.490, imu loss:  8.100, mag loss:  6.647, div loss:  6.281, slim:  3.715, tlim:  2.257
#        valid loss:  54.642, imu loss:  9.054, mag loss: 24.280, div loss: 14.671, slim:  7.860, tlim:  6.229
# 11100: train loss:   9.547, imu loss:  8.104, mag loss:  6.714, div loss:  6.328, slim:  3.725, tlim:  2.273
#        valid loss:  54.745, imu loss:  9.038, mag loss: 24.123, div loss: 14.642, slim:  8.154, tlim:  6.539
# 11200: train loss:   9.555, imu loss:  8.120, mag loss:  6.746, div loss:  6.338, slim:  3.730, tlim:  2.256
#        valid loss:  54.721, imu loss:  9.020, mag loss: 24.063, div loss: 14.611, slim:  8.207, tlim:  6.633
# 11300: train loss:   9.537, imu loss:  8.116, mag loss:  6.719, div loss:  6.320, slim:  3.722, tlim:  2.259
#        valid loss:  54.627, imu loss:  9.032, mag loss: 24.059, div loss: 14.633, slim:  8.106, tlim:  6.502
# 11400: train loss:   9.490, imu loss:  8.091, mag loss:  6.657, div loss:  6.265, slim:  3.748, tlim:  2.255
#        valid loss:  54.201, imu loss:  9.041, mag loss: 23.914, div loss: 14.590, slim:  7.885, tlim:  6.247
# 11500: train loss:   9.571, imu loss:  8.109, mag loss:  6.761, div loss:  6.361, slim:  3.725, tlim:  2.266
#        valid loss:  54.256, imu loss:  9.042, mag loss: 24.136, div loss: 14.505, slim:  7.841, tlim:  6.150
# 11600: train loss:   9.512, imu loss:  8.093, mag loss:  6.712, div loss:  6.287, slim:  3.733, tlim:  2.252
#        valid loss:  54.642, imu loss:  9.032, mag loss: 24.071, div loss: 14.703, slim:  8.039, tlim:  6.433
# 11700: train loss:   9.423, imu loss:  8.094, mag loss:  6.607, div loss:  6.172, slim:  3.743, tlim:  2.242
#        valid loss:  54.283, imu loss:  9.032, mag loss: 23.887, div loss: 14.531, slim:  8.039, tlim:  6.431
# 11800: train loss:   9.455, imu loss:  8.112, mag loss:  6.664, div loss:  6.240, slim:  3.717, tlim:  2.225
#        valid loss:  54.428, imu loss:  9.030, mag loss: 24.127, div loss: 14.579, slim:  7.881, tlim:  6.296
# 11900: train loss:   9.542, imu loss:  8.108, mag loss:  6.763, div loss:  6.296, slim:  3.739, tlim:  2.258
#        valid loss:  54.696, imu loss:  9.021, mag loss: 24.079, div loss: 14.704, slim:  8.048, tlim:  6.508
# 12000: train loss:   9.448, imu loss:  8.112, mag loss:  6.650, div loss:  6.228, slim:  3.741, tlim:  2.221
#        valid loss:  54.506, imu loss:  9.029, mag loss: 24.188, div loss: 14.694, slim:  7.852, tlim:  6.174
# 12100: train loss:   9.461, imu loss:  8.099, mag loss:  6.677, div loss:  6.251, slim:  3.744, tlim:  2.217
#        valid loss:  54.704, imu loss:  9.032, mag loss: 24.245, div loss: 14.759, slim:  7.867, tlim:  6.268
# 12200: train loss:   9.369, imu loss:  8.095, mag loss:  6.572, div loss:  6.129, slim:  3.736, tlim:  2.214
#        valid loss:  55.168, imu loss:  9.022, mag loss: 24.439, div loss: 14.841, slim:  8.047, tlim:  6.474
# 12300: train loss:   9.441, imu loss:  8.097, mag loss:  6.631, div loss:  6.244, slim:  3.725, tlim:  2.224
#        valid loss:  54.592, imu loss:  9.022, mag loss: 24.284, div loss: 14.814, slim:  7.746, tlim:  6.047
# 12400: train loss:   9.325, imu loss:  8.101, mag loss:  6.494, div loss:  6.109, slim:  3.734, tlim:  2.202
#        valid loss:  54.906, imu loss:  9.027, mag loss: 24.289, div loss: 14.972, slim:  7.873, tlim:  6.200
# 12500: train loss:   9.397, imu loss:  8.094, mag loss:  6.615, div loss:  6.158, slim:  3.751, tlim:  2.214
#        valid loss:  54.784, imu loss:  9.030, mag loss: 24.195, div loss: 14.822, slim:  7.951, tlim:  6.333
# 12600: train loss:   9.409, imu loss:  8.091, mag loss:  6.592, div loss:  6.195, slim:  3.737, tlim:  2.227
#        valid loss:  55.263, imu loss:  9.037, mag loss: 24.549, div loss: 15.209, slim:  7.701, tlim:  6.057
# 12700: train loss:   9.284, imu loss:  8.094, mag loss:  6.473, div loss:  6.033, slim:  3.754, tlim:  2.196
#        valid loss:  55.433, imu loss:  9.045, mag loss: 24.367, div loss: 15.258, slim:  7.957, tlim:  6.365
# 12800: train loss:   9.377, imu loss:  8.088, mag loss:  6.587, div loss:  6.122, slim:  3.767, tlim:  2.218
#        valid loss:  55.168, imu loss:  9.029, mag loss: 24.589, div loss: 14.871, slim:  7.893, tlim:  6.274
# 12900: train loss:   9.423, imu loss:  8.078, mag loss:  6.679, div loss:  6.181, slim:  3.745, tlim:  2.217
#        valid loss:  55.658, imu loss:  9.034, mag loss: 24.611, div loss: 15.179, slim:  8.019, tlim:  6.439
# 13000: train loss:   9.332, imu loss:  8.100, mag loss:  6.548, div loss:  6.086, slim:  3.758, tlim:  2.196
#        valid loss:  55.236, imu loss:  9.022, mag loss: 24.437, div loss: 14.961, slim:  8.006, tlim:  6.419
# 13100: train loss:   9.214, imu loss:  8.083, mag loss:  6.389, div loss:  5.951, slim:  3.754, tlim:  2.192
#        valid loss:  55.104, imu loss:  9.030, mag loss: 24.343, div loss: 14.901, slim:  8.051, tlim:  6.425
# 13200: train loss:   9.288, imu loss:  8.076, mag loss:  6.489, div loss:  6.063, slim:  3.755, tlim:  2.187
#        valid loss:  54.871, imu loss:  9.031, mag loss: 24.231, div loss: 14.709, slim:  8.083, tlim:  6.505
# 13300: train loss:   9.230, imu loss:  8.086, mag loss:  6.442, div loss:  5.992, slim:  3.742, tlim:  2.172
#        valid loss:  55.466, imu loss:  9.019, mag loss: 24.735, div loss: 15.051, slim:  7.897, tlim:  6.249
# 13400: train loss:   9.231, imu loss:  8.076, mag loss:  6.400, div loss:  6.028, slim:  3.746, tlim:  2.174
#        valid loss:  56.020, imu loss:  9.016, mag loss: 24.808, div loss: 15.223, slim:  8.125, tlim:  6.588
# 13500: train loss:   9.265, imu loss:  8.100, mag loss:  6.453, div loss:  6.009, slim:  3.773, tlim:  2.191
#        valid loss:  55.910, imu loss:  9.033, mag loss: 24.814, div loss: 15.173, slim:  8.076, tlim:  6.494
# 13600: train loss:   9.203, imu loss:  8.078, mag loss:  6.398, div loss:  5.966, slim:  3.776, tlim:  2.164
#        valid loss:  55.226, imu loss:  9.019, mag loss: 24.518, div loss: 15.019, slim:  7.906, tlim:  6.258
# 13700: train loss:   9.246, imu loss:  8.068, mag loss:  6.486, div loss:  6.006, slim:  3.773, tlim:  2.165
#        valid loss:  54.872, imu loss:  9.025, mag loss: 24.326, div loss: 14.643, slim:  8.055, tlim:  6.486
# 13800: train loss:   9.212, imu loss:  8.087, mag loss:  6.427, div loss:  5.968, slim:  3.753, tlim:  2.168
#        valid loss:  54.404, imu loss:  9.030, mag loss: 24.277, div loss: 14.571, slim:  7.800, tlim:  6.101
# 13900: train loss:   9.222, imu loss:  8.076, mag loss:  6.454, div loss:  5.998, slim:  3.747, tlim:  2.159
#        valid loss:  55.640, imu loss:  9.014, mag loss: 24.586, div loss: 15.239, slim:  8.002, tlim:  6.401
# 14000: train loss:   9.142, imu loss:  8.072, mag loss:  6.354, div loss:  5.918, slim:  3.756, tlim:  2.140
#        valid loss:  55.149, imu loss:  9.028, mag loss: 24.460, div loss: 15.030, slim:  7.863, tlim:  6.219
# 14100: train loss:   9.068, imu loss:  8.080, mag loss:  6.273, div loss:  5.839, slim:  3.756, tlim:  2.119
#        valid loss:  55.351, imu loss:  9.005, mag loss: 24.476, div loss: 15.015, slim:  8.045, tlim:  6.459
# 14200: train loss:   9.150, imu loss:  8.087, mag loss:  6.372, div loss:  5.901, slim:  3.792, tlim:  2.137
#        valid loss:  55.475, imu loss:  9.010, mag loss: 24.507, div loss: 15.098, slim:  8.064, tlim:  6.459
# 14300: train loss:   9.084, imu loss:  8.076, mag loss:  6.312, div loss:  5.851, slim:  3.756, tlim:  2.120
#        valid loss:  55.383, imu loss:  9.028, mag loss: 24.256, div loss: 15.250, slim:  8.052, tlim:  6.446
# 14400: train loss:   9.102, imu loss:  8.061, mag loss:  6.343, div loss:  5.862, slim:  3.790, tlim:  2.119
#        valid loss:  55.505, imu loss:  9.024, mag loss: 24.567, div loss: 14.983, slim:  8.151, tlim:  6.524
# 14500: train loss:   9.104, imu loss:  8.074, mag loss:  6.321, div loss:  5.826, slim:  3.784, tlim:  2.150
#        valid loss:  55.726, imu loss:  9.016, mag loss: 24.759, div loss: 15.261, slim:  7.917, tlim:  6.281
# 14600: train loss:   9.098, imu loss:  8.073, mag loss:  6.329, div loss:  5.862, slim:  3.766, tlim:  2.125
#        valid loss:  55.007, imu loss:  9.011, mag loss: 24.522, div loss: 14.900, slim:  7.820, tlim:  6.159
# 14700: train loss:   9.015, imu loss:  8.069, mag loss:  6.189, div loss:  5.766, slim:  3.782, tlim:  2.125
#        valid loss:  56.012, imu loss:  9.011, mag loss: 24.870, div loss: 15.222, slim:  8.128, tlim:  6.503
# 14800: train loss:   9.040, imu loss:  8.065, mag loss:  6.288, div loss:  5.789, slim:  3.768, tlim:  2.110
#        valid loss:  55.044, imu loss:  8.997, mag loss: 24.615, div loss: 14.805, slim:  7.885, tlim:  6.208
# 14900: train loss:   9.057, imu loss:  8.062, mag loss:  6.256, div loss:  5.807, slim:  3.798, tlim:  2.128
#        valid loss:  55.859, imu loss:  9.004, mag loss: 24.563, div loss: 15.193, slim:  8.299, tlim:  6.699
# 15000: train loss:   9.024, imu loss:  8.055, mag loss:  6.287, div loss:  5.800, slim:  3.731, tlim:  2.101
#        valid loss:  55.556, imu loss:  9.027, mag loss: 24.674, div loss: 15.020, slim:  8.035, tlim:  6.436
# 15100: train loss:   9.007, imu loss:  8.081, mag loss:  6.245, div loss:  5.753, slim:  3.767, tlim:  2.103
#        valid loss:  55.517, imu loss:  8.998, mag loss: 24.642, div loss: 15.015, slim:  8.060, tlim:  6.462
# 15200: train loss:   8.939, imu loss:  8.049, mag loss:  6.162, div loss:  5.708, slim:  3.741, tlim:  2.092
#        valid loss:  55.185, imu loss:  9.019, mag loss: 24.592, div loss: 14.967, slim:  7.818, tlim:  6.203
# 15300: train loss:   8.997, imu loss:  8.054, mag loss:  6.245, div loss:  5.763, slim:  3.764, tlim:  2.096
#        valid loss:  55.895, imu loss:  9.016, mag loss: 24.802, div loss: 15.319, slim:  7.962, tlim:  6.357
# 15400: train loss:   8.959, imu loss:  8.072, mag loss:  6.178, div loss:  5.729, slim:  3.770, tlim:  2.084
#        valid loss:  55.585, imu loss:  9.017, mag loss: 24.680, div loss: 15.187, slim:  7.952, tlim:  6.283
# 15500: train loss:   8.949, imu loss:  8.051, mag loss:  6.164, div loss:  5.729, slim:  3.791, tlim:  2.079
#        valid loss:  55.640, imu loss:  9.011, mag loss: 24.586, div loss: 15.228, slim:  8.054, tlim:  6.402
# 15600: train loss:   8.914, imu loss:  8.062, mag loss:  6.120, div loss:  5.651, slim:  3.816, tlim:  2.084
#        valid loss:  55.626, imu loss:  9.004, mag loss: 24.626, div loss: 15.089, slim:  8.085, tlim:  6.514
# 15700: train loss:   8.865, imu loss:  8.041, mag loss:  6.065, div loss:  5.637, slim:  3.781, tlim:  2.068
#        valid loss:  55.946, imu loss:  9.016, mag loss: 24.640, div loss: 15.278, slim:  8.179, tlim:  6.623
# 15800: train loss:   8.915, imu loss:  8.050, mag loss:  6.143, div loss:  5.688, slim:  3.770, tlim:  2.076
#        valid loss:  55.697, imu loss:  8.999, mag loss: 24.625, div loss: 15.227, slim:  8.046, tlim:  6.446
# 15900: train loss:   8.894, imu loss:  8.047, mag loss:  6.118, div loss:  5.643, slim:  3.776, tlim:  2.085
#        valid loss:  55.872, imu loss:  9.018, mag loss: 24.744, div loss: 15.332, slim:  7.975, tlim:  6.380
# 16000: train loss:   8.874, imu loss:  8.059, mag loss:  6.133, div loss:  5.625, slim:  3.787, tlim:  2.056
#        valid loss:  55.513, imu loss:  9.033, mag loss: 24.525, div loss: 15.075, slim:  8.127, tlim:  6.466
# 16100: train loss:   8.896, imu loss:  8.063, mag loss:  6.142, div loss:  5.661, slim:  3.770, tlim:  2.065
#        valid loss:  55.497, imu loss:  9.017, mag loss: 24.545, div loss: 15.178, slim:  7.966, tlim:  6.354
# 16200: train loss:   8.857, imu loss:  8.055, mag loss:  6.101, div loss:  5.628, slim:  3.761, tlim:  2.055
#        valid loss:  56.293, imu loss:  9.015, mag loss: 24.950, div loss: 15.499, slim:  8.026, tlim:  6.431
# 16300: train loss:   8.831, imu loss:  8.059, mag loss:  6.075, div loss:  5.596, slim:  3.778, tlim:  2.044
#        valid loss:  55.694, imu loss:  9.008, mag loss: 24.688, div loss: 15.123, slim:  8.084, tlim:  6.472
# 16400: train loss:   8.849, imu loss:  8.048, mag loss:  6.072, div loss:  5.618, slim:  3.758, tlim:  2.067
#        valid loss:  55.863, imu loss:  9.002, mag loss: 24.789, div loss: 15.233, slim:  8.011, tlim:  6.449
# 16500: train loss:   8.780, imu loss:  8.031, mag loss:  6.000, div loss:  5.548, slim:  3.768, tlim:  2.049
#        valid loss:  55.803, imu loss:  9.024, mag loss: 24.749, div loss: 15.270, slim:  7.993, tlim:  6.349
# 16600: train loss:   8.813, imu loss:  8.035, mag loss:  6.037, div loss:  5.594, slim:  3.807, tlim:  2.037
#        valid loss:  56.385, imu loss:  9.006, mag loss: 25.055, div loss: 15.497, slim:  8.028, tlim:  6.427
# 16700: train loss:   8.733, imu loss:  8.055, mag loss:  5.942, div loss:  5.501, slim:  3.768, tlim:  2.031
#        valid loss:  55.689, imu loss:  9.016, mag loss: 24.741, div loss: 15.065, slim:  8.083, tlim:  6.460
# 16800: train loss:   8.739, imu loss:  8.043, mag loss:  5.977, div loss:  5.513, slim:  3.771, tlim:  2.022
#        valid loss:  55.681, imu loss:  9.020, mag loss: 24.755, div loss: 15.143, slim:  8.006, tlim:  6.349
# 16900: train loss:   8.726, imu loss:  8.047, mag loss:  5.926, div loss:  5.493, slim:  3.808, tlim:  2.022
#        valid loss:  55.966, imu loss:  9.014, mag loss: 24.865, div loss: 15.268, slim:  8.038, tlim:  6.413
# 17000: train loss:   8.777, imu loss:  8.037, mag loss:  6.012, div loss:  5.553, slim:  3.780, tlim:  2.035
#        valid loss:  56.142, imu loss:  9.025, mag loss: 24.958, div loss: 15.275, slim:  8.100, tlim:  6.479
# 17100: train loss:   8.751, imu loss:  8.054, mag loss:  6.005, div loss:  5.500, slim:  3.801, tlim:  2.024
#        valid loss:  56.309, imu loss:  9.031, mag loss: 24.952, div loss: 15.531, slim:  7.965, tlim:  6.405
# 17200: train loss:   8.771, imu loss:  8.037, mag loss:  6.046, div loss:  5.536, slim:  3.802, tlim:  2.019
#        valid loss:  56.555, imu loss:  9.012, mag loss: 25.055, div loss: 15.706, slim:  8.009, tlim:  6.373
# 17300: train loss:   8.771, imu loss:  8.047, mag loss:  6.019, div loss:  5.528, slim:  3.818, tlim:  2.027
#        valid loss:  56.172, imu loss:  9.022, mag loss: 24.921, div loss: 15.324, slim:  8.111, tlim:  6.503
# 17400: train loss:   8.666, imu loss:  8.031, mag loss:  5.897, div loss:  5.420, slim:  3.785, tlim:  2.017
#        valid loss:  56.213, imu loss:  9.013, mag loss: 24.876, div loss: 15.515, slim:  8.011, tlim:  6.407
# 17500: train loss:   8.711, imu loss:  8.051, mag loss:  5.961, div loss:  5.454, slim:  3.804, tlim:  2.018
#        valid loss:  55.832, imu loss:  9.020, mag loss: 24.786, div loss: 15.326, slim:  7.908, tlim:  6.298
# 17600: train loss:   8.682, imu loss:  8.041, mag loss:  5.908, div loss:  5.447, slim:  3.803, tlim:  2.009
#        valid loss:  55.263, imu loss:  9.031, mag loss: 24.583, div loss: 15.036, slim:  7.914, tlim:  6.178
# 17700: train loss:   8.660, imu loss:  8.039, mag loss:  5.889, div loss:  5.413, slim:  3.807, tlim:  2.008
#        valid loss:  56.473, imu loss:  9.008, mag loss: 24.862, div loss: 15.405, slim:  8.385, tlim:  6.802
# 17800: train loss:   8.677, imu loss:  8.030, mag loss:  5.927, div loss:  5.439, slim:  3.809, tlim:  2.004
#        valid loss:  56.094, imu loss:  9.002, mag loss: 24.694, div loss: 15.357, slim:  8.225, tlim:  6.646
# 17900: train loss:   8.690, imu loss:  8.026, mag loss:  5.934, div loss:  5.451, slim:  3.815, tlim:  2.011
#        valid loss:  55.904, imu loss:  9.014, mag loss: 24.875, div loss: 15.220, slim:  8.046, tlim:  6.378
# 18000: train loss:   8.631, imu loss:  8.024, mag loss:  5.882, div loss:  5.386, slim:  3.818, tlim:  1.993
#        valid loss:  55.922, imu loss:  9.024, mag loss: 24.860, div loss: 15.177, slim:  8.078, tlim:  6.454
# 18100: train loss:   8.671, imu loss:  8.012, mag loss:  5.963, div loss:  5.439, slim:  3.803, tlim:  1.993
#        valid loss:  56.408, imu loss:  9.009, mag loss: 24.953, div loss: 15.411, slim:  8.213, tlim:  6.642
# 18200: train loss:   8.594, imu loss:  8.019, mag loss:  5.856, div loss:  5.336, slim:  3.836, tlim:  1.982
#        valid loss:  55.808, imu loss:  9.007, mag loss: 25.052, div loss: 15.158, slim:  7.850, tlim:  6.172
# 18300: train loss:   8.605, imu loss:  8.039, mag loss:  5.812, div loss:  5.374, slim:  3.836, tlim:  1.982
#        valid loss:  56.012, imu loss:  9.002, mag loss: 25.035, div loss: 15.188, slim:  8.007, tlim:  6.379
# 18400: train loss:   8.603, imu loss:  8.028, mag loss:  5.855, div loss:  5.363, slim:  3.817, tlim:  1.983
#        valid loss:  56.115, imu loss:  9.002, mag loss: 25.025, div loss: 15.226, slim:  8.058, tlim:  6.463
# 18500: train loss:   8.565, imu loss:  8.019, mag loss:  5.797, div loss:  5.312, slim:  3.826, tlim:  1.985
#        valid loss:  56.139, imu loss:  9.012, mag loss: 25.002, div loss: 15.421, slim:  7.965, tlim:  6.285
# 18600: train loss:   8.563, imu loss:  8.021, mag loss:  5.774, div loss:  5.330, slim:  3.830, tlim:  1.979
#        valid loss:  56.265, imu loss:  9.005, mag loss: 25.000, div loss: 15.522, slim:  7.952, tlim:  6.335
# 18700: train loss:   8.560, imu loss:  8.027, mag loss:  5.814, div loss:  5.362, slim:  3.812, tlim:  1.945
#        valid loss:  56.537, imu loss:  9.011, mag loss: 25.043, div loss: 15.619, slim:  8.071, tlim:  6.461
# 18800: train loss:   8.565, imu loss:  8.026, mag loss:  5.856, div loss:  5.336, slim:  3.806, tlim:  1.957
#        valid loss:  56.122, imu loss:  9.011, mag loss: 24.883, div loss: 15.283, slim:  8.172, tlim:  6.537
# 18900: train loss:   8.574, imu loss:  8.033, mag loss:  5.875, div loss:  5.338, slim:  3.820, tlim:  1.955
#        valid loss:  56.196, imu loss:  9.024, mag loss: 25.137, div loss: 15.347, slim:  7.921, tlim:  6.278
# 19000: train loss:   8.504, imu loss:  8.013, mag loss:  5.768, div loss:  5.267, slim:  3.846, tlim:  1.944
#        valid loss:  56.935, imu loss:  9.009, mag loss: 25.381, div loss: 15.602, slim:  8.087, tlim:  6.561
# 19100: train loss:   8.494, imu loss:  8.013, mag loss:  5.716, div loss:  5.278, slim:  3.818, tlim:  1.951
#        valid loss:  56.634, imu loss:  9.008, mag loss: 25.227, div loss: 15.495, slim:  8.098, tlim:  6.505
# 19200: train loss:   8.458, imu loss:  8.032, mag loss:  5.688, div loss:  5.228, slim:  3.856, tlim:  1.927
#        valid loss:  56.602, imu loss:  9.022, mag loss: 25.325, div loss: 15.423, slim:  8.036, tlim:  6.432
# 19300: train loss:   8.580, imu loss:  8.021, mag loss:  5.893, div loss:  5.353, slim:  3.833, tlim:  1.949
#        valid loss:  56.646, imu loss:  9.010, mag loss: 25.288, div loss: 15.725, slim:  7.835, tlim:  6.219
# 19400: train loss:   8.447, imu loss:  8.017, mag loss:  5.712, div loss:  5.217, slim:  3.817, tlim:  1.932
#        valid loss:  56.091, imu loss:  9.015, mag loss: 25.089, div loss: 15.244, slim:  7.946, tlim:  6.341
# 19500: train loss:   8.502, imu loss:  8.003, mag loss:  5.793, div loss:  5.257, slim:  3.843, tlim:  1.947
#        valid loss:  56.168, imu loss:  9.008, mag loss: 25.043, div loss: 15.255, slim:  8.058, tlim:  6.463
# 19600: train loss:   8.449, imu loss:  8.022, mag loss:  5.714, div loss:  5.215, slim:  3.849, tlim:  1.923
#        valid loss:  55.933, imu loss:  9.025, mag loss: 25.090, div loss: 15.192, slim:  7.844, tlim:  6.221
# 19700: train loss:   8.488, imu loss:  8.019, mag loss:  5.789, div loss:  5.256, slim:  3.844, tlim:  1.927
#        valid loss:  56.601, imu loss:  9.018, mag loss: 25.133, div loss: 15.597, slim:  8.073, tlim:  6.445
# 19800: train loss:   8.501, imu loss:  8.026, mag loss:  5.768, div loss:  5.247, slim:  3.844, tlim:  1.955
#        valid loss:  56.957, imu loss:  9.033, mag loss: 25.288, div loss: 15.795, slim:  7.973, tlim:  6.463
# 19900: train loss:   8.477, imu loss:  8.014, mag loss:  5.767, div loss:  5.233, slim:  3.841, tlim:  1.939
#        valid loss:  56.640, imu loss:  9.019, mag loss: 25.092, div loss: 15.498, slim:  8.173, tlim:  6.649
# 20000: train loss:   8.426, imu loss:  8.014, mag loss:  5.674, div loss:  5.180, slim:  3.854, tlim:  1.934
#        valid loss:  56.195, imu loss:  8.998, mag loss: 24.948, div loss: 15.408, slim:  8.060, tlim:  6.433

# %%
show_result(model, train_loader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 show_result(model, train_loader)
#
# Cell In[20], line 2, in show_result(model, dataloader)
#       1 def show_result(model, dataloader):
# ----> 2     results, cres, clabel = output_eval(model, dataloader)
#       3     print(results.shape, cres.shape, clabel.shape)
#       5     if num_of_axie == 3:
#
# Cell In[19], line 21, in output_eval(model, dataloader)
#      18             target_mag = target_data[:, :, 11:(11 + num_of_axie)]
#      20             # generate mag
# ---> 21             z_imu, predict_mag = model(source_imu, target_imu, source_mag)
#      22             # generator loss
#      23 #             gen_loss, imu_loss, mag_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)
#      24
#      25             # record loss
#      26             predict_mag = predict_mag.detach().cpu().numpy()
#
# File ~/miniconda3/envs/mag39/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[15], line 51, in NotSimpleTransformer.forward(self, source_imu, target_imu, source_mag)
#      48 def forward(self, source_imu, target_imu, source_mag):
#      49
#      50     ### step 1
# ---> 51     h_imu = self.imu_layer(source_imu)
#      52     h_imu = self.pos_encoder(h_imu)
#      54     h_t_imu = self.imu_layer(target_imu)
#
# File ~/miniconda3/envs/mag39/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/mag39/lib/python3.9/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File ~/miniconda3/envs/mag39/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/mag39/lib/python3.9/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1280x6 and 9x16)

# %%
show_result(model, valid_loader)

# %%
torch.save(model, f'{path}/{gt}_{num_of_axis}_{rotation}_rework.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()

# %%
num_of_axis, rotation, gt = 3, True, 'target'

posture_data = get_data(validation_traj, num_of_axis, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['horizontal']   = split_traj(posture_data['horizontal'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH+1):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    draw = ((epoch) % 20000 == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw, epoch / EPOCH)
    
    if (epoch) % 100 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>7.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>7.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')

# %%
show_result(model, train_loader)

# %%
show_result(model, valid_loader)

# %%
torch.save(model, f'{path}/{gt}_{num_of_axis}_{rotation}_rework.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()

# %%
num_of_axis, rotation, gt = 3, False, 'horizontal'

posture_data = get_data(validation_traj, num_of_axis, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['horizontal']   = split_traj(posture_data['horizontal'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
imu_layer_params = list(model.imu_layer.parameters())
encoder_params = list(model.encoder.parameters())
nn_params = list(model.nn.parameters())
initial_params = imu_layer_params + encoder_params + nn_params
optimizer = torch.optim.Adam(initial_params, lr=0.0001)

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH+1):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    if epoch == 1000: optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    draw = ((epoch) % 20000 == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw, epoch / EPOCH)
    
    if (epoch) % 100 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>7.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>7.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')

# %%
show_result(model, train_loader)

# %%
show_result(model, valid_loader)

# %%
torch.save(model, f'{path}/{gt}_{num_of_axis}_{rotation}_rework.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()
