# %%
import argparse
import os
import csv
import random
import time
import json
import math
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## Load data

# %%
training_traj = np.load(f'./training_traj_0.6.npy')
validation_traj = np.load(f'./all_user_match_data.npy', allow_pickle=True)

# %%
posture_data = defaultdict(list)

valid_data = validation_traj.item()
for user_name in valid_data.keys():
    for path_name in valid_data[user_name].keys():
        for posture_name in valid_data[user_name][path_name].keys():
            data = valid_data[user_name][path_name][posture_name]
            pos = (data[:, [0, 1]] + np.array((1, 1))) * 0.6
            mag = data[:, [6, 7, 8, 9, 10, 11, 12, 13, 14]]

            pos_mag = np.concatenate((pos, mag), axis=-1)
            posture_data[posture_name].append(pos_mag)

# %%
def split_traj(trajs, length=20):
    sp_traj = []
    for traj in trajs:
        for i in range(len(traj) - length + 1):
            sp_traj.append(traj[i:i+length])
    return np.array(sp_traj)

# %%
prep_training_traj = split_traj(training_traj)
prep_valid_front_pocket_traj = split_traj(posture_data['front_pocket'])
prep_valid_horizontal_traj = split_traj(posture_data['horizontal'])
prep_valid_pocket_traj = split_traj(posture_data['pocket'])
prep_valid_swing_traj = split_traj(posture_data['swing'])
prep_valid_target_traj = split_traj(posture_data['target'])
cali_valid_target_traj = np.load('./baseline_npy/target.npy', allow_pickle=True)
cali_valid_front_pocket_traj = np.load('./baseline_npy/front_pocket.npy', allow_pickle=True)
cali_valid_horizontal_traj = np.load('./baseline_npy/horizontal.npy', allow_pickle=True)
cali_valid_pocket_traj = np.load('./baseline_npy/pocket.npy', allow_pickle=True)
cali_valid_swing_traj = np.load('./baseline_npy/swing.npy', allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 prep_training_traj = split_traj(training_traj)
#       2 prep_valid_front_pocket_traj = split_traj(posture_data['front_pocket'])
#       3 prep_valid_horizontal_traj = split_traj(posture_data['horizontal'])
#
# NameError: name 'split_traj' is not defined

# %%
def expand_seq_features(seq):
    ### neighbors
    s_cord = seq[:, :, 0:2]
    s_mag = seq[:, :, -3:]
    
    s_magT = np.sqrt(np.power(s_mag[:, :, 0:1], 2) + np.power(s_mag[:, :, 1:2], 2) + np.power(s_mag[:, :, 2:3], 2))
    s_magH = np.sqrt(np.power(s_mag[:, :, 0:1], 2) + np.power(s_mag[:, :, 1:2], 2))  # magH
    s_elevation_angle = np.arccos(s_magH / s_magT) / np.pi * 180  # angle
    # n_azimuth_angle = 0
    
    print(s_cord.shape, s_mag.shape, s_magT.shape, s_magH.shape, s_elevation_angle.shape)
    s_new = np.concatenate([s_cord, s_mag, s_magT, s_magH, s_elevation_angle], axis=-1)
    
    return s_new

# %%
cali_valid_target_traj = expand_seq_features(cali_valid_target_traj)
prep_valid_front_pocket_traj = expand_seq_features(prep_valid_front_pocket_traj)
prep_valid_horizontal_traj = expand_seq_features(prep_valid_horizontal_traj)
prep_valid_pocket_traj = expand_seq_features(prep_valid_pocket_traj)
prep_valid_swing_traj = expand_seq_features(prep_valid_swing_traj)
prep_valid_target_traj = expand_seq_features(prep_valid_target_traj)
cali_valid_front_pocket_traj = expand_seq_features(cali_valid_front_pocket_traj)
cali_valid_horizontal_traj = expand_seq_features(cali_valid_horizontal_traj)
cali_valid_pocket_traj = expand_seq_features(cali_valid_pocket_traj)
cali_valid_swing_traj = expand_seq_features(cali_valid_swing_traj)
# Out:
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)

# %%
prep_valid_front_pocket_traj.shape, prep_valid_horizontal_traj.shape, prep_valid_pocket_traj.shape, prep_valid_swing_traj.shape, prep_valid_target_traj.shape
# Out:
# ((674, 20, 8), (674, 20, 8), (674, 20, 8), (674, 20, 8), (674, 20, 8))

# %%
cali_valid_target_traj[(np.arange(cali_valid_target_traj.shape[0])) % 10 != 0, :, 2:].shape
# Out:
# (606, 20, 6)

# %% [markdown]
# ## Create Dataset & Dataloader

# %%
class SequenceDataset(Dataset):
    def __init__(self, sequence, pos):
        self.sequence = sequence
        self.pos = pos

    def __len__(self):
        return len(self.sequence)

    def __getitem__(self, idx):
        return self.sequence[idx], self.pos[idx]

# %%
### train dataloader ###
train_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_target_traj[(np.arange(cali_valid_target_traj.shape[0])) % 10 != 0, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_target_traj[(np.arange(cali_valid_target_traj.shape[0])) % 10 != 0, -1, :2], dtype=torch.float)
                )
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_target_traj[::10, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_target_traj[::10, -1, :2], dtype=torch.float)
                )
test_loader = DataLoader(test_dataset, batch_size=32)


### test dataloader ###
front_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_front_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_front_pocket_traj[:, -1, :2], dtype=torch.float)
                )
front_pocket_loader = DataLoader(front_pocket_dataset, batch_size=32)

horizontal_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_horizontal_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_horizontal_traj[:, -1, :2], dtype=torch.float)
                )
horizontal_loader = DataLoader(horizontal_dataset, batch_size=32)

pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_pocket_traj[:, -1, :2], dtype=torch.float)
                )
pocket_loader = DataLoader(pocket_dataset, batch_size=32)

swing_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_swing_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_swing_traj[:, -1, :2], dtype=torch.float)
                )
swing_loader = DataLoader(swing_dataset, batch_size=32)

target_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_target_traj[::10, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_target_traj[::10, -1, :2], dtype=torch.float)
                )
target_loader = DataLoader(target_dataset, batch_size=32)

c_front_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_front_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_front_pocket_traj[:, -1, :2], dtype=torch.float)
                )
c_front_pocket_loader = DataLoader(c_front_pocket_dataset, batch_size=32)

c_horizontal_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_horizontal_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_horizontal_traj[:, -1, :2], dtype=torch.float)
                )
c_horizontal_loader = DataLoader(c_horizontal_dataset, batch_size=32)

c_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_pocket_traj[:, -1, :2], dtype=torch.float)
                )
c_pocket_loader = DataLoader(c_pocket_dataset, batch_size=32)

c_swing_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_swing_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_swing_traj[:, -1, :2], dtype=torch.float)
                )
c_swing_loader = DataLoader(c_swing_dataset, batch_size=32)

# %% [markdown]
# ## Model

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :].to(x.device)
        return self.dropout(x)
    

class NotSimpleTransformer(nn.Module):
    def __init__(self, seq_len=21, num_of_classes=2):
        super(NotSimpleTransformer, self).__init__()
        
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        
        self.imu_layer = nn.Sequential(
            nn.Linear(6, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 64),
            nn.LeakyReLU(),
        )
        self.mag_layer = nn.Sequential(
            nn.Linear(3, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 64),
            nn.LeakyReLU(),
        )
        self.pos_encoder = PositionalEncoding(64, 0.1)
        
        self.encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        self.nn = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 6),
            nn.LeakyReLU(),
        )
        
        self.decoder = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        
        self.mag_last = nn.Sequential(
            nn.Linear(64, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 3),
        )
        
    def forward(self, source_imu, source_mag):
        
        ### step 1
        h_imu = self.imu_layer(source_imu)
        h_imu = self.pos_encoder(h_imu)
        
        h_mag = self.mag_layer(source_mag)
        h_mag = self.pos_encoder(h_mag)
        
        ### step 2
        z = self.encoder(h_imu)
        z_imu = self.nn(z)
        
        ### step 3
        pred_latent = self.decoder(h_mag, z)
        pred_mag = self.mag_last(pred_latent)
        
        return z_imu, pred_mag

# %%
class Locator(nn.Module):
    def __init__(self, seq_len=60):
        super().__init__()
        
        self.lstm = nn.LSTM(input_size=3, hidden_size=32, num_layers=3, batch_first=True, bidirectional=False)
        
        self.last = nn.Sequential(
            nn.Linear(32, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 8),
            nn.LeakyReLU(),
            nn.Linear(8, 2),
        )
        
    def forward(self, features):
        h, _ = self.lstm(features)
        
        pos = self.last(h[:, -1])
        
        return pos

# %%
def train(dataloader):
    model.train()

    mse_loss = []
    l1_loss = []

    for sequences, gt_pos in dataloader:
        optimizer.zero_grad()
        
        sequences = sequences.to(device)
        gt_pos = gt_pos.to(device)
        
        # localization
        pred_pos = model(sequences[:, :, 2:5])
        
        # loss
        loss = MSE_Loss(pred_pos, gt_pos)
        
        # backward
        loss.backward()
        optimizer.step()
        
        # record loss
        mse_loss.append(loss.item())
        l1_loss.append(L1_loss(pred_pos, gt_pos).item())
    
    return np.mean(mse_loss), np.mean(l1_loss)

# %%
def evaluate(dataloader, calibrate=False):
    model.eval()

    mse_loss = []
    l1_loss = []

    with torch.no_grad():
        for sequences, gt_pos in dataloader:
            optimizer.zero_grad()
            
            sequences = sequences.to(device)
            gt_pos = gt_pos.to(device)

            # localization
            pred_pos = model(sequences[:, :, 2:5])

            # loss
            loss = MSE_Loss(pred_pos, gt_pos)

            # record loss
            mse_loss.append(loss.item())
            l1_loss.append(L1_loss(pred_pos, gt_pos).item())
    
    return np.mean(mse_loss), np.mean(l1_loss)

# %%
EPOCH = 10000
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
MSE_Loss = torch.nn.MSELoss()
L1_loss = torch.nn.L1Loss()

# %%
model = Locator().to(device)
# calibration = NotSimpleTransformer().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
from torchinfo import summary
summary(model, input_size=[(1, 20, 3)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Locator                                  [1, 2]                    --
# ├─LSTM: 1-1                              [1, 20, 32]               21,632
# ├─Sequential: 1-2                        [1, 2]                    --
# │    └─Linear: 2-1                       [1, 16]                   528
# │    └─LeakyReLU: 2-2                    [1, 16]                   --
# │    └─Linear: 2-3                       [1, 8]                    136
# │    └─LeakyReLU: 2-4                    [1, 8]                    --
# │    └─Linear: 2-5                       [1, 2]                    18
# ==========================================================================================
# Total params: 22,314
# Trainable params: 22,314
# Non-trainable params: 0
# Total mult-adds (M): 0.43
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ==========================================================================================

# %%
pos=['train', 'valid', 'front pocket', 'horizontal', 'pocket', 'swing']
for epoch in range(EPOCH):
    
    train_loss, train_l1 = train(train_loader)
#     train_loss, train_l1 = train(target_loader)
    
    if (epoch + 1) % 100 == 0:
        ep = str(epoch + 1).zfill(5)
        front_pocket_loss, front_pocket_l1 = evaluate(front_pocket_loader)
        horizontal_loss, horizontal_l1 = evaluate(horizontal_loader)
        pocket_loss, pocket_l1 = evaluate(pocket_loader)
        swing_loss, swing_l1 = evaluate(swing_loader)
        c_front_pocket_loss, c_front_pocket_l1 = evaluate(c_front_pocket_loader)
        c_horizontal_loss, c_horizontal_l1 = evaluate(c_horizontal_loader)
        c_pocket_loss, c_pocket_l1 = evaluate(c_pocket_loader)
        c_swing_loss, c_swing_l1 = evaluate(c_swing_loader)
        target_loss, target_l1 = evaluate(test_loader)
        print(f'{ep:>5}:   {pos[0]:>13} mse loss: {train_loss:>6.3f}, l1 loss: {train_l1:>6.3f}\t      valid mse loss: {target_loss:>6.3f}, l1 loss: {target_l1:>6.3f}')
        print(f'         {pos[2]:>13} mse loss: {front_pocket_loss:>6.3f}, l1 loss: {front_pocket_l1:>6.3f}\t calibrated mse loss: {c_front_pocket_loss:>6.3f}, l1 loss: {c_front_pocket_l1:>6.3f}')
        print(f'         {pos[3]:>13} mse loss: {horizontal_loss:>6.3f}, l1 loss: {horizontal_l1:>6.3f}\t calibrated mse loss: {c_horizontal_loss:>6.3f}, l1 loss: {c_horizontal_l1:>6.3f}')
        print(f'         {pos[4]:>13} mse loss: {pocket_loss:>6.3f}, l1 loss: {pocket_l1:>6.3f}\t calibrated mse loss: {c_pocket_loss:>6.3f}, l1 loss: {c_pocket_l1:>6.3f}')
        print(f'         {pos[5]:>13} mse loss: {swing_loss:>6.3f}, l1 loss: {swing_l1:>6.3f}\t calibrated mse loss: {c_swing_loss:>6.3f}, l1 loss: {c_swing_l1:>6.3f}')
#         print(f'{ep:>5}:  train mse loss: {train_loss: >6.3f}, l1 loss: {train_l1: >6.3f}     horizontal mse loss: {horizontal_loss: >6.3f}, l1 loss: {horizontal_l1: >6.3f}')  
#         print(f'        swing mse loss: {swing_loss: >6.3f}, l1 loss: {swing_l1: >6.3f}   front_pocket mse loss: {front_pocket_loss: >6.3f}, l1 loss: {front_pocket_l1: >6.3f}')
#         print(f'       pocket mse loss: {pocket_loss: >6.3f}, l1 loss: {pocket_l1: >6.3f}         target mse loss: {target_loss: >6.3f}, l1 loss: {target_l1: >6.3f}')
# Out:
# 00100:           train mse loss: 18.326, l1 loss:  3.633	      valid mse loss: 16.464, l1 loss:  3.484
#           front pocket mse loss: 18.980, l1 loss:  3.722	 calibrated mse loss: 18.972, l1 loss:  3.722
#             horizontal mse loss: 18.960, l1 loss:  3.721	 calibrated mse loss: 18.957, l1 loss:  3.720
#                 pocket mse loss: 18.974, l1 loss:  3.722	 calibrated mse loss: 18.971, l1 loss:  3.721
#                  swing mse loss: 18.970, l1 loss:  3.721	 calibrated mse loss: 18.965, l1 loss:  3.721
# 00200:           train mse loss:  8.856, l1 loss:  2.395	      valid mse loss:  9.262, l1 loss:  2.427
#           front pocket mse loss: 19.646, l1 loss:  3.591	 calibrated mse loss: 20.127, l1 loss:  3.629
#             horizontal mse loss: 16.905, l1 loss:  3.371	 calibrated mse loss: 15.338, l1 loss:  3.233
#                 pocket mse loss: 21.135, l1 loss:  3.670	 calibrated mse loss: 20.368, l1 loss:  3.603
#                  swing mse loss: 19.155, l1 loss:  3.677	 calibrated mse loss: 20.589, l1 loss:  3.826
# 00300:           train mse loss:  6.013, l1 loss:  1.955	      valid mse loss:  6.467, l1 loss:  2.010
#           front pocket mse loss: 47.562, l1 loss:  5.047	 calibrated mse loss: 44.099, l1 loss:  4.801
#             horizontal mse loss: 16.205, l1 loss:  3.362	 calibrated mse loss: 14.864, l1 loss:  3.220
#                 pocket mse loss: 52.663, l1 loss:  5.641	 calibrated mse loss: 49.389, l1 loss:  5.441
#                  swing mse loss: 30.991, l1 loss:  4.479	 calibrated mse loss: 37.967, l1 loss:  4.978
# 00400:           train mse loss:  3.506, l1 loss:  1.464	      valid mse loss:  4.702, l1 loss:  1.674
#           front pocket mse loss: 64.402, l1 loss:  6.112	 calibrated mse loss: 63.661, l1 loss:  6.005
#             horizontal mse loss: 18.633, l1 loss:  3.533	 calibrated mse loss: 17.135, l1 loss:  3.432
#                 pocket mse loss: 73.117, l1 loss:  6.909	 calibrated mse loss: 70.716, l1 loss:  6.834
#                  swing mse loss: 55.946, l1 loss:  6.181	 calibrated mse loss: 59.390, l1 loss:  6.287
# 00500:           train mse loss:  1.575, l1 loss:  0.899	      valid mse loss:  2.389, l1 loss:  1.100
#           front pocket mse loss: 59.986, l1 loss:  5.906	 calibrated mse loss: 58.477, l1 loss:  5.805
#             horizontal mse loss: 21.725, l1 loss:  3.689	 calibrated mse loss: 20.231, l1 loss:  3.625
#                 pocket mse loss: 71.003, l1 loss:  6.847	 calibrated mse loss: 67.495, l1 loss:  6.666
#                  swing mse loss: 53.866, l1 loss:  6.068	 calibrated mse loss: 55.935, l1 loss:  6.112
# 00600:           train mse loss:  1.228, l1 loss:  0.768	      valid mse loss:  1.883, l1 loss:  0.977
#           front pocket mse loss: 57.662, l1 loss:  5.763	 calibrated mse loss: 54.965, l1 loss:  5.630
#             horizontal mse loss: 22.012, l1 loss:  3.750	 calibrated mse loss: 20.807, l1 loss:  3.682
#                 pocket mse loss: 69.121, l1 loss:  6.826	 calibrated mse loss: 65.723, l1 loss:  6.671
#                  swing mse loss: 49.413, l1 loss:  5.819	 calibrated mse loss: 49.942, l1 loss:  5.765
# 00700:           train mse loss:  0.922, l1 loss:  0.656	      valid mse loss:  1.178, l1 loss:  0.777
#           front pocket mse loss: 58.050, l1 loss:  5.824	 calibrated mse loss: 56.786, l1 loss:  5.709
#             horizontal mse loss: 21.845, l1 loss:  3.734	 calibrated mse loss: 20.333, l1 loss:  3.634
#                 pocket mse loss: 70.678, l1 loss:  6.905	 calibrated mse loss: 67.656, l1 loss:  6.759
#                  swing mse loss: 47.489, l1 loss:  5.747	 calibrated mse loss: 48.917, l1 loss:  5.704
# 00800:           train mse loss:  0.684, l1 loss:  0.573	      valid mse loss:  0.758, l1 loss:  0.640
#           front pocket mse loss: 50.216, l1 loss:  5.482	 calibrated mse loss: 50.755, l1 loss:  5.481
#             horizontal mse loss: 22.031, l1 loss:  3.727	 calibrated mse loss: 20.531, l1 loss:  3.662
#                 pocket mse loss: 62.622, l1 loss:  6.546	 calibrated mse loss: 60.237, l1 loss:  6.401
#                  swing mse loss: 42.889, l1 loss:  5.494	 calibrated mse loss: 44.686, l1 loss:  5.464
# 00900:           train mse loss:  0.565, l1 loss:  0.525	      valid mse loss:  0.827, l1 loss:  0.595
#           front pocket mse loss: 48.034, l1 loss:  5.371	 calibrated mse loss: 48.103, l1 loss:  5.350
#             horizontal mse loss: 23.310, l1 loss:  3.840	 calibrated mse loss: 21.470, l1 loss:  3.758
#                 pocket mse loss: 60.719, l1 loss:  6.457	 calibrated mse loss: 58.062, l1 loss:  6.330
#                  swing mse loss: 42.510, l1 loss:  5.480	 calibrated mse loss: 44.224, l1 loss:  5.453
# 01000:           train mse loss:  0.362, l1 loss:  0.435	      valid mse loss:  0.615, l1 loss:  0.497
#           front pocket mse loss: 48.295, l1 loss:  5.407	 calibrated mse loss: 47.365, l1 loss:  5.323
#             horizontal mse loss: 23.283, l1 loss:  3.824	 calibrated mse loss: 21.533, l1 loss:  3.755
#                 pocket mse loss: 60.579, l1 loss:  6.466	 calibrated mse loss: 57.586, l1 loss:  6.324
#                  swing mse loss: 42.260, l1 loss:  5.461	 calibrated mse loss: 43.954, l1 loss:  5.449
# 01100:           train mse loss:  0.265, l1 loss:  0.371	      valid mse loss:  0.738, l1 loss:  0.501
#           front pocket mse loss: 48.839, l1 loss:  5.436	 calibrated mse loss: 47.413, l1 loss:  5.327
#             horizontal mse loss: 22.735, l1 loss:  3.776	 calibrated mse loss: 21.502, l1 loss:  3.766
#                 pocket mse loss: 61.106, l1 loss:  6.488	 calibrated mse loss: 57.311, l1 loss:  6.285
#                  swing mse loss: 42.165, l1 loss:  5.428	 calibrated mse loss: 43.999, l1 loss:  5.459
# 01200:           train mse loss:  0.270, l1 loss:  0.381	      valid mse loss:  0.777, l1 loss:  0.540
#           front pocket mse loss: 50.030, l1 loss:  5.504	 calibrated mse loss: 47.594, l1 loss:  5.346
#             horizontal mse loss: 22.046, l1 loss:  3.697	 calibrated mse loss: 21.191, l1 loss:  3.717
#                 pocket mse loss: 61.877, l1 loss:  6.510	 calibrated mse loss: 57.783, l1 loss:  6.293
#                  swing mse loss: 42.061, l1 loss:  5.397	 calibrated mse loss: 44.079, l1 loss:  5.471
# 01300:           train mse loss:  0.265, l1 loss:  0.380	      valid mse loss:  0.633, l1 loss:  0.439
#           front pocket mse loss: 51.958, l1 loss:  5.595	 calibrated mse loss: 49.546, l1 loss:  5.457
#             horizontal mse loss: 22.521, l1 loss:  3.723	 calibrated mse loss: 21.549, l1 loss:  3.763
#                 pocket mse loss: 64.169, l1 loss:  6.607	 calibrated mse loss: 60.057, l1 loss:  6.372
#                  swing mse loss: 43.087, l1 loss:  5.466	 calibrated mse loss: 44.803, l1 loss:  5.509
# 01400:           train mse loss:  0.118, l1 loss:  0.250	      valid mse loss:  0.560, l1 loss:  0.426
#           front pocket mse loss: 53.373, l1 loss:  5.678	 calibrated mse loss: 50.536, l1 loss:  5.514
#             horizontal mse loss: 22.535, l1 loss:  3.719	 calibrated mse loss: 21.745, l1 loss:  3.765
#                 pocket mse loss: 64.805, l1 loss:  6.616	 calibrated mse loss: 59.666, l1 loss:  6.330
#                  swing mse loss: 42.713, l1 loss:  5.428	 calibrated mse loss: 44.401, l1 loss:  5.478
# 01500:           train mse loss:  0.123, l1 loss:  0.256	      valid mse loss:  0.426, l1 loss:  0.389
#           front pocket mse loss: 55.992, l1 loss:  5.800	 calibrated mse loss: 53.366, l1 loss:  5.651
#             horizontal mse loss: 22.756, l1 loss:  3.731	 calibrated mse loss: 22.167, l1 loss:  3.795
#                 pocket mse loss: 66.207, l1 loss:  6.681	 calibrated mse loss: 60.939, l1 loss:  6.374
#                  swing mse loss: 42.949, l1 loss:  5.439	 calibrated mse loss: 44.704, l1 loss:  5.493
# 01600:           train mse loss:  0.086, l1 loss:  0.216	      valid mse loss:  0.306, l1 loss:  0.349
#           front pocket mse loss: 58.259, l1 loss:  5.902	 calibrated mse loss: 54.756, l1 loss:  5.710
#             horizontal mse loss: 22.968, l1 loss:  3.744	 calibrated mse loss: 22.297, l1 loss:  3.793
#                 pocket mse loss: 67.941, l1 loss:  6.758	 calibrated mse loss: 62.560, l1 loss:  6.441
#                  swing mse loss: 43.771, l1 loss:  5.479	 calibrated mse loss: 45.658, l1 loss:  5.560
# 01700:           train mse loss:  0.120, l1 loss:  0.261	      valid mse loss:  0.387, l1 loss:  0.435
#           front pocket mse loss: 60.147, l1 loss:  5.999	 calibrated mse loss: 56.576, l1 loss:  5.795
#             horizontal mse loss: 22.106, l1 loss:  3.664	 calibrated mse loss: 21.632, l1 loss:  3.732
#                 pocket mse loss: 70.162, l1 loss:  6.871	 calibrated mse loss: 64.893, l1 loss:  6.571
#                  swing mse loss: 44.131, l1 loss:  5.510	 calibrated mse loss: 46.339, l1 loss:  5.609
# 01800:           train mse loss:  0.071, l1 loss:  0.195	      valid mse loss:  0.297, l1 loss:  0.358
#           front pocket mse loss: 63.391, l1 loss:  6.158	 calibrated mse loss: 59.934, l1 loss:  5.953
#             horizontal mse loss: 22.656, l1 loss:  3.706	 calibrated mse loss: 22.303, l1 loss:  3.778
#                 pocket mse loss: 75.543, l1 loss:  7.140	 calibrated mse loss: 70.005, l1 loss:  6.850
#                  swing mse loss: 46.638, l1 loss:  5.693	 calibrated mse loss: 49.097, l1 loss:  5.789
# 01900:           train mse loss:  0.074, l1 loss:  0.203	      valid mse loss:  0.364, l1 loss:  0.388
#           front pocket mse loss: 64.880, l1 loss:  6.249	 calibrated mse loss: 61.834, l1 loss:  6.060
#             horizontal mse loss: 21.931, l1 loss:  3.641	 calibrated mse loss: 21.452, l1 loss:  3.697
#                 pocket mse loss: 77.864, l1 loss:  7.267	 calibrated mse loss: 71.859, l1 loss:  6.974
#                  swing mse loss: 48.371, l1 loss:  5.812	 calibrated mse loss: 50.699, l1 loss:  5.894
# 02000:           train mse loss:  0.050, l1 loss:  0.169	      valid mse loss:  0.271, l1 loss:  0.329
#           front pocket mse loss: 65.428, l1 loss:  6.285	 calibrated mse loss: 62.300, l1 loss:  6.088
#             horizontal mse loss: 22.457, l1 loss:  3.698	 calibrated mse loss: 22.037, l1 loss:  3.753
#                 pocket mse loss: 78.385, l1 loss:  7.282	 calibrated mse loss: 72.252, l1 loss:  6.988
#                  swing mse loss: 49.202, l1 loss:  5.871	 calibrated mse loss: 51.117, l1 loss:  5.914
# 02100:           train mse loss:  0.044, l1 loss:  0.156	      valid mse loss:  0.275, l1 loss:  0.322
#           front pocket mse loss: 66.797, l1 loss:  6.367	 calibrated mse loss: 63.621, l1 loss:  6.164
#             horizontal mse loss: 22.160, l1 loss:  3.675	 calibrated mse loss: 21.848, l1 loss:  3.738
#                 pocket mse loss: 79.778, l1 loss:  7.358	 calibrated mse loss: 73.667, l1 loss:  7.069
#                  swing mse loss: 51.018, l1 loss:  5.982	 calibrated mse loss: 52.246, l1 loss:  5.983
# 02200:           train mse loss:  0.047, l1 loss:  0.161	      valid mse loss:  0.263, l1 loss:  0.328
#           front pocket mse loss: 66.828, l1 loss:  6.370	 calibrated mse loss: 63.406, l1 loss:  6.159
#             horizontal mse loss: 22.476, l1 loss:  3.705	 calibrated mse loss: 21.999, l1 loss:  3.755
#                 pocket mse loss: 79.432, l1 loss:  7.339	 calibrated mse loss: 73.251, l1 loss:  7.051
#                  swing mse loss: 51.088, l1 loss:  5.986	 calibrated mse loss: 52.289, l1 loss:  5.984
# 02300:           train mse loss:  0.100, l1 loss:  0.241	      valid mse loss:  0.424, l1 loss:  0.455
#           front pocket mse loss: 66.853, l1 loss:  6.376	 calibrated mse loss: 63.396, l1 loss:  6.161
#             horizontal mse loss: 21.129, l1 loss:  3.567	 calibrated mse loss: 21.239, l1 loss:  3.674
#                 pocket mse loss: 79.339, l1 loss:  7.331	 calibrated mse loss: 73.146, l1 loss:  7.047
#                  swing mse loss: 50.755, l1 loss:  5.948	 calibrated mse loss: 51.762, l1 loss:  5.938
# 02400:           train mse loss:  0.029, l1 loss:  0.126	      valid mse loss:  0.259, l1 loss:  0.306
#           front pocket mse loss: 67.083, l1 loss:  6.389	 calibrated mse loss: 63.513, l1 loss:  6.172
#             horizontal mse loss: 21.997, l1 loss:  3.657	 calibrated mse loss: 21.772, l1 loss:  3.727
#                 pocket mse loss: 79.575, l1 loss:  7.348	 calibrated mse loss: 73.271, l1 loss:  7.050
#                  swing mse loss: 51.840, l1 loss:  6.027	 calibrated mse loss: 52.444, l1 loss:  5.998
# 02500:           train mse loss:  0.044, l1 loss:  0.157	      valid mse loss:  0.301, l1 loss:  0.326
#           front pocket mse loss: 67.052, l1 loss:  6.384	 calibrated mse loss: 63.345, l1 loss:  6.162
#             horizontal mse loss: 22.373, l1 loss:  3.695	 calibrated mse loss: 22.220, l1 loss:  3.765
#                 pocket mse loss: 79.456, l1 loss:  7.343	 calibrated mse loss: 73.171, l1 loss:  7.048
#                  swing mse loss: 52.190, l1 loss:  6.047	 calibrated mse loss: 52.463, l1 loss:  6.003
# 02600:           train mse loss:  0.033, l1 loss:  0.136	      valid mse loss:  0.257, l1 loss:  0.319
#           front pocket mse loss: 67.209, l1 loss:  6.408	 calibrated mse loss: 63.499, l1 loss:  6.187
#             horizontal mse loss: 22.120, l1 loss:  3.671	 calibrated mse loss: 21.866, l1 loss:  3.738
#                 pocket mse loss: 79.611, l1 loss:  7.358	 calibrated mse loss: 73.307, l1 loss:  7.061
#                  swing mse loss: 52.706, l1 loss:  6.073	 calibrated mse loss: 52.655, l1 loss:  6.014
# 02700:           train mse loss:  0.043, l1 loss:  0.155	      valid mse loss:  0.257, l1 loss:  0.292
#           front pocket mse loss: 67.402, l1 loss:  6.423	 calibrated mse loss: 63.546, l1 loss:  6.188
#             horizontal mse loss: 21.930, l1 loss:  3.658	 calibrated mse loss: 21.793, l1 loss:  3.734
#                 pocket mse loss: 79.730, l1 loss:  7.369	 calibrated mse loss: 73.420, l1 loss:  7.068
#                  swing mse loss: 53.028, l1 loss:  6.096	 calibrated mse loss: 52.616, l1 loss:  6.018
# 02800:           train mse loss:  0.026, l1 loss:  0.120	      valid mse loss:  0.274, l1 loss:  0.308
#           front pocket mse loss: 67.523, l1 loss:  6.431	 calibrated mse loss: 63.624, l1 loss:  6.196
#             horizontal mse loss: 21.576, l1 loss:  3.619	 calibrated mse loss: 21.528, l1 loss:  3.707
#                 pocket mse loss: 79.707, l1 loss:  7.367	 calibrated mse loss: 73.391, l1 loss:  7.065
#                  swing mse loss: 53.217, l1 loss:  6.096	 calibrated mse loss: 52.554, l1 loss:  6.009
# 02900:           train mse loss:  0.042, l1 loss:  0.157	      valid mse loss:  0.276, l1 loss:  0.315
#           front pocket mse loss: 66.669, l1 loss:  6.383	 calibrated mse loss: 62.719, l1 loss:  6.142
#             horizontal mse loss: 21.393, l1 loss:  3.607	 calibrated mse loss: 21.220, l1 loss:  3.675
#                 pocket mse loss: 78.914, l1 loss:  7.324	 calibrated mse loss: 72.501, l1 loss:  7.013
#                  swing mse loss: 52.528, l1 loss:  6.048	 calibrated mse loss: 51.745, l1 loss:  5.955
# 03000:           train mse loss:  0.023, l1 loss:  0.116	      valid mse loss:  0.288, l1 loss:  0.309
#           front pocket mse loss: 67.187, l1 loss:  6.427	 calibrated mse loss: 63.328, l1 loss:  6.191
#             horizontal mse loss: 21.342, l1 loss:  3.598	 calibrated mse loss: 21.337, l1 loss:  3.685
#                 pocket mse loss: 79.622, l1 loss:  7.372	 calibrated mse loss: 73.261, l1 loss:  7.070
#                  swing mse loss: 53.367, l1 loss:  6.104	 calibrated mse loss: 52.247, l1 loss:  5.998
# 03100:           train mse loss:  0.040, l1 loss:  0.151	      valid mse loss:  0.291, l1 loss:  0.312
#           front pocket mse loss: 66.798, l1 loss:  6.401	 calibrated mse loss: 62.932, l1 loss:  6.167
#             horizontal mse loss: 21.673, l1 loss:  3.636	 calibrated mse loss: 21.729, l1 loss:  3.719
#                 pocket mse loss: 79.228, l1 loss:  7.348	 calibrated mse loss: 72.765, l1 loss:  7.030
#                  swing mse loss: 53.238, l1 loss:  6.095	 calibrated mse loss: 52.052, l1 loss:  5.986
# 03200:           train mse loss:  0.022, l1 loss:  0.113	      valid mse loss:  0.262, l1 loss:  0.296
#           front pocket mse loss: 67.064, l1 loss:  6.427	 calibrated mse loss: 63.231, l1 loss:  6.192
#             horizontal mse loss: 21.406, l1 loss:  3.620	 calibrated mse loss: 21.375, l1 loss:  3.696
#                 pocket mse loss: 79.602, l1 loss:  7.374	 calibrated mse loss: 73.331, l1 loss:  7.073
#                  swing mse loss: 53.792, l1 loss:  6.132	 calibrated mse loss: 52.132, l1 loss:  5.990
# 03300:           train mse loss:  0.021, l1 loss:  0.109	      valid mse loss:  0.217, l1 loss:  0.295
#           front pocket mse loss: 66.440, l1 loss:  6.394	 calibrated mse loss: 62.549, l1 loss:  6.159
#             horizontal mse loss: 21.128, l1 loss:  3.592	 calibrated mse loss: 21.187, l1 loss:  3.681
#                 pocket mse loss: 78.850, l1 loss:  7.335	 calibrated mse loss: 72.533, l1 loss:  7.026
#                  swing mse loss: 53.056, l1 loss:  6.079	 calibrated mse loss: 51.572, l1 loss:  5.951
# 03400:           train mse loss:  0.025, l1 loss:  0.119	      valid mse loss:  0.290, l1 loss:  0.300
#           front pocket mse loss: 66.577, l1 loss:  6.406	 calibrated mse loss: 62.697, l1 loss:  6.164
#             horizontal mse loss: 21.209, l1 loss:  3.600	 calibrated mse loss: 21.403, l1 loss:  3.702
#                 pocket mse loss: 79.183, l1 loss:  7.355	 calibrated mse loss: 72.940, l1 loss:  7.056
#                  swing mse loss: 53.462, l1 loss:  6.105	 calibrated mse loss: 51.845, l1 loss:  5.975
# 03500:           train mse loss:  0.016, l1 loss:  0.097	      valid mse loss:  0.275, l1 loss:  0.293
#           front pocket mse loss: 66.486, l1 loss:  6.406	 calibrated mse loss: 62.635, l1 loss:  6.169
#             horizontal mse loss: 21.081, l1 loss:  3.579	 calibrated mse loss: 21.275, l1 loss:  3.687
#                 pocket mse loss: 79.056, l1 loss:  7.355	 calibrated mse loss: 72.895, l1 loss:  7.060
#                  swing mse loss: 53.437, l1 loss:  6.107	 calibrated mse loss: 51.634, l1 loss:  5.967
# 03600:           train mse loss:  0.028, l1 loss:  0.126	      valid mse loss:  0.260, l1 loss:  0.288
#           front pocket mse loss: 66.251, l1 loss:  6.397	 calibrated mse loss: 62.416, l1 loss:  6.164
#             horizontal mse loss: 21.348, l1 loss:  3.626	 calibrated mse loss: 21.508, l1 loss:  3.713
#                 pocket mse loss: 78.861, l1 loss:  7.347	 calibrated mse loss: 72.666, l1 loss:  7.049
#                  swing mse loss: 53.651, l1 loss:  6.125	 calibrated mse loss: 51.752, l1 loss:  5.979
# 03700:           train mse loss:  0.025, l1 loss:  0.117	      valid mse loss:  0.274, l1 loss:  0.314
#           front pocket mse loss: 65.817, l1 loss:  6.372	 calibrated mse loss: 62.057, l1 loss:  6.140
#             horizontal mse loss: 21.160, l1 loss:  3.602	 calibrated mse loss: 21.347, l1 loss:  3.701
#                 pocket mse loss: 78.370, l1 loss:  7.318	 calibrated mse loss: 72.153, l1 loss:  7.014
#                  swing mse loss: 53.033, l1 loss:  6.080	 calibrated mse loss: 51.265, l1 loss:  5.945
# 03800:           train mse loss:  0.034, l1 loss:  0.138	      valid mse loss:  0.296, l1 loss:  0.327
#           front pocket mse loss: 65.625, l1 loss:  6.364	 calibrated mse loss: 61.710, l1 loss:  6.124
#             horizontal mse loss: 21.331, l1 loss:  3.609	 calibrated mse loss: 21.895, l1 loss:  3.742
#                 pocket mse loss: 78.197, l1 loss:  7.317	 calibrated mse loss: 71.918, l1 loss:  7.012
#                  swing mse loss: 52.962, l1 loss:  6.082	 calibrated mse loss: 50.830, l1 loss:  5.927
# 03900:           train mse loss:  0.016, l1 loss:  0.094	      valid mse loss:  0.247, l1 loss:  0.280
#           front pocket mse loss: 65.577, l1 loss:  6.380	 calibrated mse loss: 61.644, l1 loss:  6.131
#             horizontal mse loss: 21.310, l1 loss:  3.615	 calibrated mse loss: 21.405, l1 loss:  3.699
#                 pocket mse loss: 78.054, l1 loss:  7.316	 calibrated mse loss: 72.085, l1 loss:  7.028
#                  swing mse loss: 53.079, l1 loss:  6.088	 calibrated mse loss: 50.973, l1 loss:  5.939
# 04000:           train mse loss:  0.014, l1 loss:  0.090	      valid mse loss:  0.264, l1 loss:  0.293
#           front pocket mse loss: 65.284, l1 loss:  6.364	 calibrated mse loss: 61.416, l1 loss:  6.119
#             horizontal mse loss: 21.133, l1 loss:  3.597	 calibrated mse loss: 21.405, l1 loss:  3.698
#                 pocket mse loss: 77.787, l1 loss:  7.304	 calibrated mse loss: 71.859, l1 loss:  7.015
#                  swing mse loss: 52.803, l1 loss:  6.071	 calibrated mse loss: 50.651, l1 loss:  5.917
# 04100:           train mse loss:  0.017, l1 loss:  0.097	      valid mse loss:  0.242, l1 loss:  0.278
#           front pocket mse loss: 64.980, l1 loss:  6.352	 calibrated mse loss: 61.101, l1 loss:  6.111
#             horizontal mse loss: 21.416, l1 loss:  3.635	 calibrated mse loss: 21.570, l1 loss:  3.717
#                 pocket mse loss: 77.489, l1 loss:  7.288	 calibrated mse loss: 71.490, l1 loss:  6.998
#                  swing mse loss: 52.725, l1 loss:  6.072	 calibrated mse loss: 50.702, l1 loss:  5.926
# 04200:           train mse loss:  0.016, l1 loss:  0.096	      valid mse loss:  0.279, l1 loss:  0.273
#           front pocket mse loss: 64.706, l1 loss:  6.336	 calibrated mse loss: 60.859, l1 loss:  6.088
#             horizontal mse loss: 21.324, l1 loss:  3.621	 calibrated mse loss: 21.416, l1 loss:  3.697
#                 pocket mse loss: 77.168, l1 loss:  7.274	 calibrated mse loss: 71.187, l1 loss:  6.984
#                  swing mse loss: 52.493, l1 loss:  6.055	 calibrated mse loss: 50.468, l1 loss:  5.915
# 04300:           train mse loss:  0.014, l1 loss:  0.090	      valid mse loss:  0.277, l1 loss:  0.289
#           front pocket mse loss: 64.547, l1 loss:  6.333	 calibrated mse loss: 60.824, l1 loss:  6.094
#             horizontal mse loss: 20.978, l1 loss:  3.597	 calibrated mse loss: 21.307, l1 loss:  3.695
#                 pocket mse loss: 77.025, l1 loss:  7.267	 calibrated mse loss: 71.115, l1 loss:  6.982
#                  swing mse loss: 52.267, l1 loss:  6.037	 calibrated mse loss: 50.330, l1 loss:  5.905
# 04400:           train mse loss:  0.018, l1 loss:  0.101	      valid mse loss:  0.300, l1 loss:  0.293
#           front pocket mse loss: 64.075, l1 loss:  6.315	 calibrated mse loss: 60.372, l1 loss:  6.070
#             horizontal mse loss: 20.925, l1 loss:  3.583	 calibrated mse loss: 21.182, l1 loss:  3.678
#                 pocket mse loss: 76.533, l1 loss:  7.249	 calibrated mse loss: 70.777, l1 loss:  6.966
#                  swing mse loss: 51.848, l1 loss:  6.014	 calibrated mse loss: 50.031, l1 loss:  5.893
# 04500:           train mse loss:  0.029, l1 loss:  0.127	      valid mse loss:  0.306, l1 loss:  0.312
#           front pocket mse loss: 63.105, l1 loss:  6.255	 calibrated mse loss: 59.289, l1 loss:  6.004
#             horizontal mse loss: 21.189, l1 loss:  3.612	 calibrated mse loss: 21.607, l1 loss:  3.719
#                 pocket mse loss: 75.602, l1 loss:  7.193	 calibrated mse loss: 69.529, l1 loss:  6.889
#                  swing mse loss: 50.782, l1 loss:  5.954	 calibrated mse loss: 49.125, l1 loss:  5.832
# 04600:           train mse loss:  0.014, l1 loss:  0.089	      valid mse loss:  0.273, l1 loss:  0.277
#           front pocket mse loss: 63.273, l1 loss:  6.278	 calibrated mse loss: 59.486, l1 loss:  6.022
#             horizontal mse loss: 21.255, l1 loss:  3.617	 calibrated mse loss: 21.680, l1 loss:  3.724
#                 pocket mse loss: 75.605, l1 loss:  7.202	 calibrated mse loss: 69.850, l1 loss:  6.918
#                  swing mse loss: 51.238, l1 loss:  5.978	 calibrated mse loss: 49.630, l1 loss:  5.874
# 04700:           train mse loss:  0.009, l1 loss:  0.074	      valid mse loss:  0.258, l1 loss:  0.263
#           front pocket mse loss: 63.219, l1 loss:  6.279	 calibrated mse loss: 59.463, l1 loss:  6.026
#             horizontal mse loss: 20.960, l1 loss:  3.590	 calibrated mse loss: 21.329, l1 loss:  3.690
#                 pocket mse loss: 75.461, l1 loss:  7.192	 calibrated mse loss: 69.877, l1 loss:  6.920
#                  swing mse loss: 51.057, l1 loss:  5.966	 calibrated mse loss: 49.468, l1 loss:  5.863
# 04800:           train mse loss:  0.011, l1 loss:  0.078	      valid mse loss:  0.313, l1 loss:  0.280
#           front pocket mse loss: 62.852, l1 loss:  6.266	 calibrated mse loss: 59.032, l1 loss:  6.004
#             horizontal mse loss: 20.848, l1 loss:  3.579	 calibrated mse loss: 21.343, l1 loss:  3.691
#                 pocket mse loss: 75.081, l1 loss:  7.177	 calibrated mse loss: 69.501, l1 loss:  6.903
#                  swing mse loss: 50.575, l1 loss:  5.941	 calibrated mse loss: 49.040, l1 loss:  5.840
# 04900:           train mse loss:  0.021, l1 loss:  0.108	      valid mse loss:  0.277, l1 loss:  0.313
#           front pocket mse loss: 62.585, l1 loss:  6.257	 calibrated mse loss: 58.788, l1 loss:  5.998
#             horizontal mse loss: 20.596, l1 loss:  3.549	 calibrated mse loss: 21.020, l1 loss:  3.663
#                 pocket mse loss: 74.596, l1 loss:  7.160	 calibrated mse loss: 69.141, l1 loss:  6.888
#                  swing mse loss: 49.971, l1 loss:  5.892	 calibrated mse loss: 48.693, l1 loss:  5.818
# 05000:           train mse loss:  0.031, l1 loss:  0.135	      valid mse loss:  0.210, l1 loss:  0.294
#           front pocket mse loss: 61.778, l1 loss:  6.208	 calibrated mse loss: 57.994, l1 loss:  5.954
#             horizontal mse loss: 21.007, l1 loss:  3.611	 calibrated mse loss: 21.473, l1 loss:  3.697
#                 pocket mse loss: 73.681, l1 loss:  7.103	 calibrated mse loss: 68.120, l1 loss:  6.833
#                  swing mse loss: 49.331, l1 loss:  5.848	 calibrated mse loss: 48.203, l1 loss:  5.783
# 05100:           train mse loss:  0.008, l1 loss:  0.066	      valid mse loss:  0.222, l1 loss:  0.246
#           front pocket mse loss: 60.613, l1 loss:  6.151	 calibrated mse loss: 56.707, l1 loss:  5.882
#             horizontal mse loss: 20.797, l1 loss:  3.579	 calibrated mse loss: 21.327, l1 loss:  3.692
#                 pocket mse loss: 72.313, l1 loss:  7.036	 calibrated mse loss: 66.983, l1 loss:  6.782
#                  swing mse loss: 48.582, l1 loss:  5.807	 calibrated mse loss: 47.418, l1 loss:  5.735
# 05200:           train mse loss:  0.007, l1 loss:  0.066	      valid mse loss:  0.255, l1 loss:  0.258
#           front pocket mse loss: 61.061, l1 loss:  6.177	 calibrated mse loss: 57.002, l1 loss:  5.895
#             horizontal mse loss: 20.823, l1 loss:  3.581	 calibrated mse loss: 21.308, l1 loss:  3.690
#                 pocket mse loss: 72.726, l1 loss:  7.062	 calibrated mse loss: 67.254, l1 loss:  6.795
#                  swing mse loss: 48.742, l1 loss:  5.815	 calibrated mse loss: 47.634, l1 loss:  5.755
# 05300:           train mse loss:  0.007, l1 loss:  0.064	      valid mse loss:  0.245, l1 loss:  0.260
#           front pocket mse loss: 60.765, l1 loss:  6.164	 calibrated mse loss: 56.669, l1 loss:  5.877
#             horizontal mse loss: 21.032, l1 loss:  3.606	 calibrated mse loss: 21.521, l1 loss:  3.708
#                 pocket mse loss: 72.393, l1 loss:  7.046	 calibrated mse loss: 67.103, l1 loss:  6.790
#                  swing mse loss: 48.591, l1 loss:  5.807	 calibrated mse loss: 47.506, l1 loss:  5.748
# 05400:           train mse loss:  0.013, l1 loss:  0.084	      valid mse loss:  0.277, l1 loss:  0.279
#           front pocket mse loss: 60.507, l1 loss:  6.151	 calibrated mse loss: 56.251, l1 loss:  5.853
#             horizontal mse loss: 20.650, l1 loss:  3.561	 calibrated mse loss: 21.304, l1 loss:  3.684
#                 pocket mse loss: 72.078, l1 loss:  7.032	 calibrated mse loss: 66.734, l1 loss:  6.775
#                  swing mse loss: 48.178, l1 loss:  5.781	 calibrated mse loss: 47.071, l1 loss:  5.718
# 05500:           train mse loss:  0.011, l1 loss:  0.079	      valid mse loss:  0.269, l1 loss:  0.268
#           front pocket mse loss: 59.976, l1 loss:  6.123	 calibrated mse loss: 55.701, l1 loss:  5.823
#             horizontal mse loss: 20.945, l1 loss:  3.603	 calibrated mse loss: 21.496, l1 loss:  3.713
#                 pocket mse loss: 71.297, l1 loss:  6.994	 calibrated mse loss: 65.878, l1 loss:  6.725
#                  swing mse loss: 47.668, l1 loss:  5.738	 calibrated mse loss: 46.767, l1 loss:  5.698
# 05600:           train mse loss:  0.013, l1 loss:  0.087	      valid mse loss:  0.275, l1 loss:  0.271
#           front pocket mse loss: 59.416, l1 loss:  6.093	 calibrated mse loss: 55.032, l1 loss:  5.782
#             horizontal mse loss: 20.646, l1 loss:  3.581	 calibrated mse loss: 21.245, l1 loss:  3.690
#                 pocket mse loss: 70.568, l1 loss:  6.956	 calibrated mse loss: 65.337, l1 loss:  6.699
#                  swing mse loss: 47.184, l1 loss:  5.710	 calibrated mse loss: 46.212, l1 loss:  5.661
# 05700:           train mse loss:  0.008, l1 loss:  0.067	      valid mse loss:  0.262, l1 loss:  0.260
#           front pocket mse loss: 59.569, l1 loss:  6.100	 calibrated mse loss: 55.116, l1 loss:  5.789
#             horizontal mse loss: 20.631, l1 loss:  3.581	 calibrated mse loss: 21.130, l1 loss:  3.678
#                 pocket mse loss: 70.698, l1 loss:  6.967	 calibrated mse loss: 65.469, l1 loss:  6.708
#                  swing mse loss: 47.172, l1 loss:  5.711	 calibrated mse loss: 46.324, l1 loss:  5.674
# 05800:           train mse loss:  0.008, l1 loss:  0.069	      valid mse loss:  0.263, l1 loss:  0.255
#           front pocket mse loss: 59.353, l1 loss:  6.087	 calibrated mse loss: 54.765, l1 loss:  5.768
#             horizontal mse loss: 20.713, l1 loss:  3.585	 calibrated mse loss: 21.311, l1 loss:  3.694
#                 pocket mse loss: 70.332, l1 loss:  6.950	 calibrated mse loss: 65.109, l1 loss:  6.691
#                  swing mse loss: 46.985, l1 loss:  5.699	 calibrated mse loss: 46.116, l1 loss:  5.658
# 05900:           train mse loss:  0.008, l1 loss:  0.068	      valid mse loss:  0.246, l1 loss:  0.250
#           front pocket mse loss: 58.755, l1 loss:  6.055	 calibrated mse loss: 54.066, l1 loss:  5.731
#             horizontal mse loss: 20.798, l1 loss:  3.597	 calibrated mse loss: 21.309, l1 loss:  3.687
#                 pocket mse loss: 69.562, l1 loss:  6.913	 calibrated mse loss: 64.359, l1 loss:  6.652
#                  swing mse loss: 46.580, l1 loss:  5.671	 calibrated mse loss: 45.724, l1 loss:  5.632
# 06000:           train mse loss:  0.006, l1 loss:  0.061	      valid mse loss:  0.251, l1 loss:  0.250
#           front pocket mse loss: 58.409, l1 loss:  6.035	 calibrated mse loss: 53.624, l1 loss:  5.704
#             horizontal mse loss: 20.760, l1 loss:  3.591	 calibrated mse loss: 21.301, l1 loss:  3.690
#                 pocket mse loss: 69.121, l1 loss:  6.888	 calibrated mse loss: 63.897, l1 loss:  6.626
#                  swing mse loss: 46.313, l1 loss:  5.652	 calibrated mse loss: 45.611, l1 loss:  5.628
# 06100:           train mse loss:  0.011, l1 loss:  0.077	      valid mse loss:  0.261, l1 loss:  0.257
#           front pocket mse loss: 58.494, l1 loss:  6.037	 calibrated mse loss: 53.637, l1 loss:  5.707
#             horizontal mse loss: 20.739, l1 loss:  3.589	 calibrated mse loss: 21.398, l1 loss:  3.704
#                 pocket mse loss: 69.147, l1 loss:  6.890	 calibrated mse loss: 64.019, l1 loss:  6.638
#                  swing mse loss: 46.334, l1 loss:  5.654	 calibrated mse loss: 45.550, l1 loss:  5.618
# 06200:           train mse loss:  0.022, l1 loss:  0.110	      valid mse loss:  0.272, l1 loss:  0.296
#           front pocket mse loss: 58.001, l1 loss:  6.003	 calibrated mse loss: 52.954, l1 loss:  5.666
#             horizontal mse loss: 20.835, l1 loss:  3.598	 calibrated mse loss: 21.828, l1 loss:  3.745
#                 pocket mse loss: 68.576, l1 loss:  6.860	 calibrated mse loss: 63.358, l1 loss:  6.602
#                  swing mse loss: 45.875, l1 loss:  5.624	 calibrated mse loss: 45.182, l1 loss:  5.595
# 06300:           train mse loss:  0.006, l1 loss:  0.056	      valid mse loss:  0.270, l1 loss:  0.254
#           front pocket mse loss: 57.870, l1 loss:  6.000	 calibrated mse loss: 52.837, l1 loss:  5.664
#             horizontal mse loss: 20.580, l1 loss:  3.578	 calibrated mse loss: 21.204, l1 loss:  3.691
#                 pocket mse loss: 68.277, l1 loss:  6.843	 calibrated mse loss: 63.109, l1 loss:  6.586
#                  swing mse loss: 45.841, l1 loss:  5.625	 calibrated mse loss: 45.064, l1 loss:  5.584
# 06400:           train mse loss:  0.007, l1 loss:  0.064	      valid mse loss:  0.240, l1 loss:  0.254
#           front pocket mse loss: 57.669, l1 loss:  5.993	 calibrated mse loss: 52.634, l1 loss:  5.655
#             horizontal mse loss: 20.531, l1 loss:  3.581	 calibrated mse loss: 21.170, l1 loss:  3.691
#                 pocket mse loss: 67.997, l1 loss:  6.830	 calibrated mse loss: 62.932, l1 loss:  6.576
#                  swing mse loss: 45.797, l1 loss:  5.626	 calibrated mse loss: 44.907, l1 loss:  5.571
# 06500:           train mse loss:  0.017, l1 loss:  0.099	      valid mse loss:  0.298, l1 loss:  0.263
#           front pocket mse loss: 56.923, l1 loss:  5.941	 calibrated mse loss: 51.739, l1 loss:  5.594
#             horizontal mse loss: 20.723, l1 loss:  3.586	 calibrated mse loss: 21.310, l1 loss:  3.697
#                 pocket mse loss: 67.154, l1 loss:  6.782	 calibrated mse loss: 62.040, l1 loss:  6.525
#                  swing mse loss: 45.220, l1 loss:  5.583	 calibrated mse loss: 44.451, l1 loss:  5.539
# 06600:           train mse loss:  0.016, l1 loss:  0.089	      valid mse loss:  0.253, l1 loss:  0.257
#           front pocket mse loss: 56.375, l1 loss:  5.910	 calibrated mse loss: 51.154, l1 loss:  5.561
#             horizontal mse loss: 20.596, l1 loss:  3.590	 calibrated mse loss: 21.161, l1 loss:  3.687
#                 pocket mse loss: 66.398, l1 loss:  6.735	 calibrated mse loss: 61.333, l1 loss:  6.481
#                  swing mse loss: 44.723, l1 loss:  5.546	 calibrated mse loss: 44.001, l1 loss:  5.501
# 06700:           train mse loss:  0.008, l1 loss:  0.065	      valid mse loss:  0.250, l1 loss:  0.253
#           front pocket mse loss: 56.278, l1 loss:  5.910	 calibrated mse loss: 51.015, l1 loss:  5.555
#             horizontal mse loss: 20.614, l1 loss:  3.586	 calibrated mse loss: 21.325, l1 loss:  3.696
#                 pocket mse loss: 66.530, l1 loss:  6.744	 calibrated mse loss: 61.432, l1 loss:  6.488
#                  swing mse loss: 44.710, l1 loss:  5.554	 calibrated mse loss: 43.770, l1 loss:  5.481
# 06800:           train mse loss:  0.009, l1 loss:  0.071	      valid mse loss:  0.250, l1 loss:  0.256
#           front pocket mse loss: 56.098, l1 loss:  5.895	 calibrated mse loss: 50.777, l1 loss:  5.536
#             horizontal mse loss: 20.888, l1 loss:  3.619	 calibrated mse loss: 21.512, l1 loss:  3.724
#                 pocket mse loss: 66.423, l1 loss:  6.734	 calibrated mse loss: 61.252, l1 loss:  6.472
#                  swing mse loss: 44.767, l1 loss:  5.552	 calibrated mse loss: 43.881, l1 loss:  5.487
# 06900:           train mse loss:  0.005, l1 loss:  0.054	      valid mse loss:  0.281, l1 loss:  0.257
#           front pocket mse loss: 56.038, l1 loss:  5.897	 calibrated mse loss: 50.747, l1 loss:  5.540
#             horizontal mse loss: 20.496, l1 loss:  3.574	 calibrated mse loss: 21.258, l1 loss:  3.695
#                 pocket mse loss: 66.269, l1 loss:  6.726	 calibrated mse loss: 61.130, l1 loss:  6.465
#                  swing mse loss: 44.838, l1 loss:  5.560	 calibrated mse loss: 43.932, l1 loss:  5.492
# 07000:           train mse loss:  0.016, l1 loss:  0.094	      valid mse loss:  0.237, l1 loss:  0.290
#           front pocket mse loss: 55.232, l1 loss:  5.842	 calibrated mse loss: 49.906, l1 loss:  5.481
#             horizontal mse loss: 21.023, l1 loss:  3.650	 calibrated mse loss: 21.615, l1 loss:  3.737
#                 pocket mse loss: 65.575, l1 loss:  6.682	 calibrated mse loss: 60.375, l1 loss:  6.419
#                  swing mse loss: 44.411, l1 loss:  5.531	 calibrated mse loss: 43.535, l1 loss:  5.465
# 07100:           train mse loss:  0.004, l1 loss:  0.051	      valid mse loss:  0.236, l1 loss:  0.250
#           front pocket mse loss: 55.601, l1 loss:  5.869	 calibrated mse loss: 50.210, l1 loss:  5.508
#             horizontal mse loss: 20.480, l1 loss:  3.579	 calibrated mse loss: 21.341, l1 loss:  3.708
#                 pocket mse loss: 65.947, l1 loss:  6.705	 calibrated mse loss: 60.746, l1 loss:  6.445
#                  swing mse loss: 44.670, l1 loss:  5.550	 calibrated mse loss: 43.689, l1 loss:  5.472
# 07200:           train mse loss:  0.008, l1 loss:  0.071	      valid mse loss:  0.289, l1 loss:  0.276
#           front pocket mse loss: 54.630, l1 loss:  5.810	 calibrated mse loss: 49.312, l1 loss:  5.451
#             horizontal mse loss: 20.432, l1 loss:  3.575	 calibrated mse loss: 21.170, l1 loss:  3.685
#                 pocket mse loss: 64.929, l1 loss:  6.641	 calibrated mse loss: 59.700, l1 loss:  6.382
#                  swing mse loss: 44.109, l1 loss:  5.510	 calibrated mse loss: 43.187, l1 loss:  5.432
# 07300:           train mse loss:  0.008, l1 loss:  0.070	      valid mse loss:  0.286, l1 loss:  0.270
#           front pocket mse loss: 54.324, l1 loss:  5.790	 calibrated mse loss: 48.942, l1 loss:  5.428
#             horizontal mse loss: 20.394, l1 loss:  3.563	 calibrated mse loss: 21.233, l1 loss:  3.691
#                 pocket mse loss: 64.569, l1 loss:  6.626	 calibrated mse loss: 59.297, l1 loss:  6.359
#                  swing mse loss: 43.895, l1 loss:  5.498	 calibrated mse loss: 42.960, l1 loss:  5.418
# 07400:           train mse loss:  0.005, l1 loss:  0.052	      valid mse loss:  0.232, l1 loss:  0.246
#           front pocket mse loss: 54.368, l1 loss:  5.796	 calibrated mse loss: 48.994, l1 loss:  5.437
#             horizontal mse loss: 20.590, l1 loss:  3.596	 calibrated mse loss: 21.305, l1 loss:  3.706
#                 pocket mse loss: 64.537, l1 loss:  6.623	 calibrated mse loss: 59.340, l1 loss:  6.364
#                  swing mse loss: 44.010, l1 loss:  5.505	 calibrated mse loss: 43.028, l1 loss:  5.419
# 07500:           train mse loss:  0.004, l1 loss:  0.048	      valid mse loss:  0.236, l1 loss:  0.248
#           front pocket mse loss: 54.309, l1 loss:  5.794	 calibrated mse loss: 48.958, l1 loss:  5.436
#             horizontal mse loss: 20.491, l1 loss:  3.590	 calibrated mse loss: 21.227, l1 loss:  3.700
#                 pocket mse loss: 64.412, l1 loss:  6.613	 calibrated mse loss: 59.212, l1 loss:  6.354
#                  swing mse loss: 43.984, l1 loss:  5.501	 calibrated mse loss: 42.958, l1 loss:  5.411
# 07600:           train mse loss:  0.016, l1 loss:  0.094	      valid mse loss:  0.227, l1 loss:  0.265
#           front pocket mse loss: 53.881, l1 loss:  5.768	 calibrated mse loss: 48.480, l1 loss:  5.411
#             horizontal mse loss: 20.265, l1 loss:  3.569	 calibrated mse loss: 20.986, l1 loss:  3.677
#                 pocket mse loss: 63.861, l1 loss:  6.591	 calibrated mse loss: 58.612, l1 loss:  6.323
#                  swing mse loss: 43.589, l1 loss:  5.475	 calibrated mse loss: 42.581, l1 loss:  5.381
# 07700:           train mse loss:  0.008, l1 loss:  0.067	      valid mse loss:  0.267, l1 loss:  0.270
#           front pocket mse loss: 53.394, l1 loss:  5.739	 calibrated mse loss: 48.041, l1 loss:  5.380
#             horizontal mse loss: 20.457, l1 loss:  3.581	 calibrated mse loss: 21.136, l1 loss:  3.690
#                 pocket mse loss: 63.339, l1 loss:  6.554	 calibrated mse loss: 58.166, l1 loss:  6.295
#                  swing mse loss: 43.489, l1 loss:  5.468	 calibrated mse loss: 42.441, l1 loss:  5.369
# 07800:           train mse loss:  0.008, l1 loss:  0.066	      valid mse loss:  0.226, l1 loss:  0.249
#           front pocket mse loss: 53.204, l1 loss:  5.725	 calibrated mse loss: 47.811, l1 loss:  5.366
#             horizontal mse loss: 20.713, l1 loss:  3.616	 calibrated mse loss: 21.425, l1 loss:  3.719
#                 pocket mse loss: 63.119, l1 loss:  6.543	 calibrated mse loss: 57.893, l1 loss:  6.277
#                  swing mse loss: 43.475, l1 loss:  5.467	 calibrated mse loss: 42.349, l1 loss:  5.361
# 07900:           train mse loss:  0.007, l1 loss:  0.065	      valid mse loss:  0.239, l1 loss:  0.273
#           front pocket mse loss: 52.796, l1 loss:  5.705	 calibrated mse loss: 47.508, l1 loss:  5.351
#             horizontal mse loss: 20.509, l1 loss:  3.589	 calibrated mse loss: 21.327, l1 loss:  3.705
#                 pocket mse loss: 62.603, l1 loss:  6.512	 calibrated mse loss: 57.429, l1 loss:  6.249
#                  swing mse loss: 43.129, l1 loss:  5.443	 calibrated mse loss: 42.117, l1 loss:  5.346
# 08000:           train mse loss:  0.006, l1 loss:  0.061	      valid mse loss:  0.257, l1 loss:  0.271
#           front pocket mse loss: 52.756, l1 loss:  5.707	 calibrated mse loss: 47.478, l1 loss:  5.356
#             horizontal mse loss: 20.347, l1 loss:  3.568	 calibrated mse loss: 21.093, l1 loss:  3.684
#                 pocket mse loss: 62.615, l1 loss:  6.514	 calibrated mse loss: 57.576, l1 loss:  6.263
#                  swing mse loss: 43.210, l1 loss:  5.448	 calibrated mse loss: 42.067, l1 loss:  5.343
# 08100:           train mse loss:  0.006, l1 loss:  0.055	      valid mse loss:  0.251, l1 loss:  0.255
#           front pocket mse loss: 52.566, l1 loss:  5.695	 calibrated mse loss: 47.239, l1 loss:  5.339
#             horizontal mse loss: 20.361, l1 loss:  3.574	 calibrated mse loss: 21.182, l1 loss:  3.694
#                 pocket mse loss: 62.350, l1 loss:  6.501	 calibrated mse loss: 57.314, l1 loss:  6.248
#                  swing mse loss: 43.153, l1 loss:  5.446	 calibrated mse loss: 42.095, l1 loss:  5.343
# 08200:           train mse loss:  0.005, l1 loss:  0.054	      valid mse loss:  0.254, l1 loss:  0.256
#           front pocket mse loss: 52.062, l1 loss:  5.662	 calibrated mse loss: 46.841, l1 loss:  5.316
#             horizontal mse loss: 20.430, l1 loss:  3.585	 calibrated mse loss: 21.226, l1 loss:  3.698
#                 pocket mse loss: 61.712, l1 loss:  6.458	 calibrated mse loss: 56.795, l1 loss:  6.215
#                  swing mse loss: 43.060, l1 loss:  5.442	 calibrated mse loss: 41.841, l1 loss:  5.320
# 08300:           train mse loss:  0.006, l1 loss:  0.056	      valid mse loss:  0.238, l1 loss:  0.248
#           front pocket mse loss: 51.486, l1 loss:  5.625	 calibrated mse loss: 46.215, l1 loss:  5.279
#             horizontal mse loss: 20.596, l1 loss:  3.603	 calibrated mse loss: 21.336, l1 loss:  3.711
#                 pocket mse loss: 61.132, l1 loss:  6.427	 calibrated mse loss: 56.125, l1 loss:  6.176
#                  swing mse loss: 42.792, l1 loss:  5.422	 calibrated mse loss: 41.580, l1 loss:  5.299
# 08400:           train mse loss:  0.008, l1 loss:  0.066	      valid mse loss:  0.267, l1 loss:  0.279
#           front pocket mse loss: 50.775, l1 loss:  5.586	 calibrated mse loss: 45.608, l1 loss:  5.240
#             horizontal mse loss: 20.278, l1 loss:  3.567	 calibrated mse loss: 21.271, l1 loss:  3.698
#                 pocket mse loss: 60.322, l1 loss:  6.380	 calibrated mse loss: 55.422, l1 loss:  6.133
#                  swing mse loss: 42.247, l1 loss:  5.385	 calibrated mse loss: 41.002, l1 loss:  5.252
# 08500:           train mse loss:  0.006, l1 loss:  0.058	      valid mse loss:  0.240, l1 loss:  0.257
#           front pocket mse loss: 51.116, l1 loss:  5.604	 calibrated mse loss: 45.956, l1 loss:  5.266
#             horizontal mse loss: 20.501, l1 loss:  3.595	 calibrated mse loss: 21.226, l1 loss:  3.694
#                 pocket mse loss: 60.637, l1 loss:  6.395	 calibrated mse loss: 55.891, l1 loss:  6.162
#                  swing mse loss: 42.721, l1 loss:  5.421	 calibrated mse loss: 41.452, l1 loss:  5.290
# 08600:           train mse loss:  0.005, l1 loss:  0.052	      valid mse loss:  0.300, l1 loss:  0.267
#           front pocket mse loss: 50.714, l1 loss:  5.585	 calibrated mse loss: 45.593, l1 loss:  5.246
#             horizontal mse loss: 20.459, l1 loss:  3.590	 calibrated mse loss: 21.254, l1 loss:  3.702
#                 pocket mse loss: 60.086, l1 loss:  6.368	 calibrated mse loss: 55.350, l1 loss:  6.132
#                  swing mse loss: 42.417, l1 loss:  5.396	 calibrated mse loss: 41.119, l1 loss:  5.270
# 08700:           train mse loss:  0.004, l1 loss:  0.045	      valid mse loss:  0.287, l1 loss:  0.275
#           front pocket mse loss: 50.508, l1 loss:  5.571	 calibrated mse loss: 45.440, l1 loss:  5.237
#             horizontal mse loss: 20.245, l1 loss:  3.565	 calibrated mse loss: 21.085, l1 loss:  3.688
#                 pocket mse loss: 59.934, l1 loss:  6.360	 calibrated mse loss: 55.195, l1 loss:  6.124
#                  swing mse loss: 42.319, l1 loss:  5.392	 calibrated mse loss: 40.972, l1 loss:  5.256
# 08800:           train mse loss:  0.002, l1 loss:  0.034	      valid mse loss:  0.298, l1 loss:  0.254
#           front pocket mse loss: 49.266, l1 loss:  5.496	 calibrated mse loss: 44.215, l1 loss:  5.158
#             horizontal mse loss: 20.453, l1 loss:  3.591	 calibrated mse loss: 21.258, l1 loss:  3.701
#                 pocket mse loss: 58.429, l1 loss:  6.277	 calibrated mse loss: 53.595, l1 loss:  6.028
#                  swing mse loss: 41.307, l1 loss:  5.313	 calibrated mse loss: 40.208, l1 loss:  5.197
# 08900:           train mse loss:  0.005, l1 loss:  0.052	      valid mse loss:  0.297, l1 loss:  0.268
#           front pocket mse loss: 49.319, l1 loss:  5.495	 calibrated mse loss: 44.286, l1 loss:  5.159
#             horizontal mse loss: 20.627, l1 loss:  3.608	 calibrated mse loss: 21.312, l1 loss:  3.707
#                 pocket mse loss: 58.501, l1 loss:  6.276	 calibrated mse loss: 53.793, l1 loss:  6.038
#                  swing mse loss: 41.511, l1 loss:  5.331	 calibrated mse loss: 40.201, l1 loss:  5.196
# 09000:           train mse loss:  0.003, l1 loss:  0.042	      valid mse loss:  0.301, l1 loss:  0.257
#           front pocket mse loss: 49.568, l1 loss:  5.516	 calibrated mse loss: 44.507, l1 loss:  5.181
#             horizontal mse loss: 20.398, l1 loss:  3.586	 calibrated mse loss: 21.218, l1 loss:  3.695
#                 pocket mse loss: 58.689, l1 loss:  6.291	 calibrated mse loss: 53.936, l1 loss:  6.048
#                  swing mse loss: 41.755, l1 loss:  5.347	 calibrated mse loss: 40.406, l1 loss:  5.219
# 09100:           train mse loss:  0.006, l1 loss:  0.059	      valid mse loss:  0.257, l1 loss:  0.255
#           front pocket mse loss: 49.173, l1 loss:  5.494	 calibrated mse loss: 44.159, l1 loss:  5.165
#             horizontal mse loss: 20.489, l1 loss:  3.598	 calibrated mse loss: 21.225, l1 loss:  3.700
#                 pocket mse loss: 58.259, l1 loss:  6.266	 calibrated mse loss: 53.715, l1 loss:  6.040
#                  swing mse loss: 41.669, l1 loss:  5.342	 calibrated mse loss: 40.175, l1 loss:  5.199
# 09200:           train mse loss:  0.005, l1 loss:  0.052	      valid mse loss:  0.343, l1 loss:  0.269
#           front pocket mse loss: 49.073, l1 loss:  5.488	 calibrated mse loss: 44.126, l1 loss:  5.161
#             horizontal mse loss: 20.416, l1 loss:  3.584	 calibrated mse loss: 21.203, l1 loss:  3.693
#                 pocket mse loss: 58.111, l1 loss:  6.257	 calibrated mse loss: 53.657, l1 loss:  6.035
#                  swing mse loss: 41.732, l1 loss:  5.348	 calibrated mse loss: 40.305, l1 loss:  5.209
# 09300:           train mse loss:  0.006, l1 loss:  0.057	      valid mse loss:  0.275, l1 loss:  0.267
#           front pocket mse loss: 48.755, l1 loss:  5.472	 calibrated mse loss: 43.790, l1 loss:  5.142
#             horizontal mse loss: 20.343, l1 loss:  3.570	 calibrated mse loss: 21.248, l1 loss:  3.690
#                 pocket mse loss: 57.670, l1 loss:  6.232	 calibrated mse loss: 53.218, l1 loss:  6.010
#                  swing mse loss: 41.443, l1 loss:  5.327	 calibrated mse loss: 40.045, l1 loss:  5.190
# 09400:           train mse loss:  0.004, l1 loss:  0.049	      valid mse loss:  0.327, l1 loss:  0.271
#           front pocket mse loss: 48.487, l1 loss:  5.453	 calibrated mse loss: 43.564, l1 loss:  5.126
#             horizontal mse loss: 20.425, l1 loss:  3.588	 calibrated mse loss: 21.105, l1 loss:  3.686
#                 pocket mse loss: 57.342, l1 loss:  6.209	 calibrated mse loss: 52.853, l1 loss:  5.985
#                  swing mse loss: 41.278, l1 loss:  5.310	 calibrated mse loss: 39.835, l1 loss:  5.172
# 09500:           train mse loss:  0.016, l1 loss:  0.095	      valid mse loss:  0.250, l1 loss:  0.265
#           front pocket mse loss: 48.702, l1 loss:  5.470	 calibrated mse loss: 43.863, l1 loss:  5.149
#             horizontal mse loss: 20.476, l1 loss:  3.597	 calibrated mse loss: 21.363, l1 loss:  3.711
#                 pocket mse loss: 57.640, l1 loss:  6.225	 calibrated mse loss: 53.306, l1 loss:  6.012
#                  swing mse loss: 41.579, l1 loss:  5.335	 calibrated mse loss: 40.100, l1 loss:  5.194
# 09600:           train mse loss:  0.008, l1 loss:  0.068	      valid mse loss:  0.294, l1 loss:  0.269
#           front pocket mse loss: 48.081, l1 loss:  5.431	 calibrated mse loss: 43.208, l1 loss:  5.107
#             horizontal mse loss: 20.573, l1 loss:  3.599	 calibrated mse loss: 21.260, l1 loss:  3.698
#                 pocket mse loss: 56.822, l1 loss:  6.180	 calibrated mse loss: 52.395, l1 loss:  5.959
#                  swing mse loss: 41.107, l1 loss:  5.301	 calibrated mse loss: 39.774, l1 loss:  5.170
# 09700:           train mse loss:  0.019, l1 loss:  0.103	      valid mse loss:  0.336, l1 loss:  0.301
#           front pocket mse loss: 47.882, l1 loss:  5.427	 calibrated mse loss: 43.043, l1 loss:  5.099
#             horizontal mse loss: 20.204, l1 loss:  3.567	 calibrated mse loss: 21.156, l1 loss:  3.690
#                 pocket mse loss: 56.614, l1 loss:  6.168	 calibrated mse loss: 52.445, l1 loss:  5.967
#                  swing mse loss: 40.844, l1 loss:  5.277	 calibrated mse loss: 39.392, l1 loss:  5.142
# 09800:           train mse loss:  0.011, l1 loss:  0.077	      valid mse loss:  0.324, l1 loss:  0.281
#           front pocket mse loss: 47.275, l1 loss:  5.385	 calibrated mse loss: 42.473, l1 loss:  5.061
#             horizontal mse loss: 20.332, l1 loss:  3.580	 calibrated mse loss: 21.025, l1 loss:  3.673
#                 pocket mse loss: 55.939, l1 loss:  6.124	 calibrated mse loss: 51.637, l1 loss:  5.909
#                  swing mse loss: 40.557, l1 loss:  5.255	 calibrated mse loss: 39.075, l1 loss:  5.112
# 09900:           train mse loss:  0.010, l1 loss:  0.075	      valid mse loss:  0.317, l1 loss:  0.271
#           front pocket mse loss: 47.691, l1 loss:  5.414	 calibrated mse loss: 42.920, l1 loss:  5.096
#             horizontal mse loss: 20.407, l1 loss:  3.583	 calibrated mse loss: 21.191, l1 loss:  3.694
#                 pocket mse loss: 56.350, l1 loss:  6.154	 calibrated mse loss: 52.154, l1 loss:  5.949
#                  swing mse loss: 40.783, l1 loss:  5.278	 calibrated mse loss: 39.321, l1 loss:  5.134
# 10000:           train mse loss:  0.004, l1 loss:  0.047	      valid mse loss:  0.319, l1 loss:  0.261
#           front pocket mse loss: 47.140, l1 loss:  5.381	 calibrated mse loss: 42.411, l1 loss:  5.063
#             horizontal mse loss: 20.451, l1 loss:  3.590	 calibrated mse loss: 21.239, l1 loss:  3.696
#                 pocket mse loss: 55.703, l1 loss:  6.116	 calibrated mse loss: 51.550, l1 loss:  5.911
#                  swing mse loss: 40.521, l1 loss:  5.257	 calibrated mse loss: 39.120, l1 loss:  5.118

# %%
# torch.save({
#     'locator_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     }, f'/root/Mag/Experiments/0712/loc/m_A_gpr_model.pt')

# %%
def pred_sequence_pos(dataloader):
    model.eval()

    pred_poses = []
    gt_poses = []
    pairs = []
    pp = nn.PairwiseDistance(p=2)
    
    with torch.no_grad():
        for sequences, gt_pos in dataloader:
            optimizer.zero_grad()
            
            sequences = sequences.to(device)
            gt_pos = gt_pos.to(device)

            # localization
            pred_pos = model(sequences[:, :, 2:5])
            pair = pp(pred_pos, gt_pos)
            
            gt_poses.extend(gt_pos.detach().cpu().numpy())
            pred_poses.extend(pred_pos.detach().cpu().numpy())
            pairs.extend(pair.detach().cpu().numpy())
    
    return np.array(gt_poses), np.array(pred_poses), np.array(pairs)

# %%
def visualize(data_loader, trajectory, skip=50):
    gt_poses, pred_poses, pairs = pred_sequence_pos(data_loader)
    print(gt_poses.shape, pred_poses.shape, pairs.shape, trajectory.shape)
    print(f'Mean: {np.mean(pairs):>6.3f}\tMedian: {np.median(pairs):>6.3f}')
    test_seq = trajectory[::skip, :, :2]

    plt.figure(figsize=(12, 8))

    plt.plot(test_seq[:, :, 1].T, test_seq[:, :, 0].T, alpha=0.25)

    # plt.scatter(test_seq[:, -1, 1], test_seq[:, -1, 0])
    plt.scatter(gt_poses[::skip, 1], gt_poses[::skip, 0])
    plt.scatter(pred_poses[::skip, 1], pred_poses[::skip, 0])


    for i in range(0, len(gt_poses), skip):
        plt.annotate(int(i/skip), (gt_poses[i, 1], gt_poses[i, 0]))
        plt.annotate(int(i/skip), (pred_poses[i, 1], pred_poses[i, 0]))

    plt.axis('equal')
    plt.gca().invert_yaxis()
    plt.show()

# %%
valid_loader = DataLoader(train_dataset, batch_size=32)
visualize(valid_loader, prep_valid_target_traj[(np.arange(prep_valid_target_traj.shape[0])) % 10 != 0, :, :])
# Out:
# (606, 2) (606, 2) (606,) (606, 20, 8)
# Mean:  0.065	Median:  0.057

# %%
visualize(target_loader, prep_valid_target_traj[::10, :, :], 6)
# Out:
# (68, 2) (68, 2) (68,) (68, 20, 8)
# Mean:  3.247	Median:  2.735

# %%
visualize(front_pocket_loader, prep_valid_front_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  8.317	Median:  7.910

# %%
visualize(c_front_pocket_loader, cali_valid_front_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  7.820	Median:  7.363

# %%
visualize(horizontal_loader, prep_valid_horizontal_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  5.722	Median:  5.241

# %%
visualize(c_horizontal_loader, cali_valid_horizontal_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  5.767	Median:  5.313

# %%
visualize(pocket_loader, prep_valid_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  9.174	Median:  9.399

# %%
visualize(c_pocket_loader, cali_valid_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  8.807	Median:  8.822

# %%
visualize(swing_loader, prep_valid_swing_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  8.226	Median:  8.226

# %%
visualize(c_swing_loader, cali_valid_swing_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  8.082	Median:  7.968
