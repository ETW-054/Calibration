# %% [markdown]
# # Used Packages

# %%
import os
import glob
import gc

import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
from datetime import datetime

from scipy.spatial.transform import Rotation as R

from utils.MovingAverager import *
from collections import defaultdict
from torchinfo import summary

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Global Variable

# %%
datapoint_per_second = 20
duration = 2
seq_len = 10

# %%
validation_traj = np.load(f'./npys/all_user_match_data.npy', allow_pickle=True)

# %%
def estimate_gravity(gravity_included_acceleration, dynamic_acceleration):
    raw_gravity_vector = np.array(gravity_included_acceleration) - np.array(dynamic_acceleration)
    gravity_direction = raw_gravity_vector / np.linalg.norm(raw_gravity_vector)
    return gravity_direction

# %%
def align_magnetometer_with_gravity(magnetometer_data, gravity_direction, num_of_axie):
    target_gravity_direction = np.array([0, 0, 1])
    rotation_vector = np.cross(gravity_direction, target_gravity_direction)
    rotation_vector_magnitude = np.linalg.norm(rotation_vector)
    if rotation_vector_magnitude == 0:
        return magnetometer_data  # 如果已经对齐，则不需要旋转
    rotation_vector /= rotation_vector_magnitude
    angle = np.arccos(np.dot(gravity_direction, target_gravity_direction))
    rotation = R.from_rotvec(rotation_vector * angle[:, np.newaxis])
    rotated_magnetometer_data = rotation.apply(magnetometer_data)
    hv = np.column_stack((np.sqrt(rotated_magnetometer_data[:, 0]**2 + rotated_magnetometer_data[:, 1]**2), rotated_magnetometer_data[:, 2]))
    return hv if num_of_axie == 2 else rotated_magnetometer_data

# %%
def get_data(validation_traj, num_of_axie, rotation):
    posture_data = defaultdict(list)

    valid_data = validation_traj.item()
    for user_name in valid_data.keys():
        for path_name in valid_data[user_name].keys():
            for posture_name in valid_data[user_name][path_name].keys():
                data = valid_data[user_name][path_name][posture_name]

                if posture_name == 'ref_mag':
                    if num_of_axie == 2:
                        posture_data[posture_name].append(data[:, [0, 1, 6, 7, 5]])
                    else:
                        posture_data[posture_name].append(data[:, [0, 1, 2, 3, 4, 6, 7, 5]])
                    continue

                pos = (data[:, [0, 1]] + np.array((1, 1))) * 0.6
                imu = data[:, [3, 4, 5, 6, 7, 8, 9, 10, 11]]
                mag = data[:, [12, 13, 14]]

                pos_mag = np.concatenate((pos, imu), axis=-1)

                if rotation:
                    gravity_direction = estimate_gravity(imu[:, 0:3], imu[:, 3:6])
                    mag = align_magnetometer_with_gravity(mag[:, 0:3], gravity_direction, num_of_axie)
                    imu[:, 0:3] = align_magnetometer_with_gravity(imu[:, 0:3], gravity_direction, 3)
                    imu[:, 3:6] = align_magnetometer_with_gravity(imu[:, 3:6], gravity_direction, 3)
                    imu[:, 6:9] = align_magnetometer_with_gravity(imu[:, 6:9], gravity_direction, 3)
                    
                else:
                    if num_of_axie == 2: 
                        mag = np.column_stack((np.sqrt(np.sum(mag[:, :2]**2, axis=1)), mag[:, 2]))
                pos_mag = np.concatenate((pos_mag, mag, data[:, [15]]), axis=-1)            
                posture_data[posture_name].append(pos_mag)
    return posture_data

# %%
def split_traj(trajs, length=20):
    sp_traj = []
    for traj in trajs:
        for i in range(len(traj) - length + 1):
            sp_traj.append(traj[i:i+length])
    return np.array(sp_traj)

# %% [markdown]
# # Data Loader

# %%
class PairDataset(Dataset):
    def __init__(self, source_data, source_label, target_data, target_label):
        assert (source_data.shape[0] == source_label.shape[0] == target_data.shape[0] == target_label.shape[0]), f'{source_data.shape}, {source_label.shape}, {target_data.shape}, {target_label.shape}'
        self.source_data = source_data
        self.source_label = source_label
        self.target_data = target_data
        self.target_label = target_label

    def __len__(self):
        return len(self.source_data)

    def __getitem__(self, idx):
        return self.source_data[idx], self.source_label[idx], self.target_data[idx], self.target_label[idx]

# %%
def for_dataloaders(traj, gt='target'):
    t_data = 0
    t_label = 0
    t_target_data = 0
    v_data = 0
    v_label = 0
    v_target_data = 0
    label = 1
    label_dict = {}
    flag = False
    for key, value in traj.items():
        split = int(len(value) * 9 / 10)
        tmp1, tmp2 = value[:split], value[split:]
        if key != gt: 
            t_data = np.concatenate((t_data, tmp1)) if flag else tmp1
            t_label = np.concatenate((t_label, np.full((tmp1.shape[0], ), label))) if flag else np.full((tmp1.shape[0], ), label)
            v_data = np.concatenate((v_data, tmp2)) if flag else tmp2
            v_label = np.concatenate((v_label, np.full((tmp2.shape[0], ), label))) if flag else np.full((tmp2.shape[0], ), label)
            flag = True
            label_dict[label] = key
            label += 1
        else:
            t_target_data = np.tile(tmp1, (4, 1, 1))
            v_target_data = np.tile(tmp2, (4, 1, 1))
            label_dict[0] = key
    
    train_dataset = PairDataset(
                        source_data = torch.tensor(t_data, dtype=torch.float),
                        source_label = t_label,
                        target_data = torch.tensor(t_target_data, dtype=torch.float),
                        target_label = np.zeros((len(t_target_data), ))
                    )
    
    valid_dataset = PairDataset(
                        source_data = torch.tensor(v_data, dtype=torch.float),
                        source_label = v_label,
                        target_data = torch.tensor(v_target_data, dtype=torch.float),
                        target_label = np.zeros((len(v_target_data), ))
                    )

    print(label_dict)
    return label_dict, train_dataset, valid_dataset

# %% [markdown]
# # Model Declaration

# %%
class FirstDerivativeLoss(nn.Module):
    def __init__(self, weight=None, size_average=None, reduce=None, reduction='mean'):
        super(FirstDerivativeLoss, self).__init__()

    def forward(self, source, target):
        # calculate the first derivative
        source_o = torch.reshape(source, (len(source), -1))
        target_o = torch.reshape(target, (len(target), -1))
        d_source = source_o[1:] - source_o[:-1]
        d_target = target_o[1:] - target_o[:-1]
        deriv = d_source - d_target

        # calculate the loss as the mean squared error of the derivative
        loss = torch.mean(torch.pow(deriv, 2))

        return loss

# %%
def generator_loss(z_imu, target_imu, predict_mag, target_mag, source_total_mag, target_total_mag):
    imu_loss = mse_loss(z_imu, target_imu)
    mag_loss = mse_loss(predict_mag, target_mag)
    d1_loss = div_loss(predict_mag, target_mag)
    
    pred_total_mag = torch.sqrt(torch.sum(torch.pow(predict_mag, 2), dim=-1))
    
    smag_limitation_loss = torch.mean(torch.abs(pred_total_mag - source_total_mag))
    tmag_limitation_loss = torch.mean(torch.abs(pred_total_mag - target_total_mag))

    total_loss = imu_loss + mag_loss + 2 * d1_loss + smag_limitation_loss * 0.25 + tmag_limitation_loss * 0.75
    return total_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss)

# %%
num_of_classes = 4
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
ce_loss = torch.nn.CrossEntropyLoss()
mse_loss = torch.nn.MSELoss()
bce_loss = torch.nn.BCELoss()
div_loss = FirstDerivativeLoss()

# %%
def get_tgt_mask(size) -> torch.tensor:
    # Generates a squeare matrix where the each row allows one word more to be seen
    mask = torch.tril(torch.ones(size, size) == 1) # Lower triangular matrix
    mask = mask.float()
    mask = mask.masked_fill(mask == 0, float('-inf')) # Convert zeros to -inf
    mask = mask.masked_fill(mask == 1, float(0.0)) # Convert ones to 0

    return mask

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :].to(x.device)
        return self.dropout(x)
    

class NotSimpleTransformer(nn.Module):
    def __init__(self, seq_len=21, num_of_classes=2):
        super(NotSimpleTransformer, self).__init__()
        
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        self.mag_axis = num_of_axie
        
        self.imu_layer = nn.Sequential(
            nn.Linear(9, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 64),
            nn.LeakyReLU(),
        )
        self.mag_layer = nn.Sequential(
            nn.Linear(self.mag_axis, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 64),
            nn.LeakyReLU(),
        )
        self.pos_encoder = PositionalEncoding(64, 0.1)
        
        self.encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        self.nn = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 9),
            nn.LeakyReLU(),
        )
        
        self.decoder = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        
        self.mag_last = nn.Sequential(
            nn.Linear(64, 16),
            nn.LeakyReLU(),
            nn.Linear(16, self.mag_axis),
        )
        
    def forward(self, source_imu, source_mag):
        
        ### step 1
        h_imu = self.imu_layer(source_imu)
        h_imu = self.pos_encoder(h_imu)
        
        h_mag = self.mag_layer(source_mag)
        h_mag = self.pos_encoder(h_mag)
        
        ### step 2
        z = self.encoder(h_imu)
        z_imu = self.nn(z)
        
        ### step 3
        pred_latent = self.decoder(h_mag, z)
        pred_mag = self.mag_last(pred_latent)
        
        return z_imu, pred_mag

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.lstm1 = nn.LSTM(input_size=32, hidden_size=128, batch_first=True)  # 条件维度2
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=256, batch_first=True)  # 条件维度2
        self.fc = nn.Linear(256, 9)  # 输出维度为9，每个序列元素
        self.batchnorm = nn.BatchNorm1d(256)

    def forward(self, noise, conditions):
        combined_input = torch.cat([noise, conditions], dim=2)  # 合并噪声和条件
        output, _ = self.lstm1(combined_input)
        output, _ = self.lstm2(output)
        output = self.batchnorm(output.transpose(1, 2)).transpose(1, 2)
        return self.fc(output)  # 输出batch_size * sequence_length * 9

# %%
generator =torch.load('/root/Calibration/R403/generator.pt').to(device)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
# summary(model, input_size=[(1, 10, 9), (1, 10, 2)])

# %%
def plot_result(result, source_label=None):
    pred_mag = result[0].reshape(-1, num_of_axie)
    targ_mag = result[1].reshape(-1, num_of_axie)
    x = np.arange(len(pred_mag))
    
    loss = mse_loss(torch.tensor(pred_mag), torch.tensor(targ_mag)).item()
    
    fig = plt.figure(figsize=(15, 5))
    
    for pm, tm, caxis, color in zip(pred_mag.T, targ_mag.T, ['x', 'y', 'z'][:num_of_axie], ['tab:blue', 'tab:orange', 'tab:green'][:num_of_axie]):
        plt.plot(x, pm, label=f'pred_{caxis}', color=color, linewidth=2.5, zorder=2)
        plt.plot(x, tm, '--', label=f'targ_{caxis}', color=color, linewidth=1, alpha=0.8, zorder=1)
    
    pred_total_mag = np.sqrt(np.sum(np.power(pred_mag, 2), axis=-1))
    targ_total_mag = np.sqrt(np.sum(np.power(targ_mag, 2), axis=-1))
    plt.plot(x, pred_total_mag, label=f'pred_t', color='tab:red', linewidth=2.5, zorder=2)
    plt.plot(x, targ_total_mag, '--', label=f'targ_t', color='tab:red', linewidth=1, alpha=0.8, zorder=1)
    
    if source_label != None:
        plt.suptitle(f'{classes[source_label]}   Loss: {loss:.2f}')
    else:
        plt.suptitle(f'Loss: {loss:.2f}')
    plt.legend()
    plt.show()

# %%
def train(dataloader, draw=False):
    model.train()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []
    lim_loss = []

    for source_data, source_label, target_data, target_label in dataloader:
        optimizer.zero_grad()

        source_data = source_data.to(device)
        source_imu = source_data[:, :, 2:11] + torch.randn_like(source_data[:, :, 2:11]) * 0.25
        source_mag = source_data[:, :, 11:(11 + num_of_axie)] + torch.randn_like(source_data[:, :, 11:(11 + num_of_axie)]) * 0.5
        source_total_mag = source_data[:, :, -1]
        
        with torch.no_grad():
            target_data = target_data.to(device)
            target_imu = generator(target_data[:, :, 0:2], torch.zeros(target_data[:, :, 0:2].size(0), target_data[:, :, 0:2].size(1), 30, device=device))
            target_mag = target_data[:, :, 2:(2 + num_of_axie)]
            target_total_mag = target_data[:, :, -1]

        # generate mag
        z_imu, predict_mag = model(source_imu, source_mag)
        
        # generator loss
        gen_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss) = generator_loss(z_imu, target_imu, predict_mag, target_mag,
                                                                                              source_total_mag, target_total_mag)
        
        # backward
        gen_loss.backward()
        optimizer.step()
        
        # record loss
        g_losses.append(gen_loss.item())
        imu_losses.append(imu_loss.item())
        mag_losses.append(mag_loss.item())
        d1_losses.append(d1_loss.item())
        lim_loss.append([smag_limitation_loss.item(), tmag_limitation_loss.item()])
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses), np.mean(lim_loss, axis=0)

# %%
def evalute(dataloader, draw=False):
    model.eval()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []
    lim_loss = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_imu = source_data[:, :, 2:11]
            source_mag = source_data[:, :, 11:(11 + num_of_axie)]
            source_total_mag = source_data[:, :, -1]

            target_data = target_data.to(device)
            target_imu = generator(target_data[:, :, 0:2], torch.zeros(target_data[:, :, 0:2].size(0), target_data[:, :, 0:2].size(1), 30, device=device))
            target_mag = target_data[:, :, 2:(2 + num_of_axie)]
            target_total_mag = target_data[:, :, -1]
            
            # generate mag
            z_imu, predict_mag = model(source_imu, source_mag)

            # generator loss
            gen_loss, (imu_loss, mag_loss, d1_loss, smag_limitation_loss, tmag_limitation_loss) = generator_loss(z_imu, target_imu, predict_mag, target_mag,
                                                                                                  source_total_mag, target_total_mag)

            # record loss
            g_losses.append(gen_loss.item())
            imu_losses.append(imu_loss.item())
            mag_losses.append(mag_loss.item())
            d1_losses.append(d1_loss.item())
            lim_loss.append([smag_limitation_loss.item(), tmag_limitation_loss.item()])
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses), np.mean(lim_loss, axis=0)

# %%
def output_eval(model, dataloader):
    model.eval()
    
    results = []
    class_results = []
    class_labels = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_pos = source_data[:, :, :2]
            source_imu = source_data[:, :, 2:11]
            source_mag = source_data[:, :, 11:(11 + num_of_axie)]

            target_data = target_data.to(device)
            target_imu = generator(target_data[:, :, 0:2], torch.zeros(target_data[:, :, 0:2].size(0), target_data[:, :, 0:2].size(1), 30, device=device))
            target_pos = target_data[:, :, :2]
            target_mag = target_data[:, :, 2:(2 + num_of_axie)]
            target_total_mag = target_data[:, :, -1]

            # generate mag
            z_imu, predict_mag = model(source_imu, source_mag)

            # generator loss
#             gen_loss, imu_loss, mag_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)

            # record loss
            predict_mag = predict_mag.detach().cpu().numpy()
            target_pos = target_pos.detach().cpu().numpy()
            target_mag = target_mag.cpu().numpy()
            source_label = source_label.detach().cpu().numpy()
            
            results.extend(zip(predict_mag, target_mag, source_label, target_pos))
            
            diff = np.power(predict_mag.reshape(len(predict_mag), -1, num_of_axie) - target_mag.reshape(len(target_mag), -1, num_of_axie), 2).mean(axis=1)
            class_results.extend(diff)
            class_labels.extend(source_label)
    
    return np.array(results, dtype=object), np.array(class_results), np.array(class_labels)

# %%
def show_result(model, dataloader):
    results, cres, clabel = output_eval(model, dataloader)
    print(results.shape, cres.shape, clabel.shape)

    if num_of_axie == 3:
        print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"diff z":>8} {"avg":>8}')
        for class_label, class_name in classes.items():
            if sum(clabel == class_label) <= 0:
                continue
            dx, dy, dz = cres[clabel == class_label].mean(axis=0)
            print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
        dx, dy, dz = cres.mean(axis=0)
        print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
    
    elif num_of_axie == 2:
        print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"avg":>8}')
        for class_label, class_name in classes.items():
            if sum(clabel == class_label) <= 0:
                continue
            dx, dy = cres[clabel == class_label].mean(axis=0)
            print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {np.mean([dx, dy]):>8.2f}')
        dx, dy = cres.mean(axis=0)
        print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {np.mean([dx, dy]):>8.2f}')

    for rs, rl in zip(results[::500], clabel[::50]):
        plot_result(rs, rl)

# %% [markdown]
# # Experiment 1
# rotation = False
# num_of_axie = 2 Different final ground truth (最終姿態)

# %%
num_of_axie, rotation = 2, True
posture_data = get_data(validation_traj, num_of_axie, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])
prep_valid_traj['ref_mag']      = split_traj(posture_data['ref_mag'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt='ref_mag')
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
# Out:
# {1: 'front_pocket', 2: 'pocket', 3: 'swing', 4: 'target', 0: 'ref_mag'}

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    
    draw = ((epoch + 1) % EPOCH == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw)
    
    if (epoch + 1) % 1000 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch+1:05d}: train loss: {train_loss:>6.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>6.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')
# Out:
# 01000: train loss: 73.446, imu loss:  2.985, mag loss: 13.754, div loss: 27.017, slim:  3.064, tlim:  2.542
#        valid loss: 77.617, imu loss:  3.051, mag loss: 57.271, div loss:  6.467, slim:  4.803, tlim:  4.215
# 02000: train loss: 52.740, imu loss:  2.927, mag loss:  9.492, div loss: 18.964, slim:  3.126, tlim:  2.150
#        valid loss: 78.324, imu loss:  3.027, mag loss: 55.448, div loss:  7.860, slim:  4.597, tlim:  3.974
# 03000: train loss: 42.751, imu loss:  2.897, mag loss:  7.567, div loss: 15.037, slim:  3.132, tlim:  1.907
#        valid loss: 77.405, imu loss:  3.014, mag loss: 53.366, div loss:  8.681, slim:  4.110, tlim:  3.515
# 04000: train loss: 36.250, imu loss:  2.875, mag loss:  6.294, div loss: 12.500, slim:  3.135, tlim:  1.728
#        valid loss: 77.564, imu loss:  3.010, mag loss: 53.253, div loss:  8.880, slim:  4.032, tlim:  3.377
# 05000: train loss: 32.206, imu loss:  2.859, mag loss:  5.484, div loss: 10.940, slim:  3.136, tlim:  1.596
#        valid loss: 75.293, imu loss:  3.014, mag loss: 51.874, div loss:  8.464, slim:  3.963, tlim:  3.316
# 06000: train loss: 29.658, imu loss:  2.840, mag loss:  5.007, div loss:  9.950, slim:  3.138, tlim:  1.503
#        valid loss: 75.687, imu loss:  3.031, mag loss: 51.862, div loss:  8.719, slim:  3.812, tlim:  3.203
# 07000: train loss: 27.547, imu loss:  2.829, mag loss:  4.589, div loss:  9.130, slim:  3.186, tlim:  1.429
#        valid loss: 74.820, imu loss:  3.039, mag loss: 51.175, div loss:  8.659, slim:  3.773, tlim:  3.126
# 08000: train loss: 26.342, imu loss:  2.808, mag loss:  4.327, div loss:  8.688, slim:  3.197, tlim:  1.377
#        valid loss: 74.431, imu loss:  3.044, mag loss: 51.109, div loss:  8.488, slim:  3.824, tlim:  3.129
# 09000: train loss: 25.011, imu loss:  2.795, mag loss:  4.085, div loss:  8.169, slim:  3.175, tlim:  1.333
#        valid loss: 74.507, imu loss:  3.041, mag loss: 50.781, div loss:  8.682, slim:  3.863, tlim:  3.142
# 10000: train loss: 24.094, imu loss:  2.785, mag loss:  3.918, div loss:  7.806, slim:  3.215, tlim:  1.300
#        valid loss: 74.819, imu loss:  3.049, mag loss: 51.059, div loss:  8.710, slim:  3.847, tlim:  3.105
# 11000: train loss: 23.547, imu loss:  2.765, mag loss:  3.832, div loss:  7.595, slim:  3.200, tlim:  1.279
#        valid loss: 74.386, imu loss:  3.052, mag loss: 50.596, div loss:  8.738, slim:  3.817, tlim:  3.077
# 12000: train loss: 22.558, imu loss:  2.749, mag loss:  3.625, div loss:  7.223, slim:  3.220, tlim:  1.244
#        valid loss: 75.224, imu loss:  3.059, mag loss: 51.131, div loss:  8.893, slim:  3.807, tlim:  3.063
# 13000: train loss: 22.186, imu loss:  2.741, mag loss:  3.557, div loss:  7.084, slim:  3.222, tlim:  1.220
#        valid loss: 76.115, imu loss:  3.069, mag loss: 51.528, div loss:  9.143, slim:  3.820, tlim:  3.035
# 14000: train loss: 21.796, imu loss:  2.726, mag loss:  3.476, div loss:  6.946, slim:  3.206, tlim:  1.203
#        valid loss: 75.485, imu loss:  3.073, mag loss: 51.214, div loss:  9.003, slim:  3.784, tlim:  2.994
# 15000: train loss: 21.055, imu loss:  2.710, mag loss:  3.348, div loss:  6.652, slim:  3.230, tlim:  1.181
#        valid loss: 75.890, imu loss:  3.085, mag loss: 51.294, div loss:  9.149, slim:  3.802, tlim:  3.016
# 16000: train loss: 20.524, imu loss:  2.706, mag loss:  3.230, div loss:  6.456, slim:  3.233, tlim:  1.156
#        valid loss: 75.888, imu loss:  3.085, mag loss: 51.312, div loss:  9.145, slim:  3.778, tlim:  3.008
# 17000: train loss: 20.350, imu loss:  2.698, mag loss:  3.208, div loss:  6.386, slim:  3.248, tlim:  1.147
#        valid loss: 75.565, imu loss:  3.090, mag loss: 51.251, div loss:  9.022, slim:  3.789, tlim:  2.977
# 18000: train loss: 19.938, imu loss:  2.677, mag loss:  3.138, div loss:  6.233, slim:  3.228, tlim:  1.133
#        valid loss: 75.038, imu loss:  3.095, mag loss: 51.034, div loss:  8.871, slim:  3.748, tlim:  2.973
# 19000: train loss: 19.798, imu loss:  2.666, mag loss:  3.108, div loss:  6.183, slim:  3.251, tlim:  1.127
#        valid loss: 75.412, imu loss:  3.099, mag loss: 51.136, div loss:  8.990, slim:  3.776, tlim:  3.004
# 20000: train loss: 19.311, imu loss:  2.653, mag loss:  3.040, div loss:  5.987, slim:  3.254, tlim:  1.107
#        valid loss: 75.277, imu loss:  3.096, mag loss: 50.879, div loss:  9.072, slim:  3.721, tlim:  2.969

# %%
show_result(model, train_loader)
# Out:
# (2424, 4) (2424, 2) (2424,)
#            loss name|   diff x   diff y      avg
#    front_pocket loss:     1.73     1.77     1.75
#          pocket loss:     1.79     2.03     1.91
#           swing loss:     1.32     1.50     1.41
#          target loss:     1.93     2.15     2.04
#         average loss:     1.69     1.86     1.78

# %%
show_result(model, valid_loader)
# Out:
# (272, 4) (272, 2) (272,)
#            loss name|   diff x   diff y      avg
#    front_pocket loss:    42.44    68.33    55.39
#          pocket loss:    36.13    65.26    50.70
#           swing loss:    26.57    58.50    42.53
#          target loss:    27.76    49.35    38.55
#         average loss:    33.23    60.36    46.79

# %%
torch.save(model, f'./model/ft_rotation/transformer_{num_of_axie}_{int(rotation)}.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Experiment 2
# rotation = False
# num_of_axie = 2 Different final ground truth (最終姿態)

# %%
num_of_axie, rotation = 2, False
posture_data = get_data(validation_traj, num_of_axie, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])
prep_valid_traj['ref_mag']      = split_traj(posture_data['ref_mag'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt='ref_mag')
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
# Out:
# {1: 'front_pocket', 2: 'pocket', 3: 'swing', 4: 'target', 0: 'ref_mag'}

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    
    draw = ((epoch + 1) % EPOCH == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw)
    
    if (epoch + 1) % 1000 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>6.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>6.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')
# Out:
# 00999: train loss: 70.627, imu loss:  2.988, mag loss: 13.018, div loss: 25.997, slim:  3.081, tlim:  2.474
#        valid loss: 73.460, imu loss:  3.067, mag loss: 52.903, div loss:  6.893, slim:  4.117, tlim:  3.568
# 01999: train loss: 51.505, imu loss:  2.932, mag loss:  9.213, div loss: 18.499, slim:  3.122, tlim:  2.107
#        valid loss: 72.746, imu loss:  3.021, mag loss: 51.399, div loss:  7.360, slim:  3.992, tlim:  3.477
# 02999: train loss: 41.969, imu loss:  2.897, mag loss:  7.350, div loss: 14.772, slim:  3.124, tlim:  1.863
#        valid loss: 71.439, imu loss:  3.024, mag loss: 50.128, div loss:  7.404, slim:  3.839, tlim:  3.358
# 03999: train loss: 36.260, imu loss:  2.872, mag loss:  6.316, div loss: 12.496, slim:  3.132, tlim:  1.729
#        valid loss: 70.613, imu loss:  3.020, mag loss: 49.069, div loss:  7.585, slim:  3.804, tlim:  3.202
# 04999: train loss: 32.124, imu loss:  2.858, mag loss:  5.493, div loss: 10.900, slim:  3.140, tlim:  1.584
#        valid loss: 71.805, imu loss:  3.011, mag loss: 49.970, div loss:  7.719, slim:  3.906, tlim:  3.212
# 05999: train loss: 29.521, imu loss:  2.845, mag loss:  4.980, div loss:  9.892, slim:  3.141, tlim:  1.502
#        valid loss: 72.338, imu loss:  3.014, mag loss: 50.210, div loss:  7.857, slim:  3.914, tlim:  3.230
# 06999: train loss: 27.472, imu loss:  2.824, mag loss:  4.572, div loss:  9.110, slim:  3.157, tlim:  1.422
#        valid loss: 73.632, imu loss:  3.023, mag loss: 50.915, div loss:  8.142, slim:  3.926, tlim:  3.237
# 07999: train loss: 26.285, imu loss:  2.814, mag loss:  4.327, div loss:  8.657, slim:  3.187, tlim:  1.376
#        valid loss: 74.121, imu loss:  3.030, mag loss: 50.891, div loss:  8.394, slim:  3.881, tlim:  3.256
# 08999: train loss: 24.783, imu loss:  2.801, mag loss:  4.062, div loss:  8.068, slim:  3.183, tlim:  1.319
#        valid loss: 74.271, imu loss:  3.038, mag loss: 51.038, div loss:  8.393, slim:  3.886, tlim:  3.250
# 09999: train loss: 23.944, imu loss:  2.785, mag loss:  3.898, div loss:  7.745, slim:  3.207, tlim:  1.290
#        valid loss: 74.015, imu loss:  3.045, mag loss: 50.932, div loss:  8.315, slim:  3.860, tlim:  3.258
# 10999: train loss: 23.014, imu loss:  2.766, mag loss:  3.710, div loss:  7.395, slim:  3.216, tlim:  1.258
#        valid loss: 73.306, imu loss:  3.054, mag loss: 50.107, div loss:  8.374, slim:  3.855, tlim:  3.243
# 11999: train loss: 22.420, imu loss:  2.760, mag loss:  3.599, div loss:  7.166, slim:  3.222, tlim:  1.230
#        valid loss: 73.688, imu loss:  3.055, mag loss: 50.767, div loss:  8.239, slim:  3.847, tlim:  3.235
# 12999: train loss: 21.748, imu loss:  2.746, mag loss:  3.454, div loss:  6.918, slim:  3.225, tlim:  1.206
#        valid loss: 74.377, imu loss:  3.057, mag loss: 51.389, div loss:  8.260, slim:  3.870, tlim:  3.259
# 13999: train loss: 21.257, imu loss:  2.742, mag loss:  3.372, div loss:  6.724, slim:  3.216, tlim:  1.188
#        valid loss: 73.755, imu loss:  3.055, mag loss: 50.754, div loss:  8.292, slim:  3.812, tlim:  3.212
# 14999: train loss: 20.633, imu loss:  2.729, mag loss:  3.247, div loss:  6.489, slim:  3.224, tlim:  1.163
#        valid loss: 73.802, imu loss:  3.067, mag loss: 50.861, div loss:  8.259, slim:  3.796, tlim:  3.208
# 15999: train loss: 20.256, imu loss:  2.716, mag loss:  3.180, div loss:  6.348, slim:  3.239, tlim:  1.140
#        valid loss: 74.227, imu loss:  3.074, mag loss: 51.120, div loss:  8.352, slim:  3.753, tlim:  3.189
# 16999: train loss: 19.909, imu loss:  2.705, mag loss:  3.115, div loss:  6.216, slim:  3.255, tlim:  1.125
#        valid loss: 74.582, imu loss:  3.077, mag loss: 50.895, div loss:  8.644, slim:  3.750, tlim:  3.177
# 17999: train loss: 19.573, imu loss:  2.703, mag loss:  3.043, div loss:  6.089, slim:  3.236, tlim:  1.119
#        valid loss: 74.730, imu loss:  3.090, mag loss: 51.221, div loss:  8.559, slim:  3.658, tlim:  3.181
# 18999: train loss: 19.128, imu loss:  2.683, mag loss:  2.987, div loss:  5.910, slim:  3.250, tlim:  1.101
#        valid loss: 74.670, imu loss:  3.097, mag loss: 51.278, div loss:  8.486, slim:  3.722, tlim:  3.190
# 19999: train loss: 18.706, imu loss:  2.678, mag loss:  2.894, div loss:  5.756, slim:  3.256, tlim:  1.079
#        valid loss: 75.063, imu loss:  3.103, mag loss: 51.153, div loss:  8.751, slim:  3.660, tlim:  3.188

# %%
show_result(model, train_loader)
# Out:
# (2424, 4) (2424, 2) (2424,)
#            loss name|   diff x   diff y      avg
#    front_pocket loss:     1.68     1.78     1.73
#          pocket loss:     1.65     1.77     1.71
#           swing loss:     1.42     1.43     1.42
#          target loss:     1.86     1.99     1.92
#         average loss:     1.65     1.74     1.70

# %%
show_result(model, valid_loader)
# Out:
# (272, 4) (272, 2) (272,)
#            loss name|   diff x   diff y      avg
#    front_pocket loss:    41.12    64.74    52.93
#          pocket loss:    28.64    60.75    44.69
#           swing loss:    29.44    68.79    49.12
#          target loss:    26.13    50.07    38.10
#         average loss:    31.33    61.09    46.21

# %%
torch.save(model, f'./model/ft_rotation/transformer_{num_of_axie}_{int(rotation)}.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Experiment 3
# rotation = True
# num_of_axie = 3 Different final ground truth (最終姿態)

# %%
num_of_axie, rotation = 3, True
posture_data = get_data(validation_traj, num_of_axie, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])
prep_valid_traj['ref_mag']      = split_traj(posture_data['ref_mag'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt='ref_mag')
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
# Out:
# {1: 'front_pocket', 2: 'pocket', 3: 'swing', 4: 'target', 0: 'ref_mag'}

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    
    draw = ((epoch + 1) % EPOCH == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw)
    
    if (epoch + 1) % 1000 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>6.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>6.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')
# Out:
# 00999: train loss: 61.601, imu loss:  2.962, mag loss: 11.223, div loss: 22.421, slim:  3.362, tlim:  2.312
#        valid loss: 59.566, imu loss:  3.046, mag loss: 39.471, div loss:  6.292, slim:  5.133, tlim:  4.242
# 01999: train loss: 43.557, imu loss:  2.915, mag loss:  7.673, div loss: 15.352, slim:  3.324, tlim:  1.913
#        valid loss: 58.978, imu loss:  3.014, mag loss: 38.152, div loss:  6.790, slim:  4.800, tlim:  4.043
# 02999: train loss: 35.889, imu loss:  2.882, mag loss:  6.189, div loss: 12.355, slim:  3.333, tlim:  1.702
#        valid loss: 59.078, imu loss:  3.010, mag loss: 37.426, div loss:  7.304, slim:  4.629, tlim:  3.834
# 03999: train loss: 30.429, imu loss:  2.857, mag loss:  5.125, div loss: 10.236, slim:  3.294, tlim:  1.534
#        valid loss: 58.477, imu loss:  3.012, mag loss: 36.542, div loss:  7.567, slim:  4.444, tlim:  3.573
# 04999: train loss: 26.772, imu loss:  2.844, mag loss:  4.420, div loss:  8.808, slim:  3.316, tlim:  1.417
#        valid loss: 57.427, imu loss:  3.014, mag loss: 35.453, div loss:  7.665, slim:  4.317, tlim:  3.400
# 05999: train loss: 24.212, imu loss:  2.826, mag loss:  3.914, div loss:  7.823, slim:  3.309, tlim:  1.332
#        valid loss: 56.542, imu loss:  3.011, mag loss: 34.987, div loss:  7.521, slim:  4.185, tlim:  3.273
# 06999: train loss: 22.541, imu loss:  2.816, mag loss:  3.615, div loss:  7.173, slim:  3.285, tlim:  1.258
#        valid loss: 56.241, imu loss:  3.014, mag loss: 34.688, div loss:  7.578, slim:  4.126, tlim:  3.136
# 07999: train loss: 21.009, imu loss:  2.796, mag loss:  3.306, div loss:  6.592, slim:  3.301, tlim:  1.197
#        valid loss: 56.016, imu loss:  3.015, mag loss: 34.580, div loss:  7.538, slim:  4.080, tlim:  3.101
# 08999: train loss: 19.965, imu loss:  2.781, mag loss:  3.112, div loss:  6.190, slim:  3.311, tlim:  1.152
#        valid loss: 56.541, imu loss:  3.017, mag loss: 34.961, div loss:  7.617, slim:  4.051, tlim:  3.088
# 09999: train loss: 19.115, imu loss:  2.775, mag loss:  2.939, div loss:  5.873, slim:  3.302, tlim:  1.107
#        valid loss: 56.314, imu loss:  3.029, mag loss: 34.832, div loss:  7.584, slim:  4.013, tlim:  3.042
# 10999: train loss: 18.235, imu loss:  2.756, mag loss:  2.766, div loss:  5.538, slim:  3.313, tlim:  1.077
#        valid loss: 56.436, imu loss:  3.045, mag loss: 34.903, div loss:  7.571, slim:  4.040, tlim:  3.113
# 11999: train loss: 17.711, imu loss:  2.742, mag loss:  2.682, div loss:  5.331, slim:  3.339, tlim:  1.053
#        valid loss: 56.686, imu loss:  3.062, mag loss: 34.678, div loss:  7.803, slim:  4.021, tlim:  3.114
# 12999: train loss: 16.947, imu loss:  2.729, mag loss:  2.536, div loss:  5.041, slim:  3.320, tlim:  1.026
#        valid loss: 57.662, imu loss:  3.069, mag loss: 35.293, div loss:  7.967, slim:  4.048, tlim:  3.140
# 13999: train loss: 16.454, imu loss:  2.719, mag loss:  2.444, div loss:  4.856, slim:  3.319, tlim:  0.999
#        valid loss: 57.804, imu loss:  3.076, mag loss: 35.064, div loss:  8.123, slim:  4.079, tlim:  3.197
# 14999: train loss: 16.203, imu loss:  2.711, mag loss:  2.383, div loss:  4.764, slim:  3.326, tlim:  0.999
#        valid loss: 57.803, imu loss:  3.079, mag loss: 35.046, div loss:  8.116, slim:  4.114, tlim:  3.221
# 15999: train loss: 15.612, imu loss:  2.703, mag loss:  2.277, div loss:  4.536, slim:  3.322, tlim:  0.972
#        valid loss: 58.154, imu loss:  3.079, mag loss: 35.229, div loss:  8.206, slim:  4.113, tlim:  3.206
# 16999: train loss: 15.341, imu loss:  2.682, mag loss:  2.229, div loss:  4.442, slim:  3.320, tlim:  0.954
#        valid loss: 59.144, imu loss:  3.088, mag loss: 35.716, div loss:  8.464, slim:  4.122, tlim:  3.176
# 17999: train loss: 14.797, imu loss:  2.669, mag loss:  2.126, div loss:  4.234, slim:  3.328, tlim:  0.936
#        valid loss: 58.913, imu loss:  3.090, mag loss: 35.526, div loss:  8.444, slim:  4.140, tlim:  3.165
# 18999: train loss: 14.550, imu loss:  2.667, mag loss:  2.079, div loss:  4.142, slim:  3.323, tlim:  0.921
#        valid loss: 58.963, imu loss:  3.090, mag loss: 35.597, div loss:  8.420, slim:  4.173, tlim:  3.188
# 19999: train loss: 14.447, imu loss:  2.651, mag loss:  2.062, div loss:  4.110, slim:  3.319, tlim:  0.912
#        valid loss: 58.992, imu loss:  3.091, mag loss: 35.439, div loss:  8.516, slim:  4.167, tlim:  3.184

# %%
show_result(model, train_loader)
# Out:
# (2424, 4) (2424, 3) (2424,)
#            loss name|   diff x   diff y   diff z      avg
#    front_pocket loss:     0.90     1.58     0.93     1.14
#          pocket loss:     0.95     1.11     1.00     1.02
#           swing loss:     0.73     0.88     0.72     0.78
#          target loss:     0.84     1.26     0.84     0.98
#         average loss:     0.86     1.21     0.87     0.98

# %%
show_result(model, valid_loader)
# Out:
# (272, 4) (272, 3) (272,)
#            loss name|   diff x   diff y   diff z      avg
#    front_pocket loss:    36.35    16.63    58.79    37.26
#          pocket loss:    17.65    20.68    57.40    31.91
#           swing loss:    17.55    21.82    49.39    29.59
#          target loss:    20.95    22.84    46.49    30.10
#         average loss:    23.13    20.50    53.02    32.21

# %%
torch.save(model, f'./model/ft_rotation/transformer_{num_of_axie}_{int(rotation)}.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Experiment 4
# rotation = False
# num_of_axie = 3 Different final ground truth (最終姿態)

# %%
num_of_axie, rotation = 3, False
posture_data = get_data(validation_traj, num_of_axie, rotation)
prep_valid_traj = defaultdict(np.array)

prep_valid_traj['front_pocket'] = split_traj(posture_data['front_pocket'])
prep_valid_traj['pocket']       = split_traj(posture_data['pocket'])
prep_valid_traj['swing']        = split_traj(posture_data['swing'])
prep_valid_traj['target']       = split_traj(posture_data['target'])
prep_valid_traj['ref_mag']      = split_traj(posture_data['ref_mag'])

classes, train_dataset, valid_dataset = for_dataloaders(prep_valid_traj, gt='ref_mag')
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

model = NotSimpleTransformer(seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
# Out:
# {1: 'front_pocket', 2: 'pocket', 3: 'swing', 4: 'target', 0: 'ref_mag'}

# %%
EPOCH = 20000
draw = False

for epoch in range(EPOCH):
    #####
    # 1. 用上半部訓練50epoch
    # 2. 隨機用上或下半部訓練Model
    # 3. 印出trajectory結果
    #####
    
    draw = ((epoch + 1) % EPOCH == 0)
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss, tlim_loss = train(train_loader, draw)
    
    if (epoch + 1) % 1000 == 0:
        valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss, vlim_loss = evalute(valid_loader, draw)
        print(f'{epoch:05d}: train loss: {train_loss:>6.3f}, imu loss: {train_imu_loss:>6.3f}, mag loss: {train_mag_loss:>6.3f}, div loss: {t_d1_loss:>6.3f}, slim: {tlim_loss[0]:>6.3f}, tlim: {tlim_loss[1]:>6.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss:>6.3f}, imu loss: {valid_imu_loss:>6.3f}, mag loss: {valid_mag_loss:>6.3f}, div loss: {v_d1_loss:>6.3f}, slim: {vlim_loss[0]:>6.3f}, tlim: {vlim_loss[1]:>6.3f}')
# Out:
# 00999: train loss: 66.741, imu loss:  2.980, mag loss: 12.278, div loss: 24.410, slim:  3.428, tlim:  2.407
#        valid loss: 59.304, imu loss:  3.048, mag loss: 38.826, div loss:  6.462, slim:  5.255, tlim:  4.256
# 01999: train loss: 44.888, imu loss:  2.919, mag loss:  7.945, div loss: 15.864, slim:  3.377, tlim:  1.937
#        valid loss: 62.549, imu loss:  3.021, mag loss: 40.301, div loss:  7.355, slim:  5.199, tlim:  4.291
# 02999: train loss: 36.089, imu loss:  2.889, mag loss:  6.222, div loss: 12.426, slim:  3.342, tlim:  1.721
#        valid loss: 62.380, imu loss:  3.006, mag loss: 39.973, div loss:  7.563, slim:  4.978, tlim:  4.041
# 03999: train loss: 31.072, imu loss:  2.865, mag loss:  5.239, div loss: 10.481, slim:  3.335, tlim:  1.565
#        valid loss: 62.126, imu loss:  3.008, mag loss: 39.569, div loss:  7.688, slim:  4.896, tlim:  3.933
# 04999: train loss: 27.260, imu loss:  2.846, mag loss:  4.511, div loss:  8.997, slim:  3.315, tlim:  1.441
#        valid loss: 63.359, imu loss:  3.006, mag loss: 40.117, div loss:  8.056, slim:  4.818, tlim:  3.891
# 05999: train loss: 24.899, imu loss:  2.832, mag loss:  4.060, div loss:  8.079, slim:  3.303, tlim:  1.363
#        valid loss: 64.284, imu loss:  3.006, mag loss: 40.228, div loss:  8.475, slim:  4.794, tlim:  3.869
# 06999: train loss: 23.258, imu loss:  2.815, mag loss:  3.718, div loss:  7.465, slim:  3.313, tlim:  1.290
#        valid loss: 64.643, imu loss:  3.005, mag loss: 40.290, div loss:  8.651, slim:  4.774, tlim:  3.803
# 07999: train loss: 21.808, imu loss:  2.802, mag loss:  3.464, div loss:  6.891, slim:  3.319, tlim:  1.241
#        valid loss: 64.266, imu loss:  3.012, mag loss: 40.018, div loss:  8.652, slim:  4.665, tlim:  3.688
# 08999: train loss: 20.458, imu loss:  2.789, mag loss:  3.201, div loss:  6.382, slim:  3.303, tlim:  1.171
#        valid loss: 64.724, imu loss:  3.019, mag loss: 40.096, div loss:  8.856, slim:  4.641, tlim:  3.649
# 09999: train loss: 19.495, imu loss:  2.775, mag loss:  3.008, div loss:  6.015, slim:  3.304, tlim:  1.142
#        valid loss: 65.441, imu loss:  3.024, mag loss: 40.545, div loss:  8.994, slim:  4.609, tlim:  3.642
# 10999: train loss: 18.564, imu loss:  2.765, mag loss:  2.838, div loss:  5.650, slim:  3.301, tlim:  1.113
#        valid loss: 64.600, imu loss:  3.038, mag loss: 40.087, div loss:  8.806, slim:  4.578, tlim:  3.625
# 11999: train loss: 17.835, imu loss:  2.752, mag loss:  2.696, div loss:  5.377, slim:  3.315, tlim:  1.074
#        valid loss: 64.125, imu loss:  3.049, mag loss: 39.676, div loss:  8.792, slim:  4.517, tlim:  3.582
# 12999: train loss: 17.429, imu loss:  2.739, mag loss:  2.617, div loss:  5.227, slim:  3.324, tlim:  1.052
#        valid loss: 63.694, imu loss:  3.057, mag loss: 39.581, div loss:  8.646, slim:  4.477, tlim:  3.526
# 13999: train loss: 16.865, imu loss:  2.730, mag loss:  2.511, div loss:  5.012, slim:  3.319, tlim:  1.028
#        valid loss: 63.827, imu loss:  3.070, mag loss: 39.506, div loss:  8.751, slim:  4.447, tlim:  3.515
# 14999: train loss: 16.357, imu loss:  2.721, mag loss:  2.405, div loss:  4.822, slim:  3.330, tlim:  1.005
#        valid loss: 63.663, imu loss:  3.079, mag loss: 39.251, div loss:  8.786, slim:  4.449, tlim:  3.532
# 15999: train loss: 15.787, imu loss:  2.711, mag loss:  2.313, div loss:  4.597, slim:  3.319, tlim:  0.986
#        valid loss: 63.591, imu loss:  3.096, mag loss: 39.339, div loss:  8.731, slim:  4.354, tlim:  3.474
# 16999: train loss: 15.688, imu loss:  2.706, mag loss:  2.286, div loss:  4.563, slim:  3.345, tlim:  0.979
#        valid loss: 62.767, imu loss:  3.093, mag loss: 38.653, div loss:  8.664, slim:  4.393, tlim:  3.460
# 17999: train loss: 15.395, imu loss:  2.687, mag loss:  2.235, div loss:  4.459, slim:  3.335, tlim:  0.962
#        valid loss: 63.977, imu loss:  3.096, mag loss: 39.522, div loss:  8.817, slim:  4.394, tlim:  3.501
# 18999: train loss: 15.032, imu loss:  2.679, mag loss:  2.172, div loss:  4.323, slim:  3.320, tlim:  0.941
#        valid loss: 63.606, imu loss:  3.098, mag loss: 39.277, div loss:  8.767, slim:  4.357, tlim:  3.477
# 19999: train loss: 14.691, imu loss:  2.671, mag loss:  2.111, div loss:  4.192, slim:  3.307, tlim:  0.933
#        valid loss: 63.183, imu loss:  3.103, mag loss: 39.037, div loss:  8.678, slim:  4.352, tlim:  3.464

# %%
show_result(model, train_loader)
# Out:
# (2424, 4) (2424, 3) (2424,)
#            loss name|   diff x   diff y   diff z      avg
#    front_pocket loss:     0.97     1.64     0.94     1.18
#          pocket loss:     0.78     0.95     0.91     0.88
#           swing loss:     0.67     0.80     0.72     0.73
#          target loss:     0.95     1.36     0.92     1.08
#         average loss:     0.84     1.19     0.87     0.97

# %%
show_result(model, valid_loader)
# Out:
# (272, 4) (272, 3) (272,)
#            loss name|   diff x   diff y   diff z      avg
#    front_pocket loss:    41.56    20.48    58.65    40.23
#          pocket loss:    26.24    15.83    67.76    36.61
#           swing loss:    19.08    21.07    57.85    32.67
#          target loss:    20.55    20.80    57.12    32.82
#         average loss:    26.86    19.55    60.35    35.58

# %%
torch.save(model, f'./model/ft_rotation/transformer_{num_of_axie}_{int(rotation)}.pt')
model.cpu()
del model, optimizer, train_loader, valid_loader, train_dataset, valid_dataset
gc.collect()
torch.cuda.empty_cache()
