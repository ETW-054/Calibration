# %%
import argparse
import os
import csv
import random
import time
import json
import math
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## Load data

# %%
training_traj = np.load(f'./training_traj_0.6.npy')
validation_traj = np.load(f'./kalman/all_user_match_data.npy', allow_pickle=True)

# %%
posture_data = defaultdict(list)

valid_data = validation_traj.item()
for user_name in valid_data.keys():
    for path_name in valid_data[user_name].keys():
        for posture_name in valid_data[user_name][path_name].keys():
            data = valid_data[user_name][path_name][posture_name]
            pos = (data[:, [0, 1]] + np.array((1, 1))) * 0.6
            mag = data[:, [6, 7, 8, 9, 10, 11, 12, 13, 14]]

            pos_mag = np.concatenate((pos, mag), axis=-1)
            posture_data[posture_name].append(pos_mag)

# %%
def split_traj(trajs, length=20):
    sp_traj = []
    for traj in trajs:
        for i in range(len(traj) - length + 1):
            sp_traj.append(traj[i:i+length])
    return np.array(sp_traj)

# %%
prep_training_traj = split_traj(training_traj)
prep_valid_front_pocket_traj = split_traj(posture_data['front_pocket'])
prep_valid_horizontal_traj = split_traj(posture_data['horizontal'])
prep_valid_pocket_traj = split_traj(posture_data['pocket'])
prep_valid_swing_traj = split_traj(posture_data['swing'])
prep_valid_target_traj = split_traj(posture_data['target'])
cali_valid_front_pocket_traj = np.load('pred_front_pocket_result.npy', allow_pickle=True)
cali_valid_horizontal_traj = np.load('pred_horizontal_result.npy', allow_pickle=True)
cali_valid_pocket_traj = np.load('pred_pocket_result.npy', allow_pickle=True)
cali_valid_swing_traj = np.load('pred_swing_result.npy', allow_pickle=True)

# %%
def expand_seq_features(seq):
    ### neighbors
    s_cord = seq[:, :, 0:2]
    s_mag = seq[:, :, -3:]
    
    s_magT = np.sqrt(np.power(s_mag[:, :, 0:1], 2) + np.power(s_mag[:, :, 1:2], 2) + np.power(s_mag[:, :, 2:3], 2))
    s_magH = np.sqrt(np.power(s_mag[:, :, 0:1], 2) + np.power(s_mag[:, :, 1:2], 2))  # magH
    s_elevation_angle = np.arccos(s_magH / s_magT) / np.pi * 180  # angle
    # n_azimuth_angle = 0
    
    print(s_cord.shape, s_mag.shape, s_magT.shape, s_magH.shape, s_elevation_angle.shape)
    s_new = np.concatenate([s_cord, s_mag, s_magT, s_magH, s_elevation_angle], axis=-1)
    
    return s_new

# %%
prep_training_traj = expand_seq_features(prep_training_traj)
prep_valid_front_pocket_traj = expand_seq_features(prep_valid_front_pocket_traj)
prep_valid_horizontal_traj = expand_seq_features(prep_valid_horizontal_traj)
prep_valid_pocket_traj = expand_seq_features(prep_valid_pocket_traj)
prep_valid_swing_traj = expand_seq_features(prep_valid_swing_traj)
prep_valid_target_traj = expand_seq_features(prep_valid_target_traj)
cali_valid_front_pocket_traj = expand_seq_features(cali_valid_front_pocket_traj)
cali_valid_horizontal_traj = expand_seq_features(cali_valid_horizontal_traj)
cali_valid_pocket_traj = expand_seq_features(cali_valid_pocket_traj)
cali_valid_swing_traj = expand_seq_features(cali_valid_swing_traj)
# Out:
# (310, 20, 2) (310, 20, 3) (310, 20, 1) (310, 20, 1) (310, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (674, 20, 2) (674, 20, 3) (674, 20, 1) (674, 20, 1) (674, 20, 1)
# (337, 20, 2) (337, 20, 3) (337, 20, 1) (337, 20, 1) (337, 20, 1)
# (337, 20, 2) (337, 20, 3) (337, 20, 1) (337, 20, 1) (337, 20, 1)
# (337, 20, 2) (337, 20, 3) (337, 20, 1) (337, 20, 1) (337, 20, 1)
# (337, 20, 2) (337, 20, 3) (337, 20, 1) (337, 20, 1) (337, 20, 1)

# %%
prep_valid_front_pocket_traj.shape, prep_valid_horizontal_traj.shape, prep_valid_pocket_traj.shape, prep_valid_swing_traj.shape, prep_valid_target_traj.shape
# Out:
# ((674, 20, 8), (674, 20, 8), (674, 20, 8), (674, 20, 8), (674, 20, 8))

# %%
prep_valid_target_traj[(np.arange(prep_valid_target_traj.shape[0])) % 10 != 0, :, 2:].shape
# Out:
# (606, 20, 6)

# %% [markdown]
# ## Create Dataset & Dataloader

# %%
class SequenceDataset(Dataset):
    def __init__(self, sequence, pos):
        self.sequence = sequence
        self.pos = pos

    def __len__(self):
        return len(self.sequence)

    def __getitem__(self, idx):
        return self.sequence[idx], self.pos[idx]

# %%
### train dataloader ###
train_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_target_traj[(np.arange(prep_valid_target_traj.shape[0])) % 10 != 0, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_target_traj[(np.arange(prep_valid_target_traj.shape[0])) % 10 != 0, -1, :2], dtype=torch.float)
                )
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)


### test dataloader ###
front_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_front_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_front_pocket_traj[:, -1, :2], dtype=torch.float)
                )
front_pocket_loader = DataLoader(front_pocket_dataset, batch_size=32)

horizontal_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_horizontal_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_horizontal_traj[:, -1, :2], dtype=torch.float)
                )
horizontal_loader = DataLoader(horizontal_dataset, batch_size=32)

pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_pocket_traj[:, -1, :2], dtype=torch.float)
                )
pocket_loader = DataLoader(pocket_dataset, batch_size=32)

swing_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_swing_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_swing_traj[:, -1, :2], dtype=torch.float)
                )
swing_loader = DataLoader(swing_dataset, batch_size=32)

target_dataset = SequenceDataset(
                    sequence=torch.tensor(prep_valid_target_traj[::10, :, 2:], dtype=torch.float),
                    pos=torch.tensor(prep_valid_target_traj[::10, -1, :2], dtype=torch.float)
                )
target_loader = DataLoader(target_dataset, batch_size=32)

c_front_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_front_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_front_pocket_traj[:, -1, :2], dtype=torch.float)
                )
c_front_pocket_loader = DataLoader(c_front_pocket_dataset, batch_size=32)

c_horizontal_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_horizontal_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_horizontal_traj[:, -1, :2], dtype=torch.float)
                )
c_horizontal_loader = DataLoader(c_horizontal_dataset, batch_size=32)

c_pocket_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_pocket_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_pocket_traj[:, -1, :2], dtype=torch.float)
                )
c_pocket_loader = DataLoader(c_pocket_dataset, batch_size=32)

c_swing_dataset = SequenceDataset(
                    sequence=torch.tensor(cali_valid_swing_traj[:, :, 2:], dtype=torch.float),
                    pos=torch.tensor(cali_valid_swing_traj[:, -1, :2], dtype=torch.float)
                )
c_swing_loader = DataLoader(c_swing_dataset, batch_size=32)

# %% [markdown]
# ## Model

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :].to(x.device)
        return self.dropout(x)
    

class NotSimpleTransformer(nn.Module):
    def __init__(self, seq_len=21, num_of_classes=2):
        super(NotSimpleTransformer, self).__init__()
        
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        
        self.imu_layer = nn.Sequential(
            nn.Linear(6, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 64),
            nn.LeakyReLU(),
        )
        self.mag_layer = nn.Sequential(
            nn.Linear(3, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 64),
            nn.LeakyReLU(),
        )
        self.pos_encoder = PositionalEncoding(64, 0.1)
        
        self.encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        self.nn = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 6),
            nn.LeakyReLU(),
        )
        
        self.decoder = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=64, nhead=8, dropout=0.1, batch_first=True), num_layers=1)
        
        self.mag_last = nn.Sequential(
            nn.Linear(64, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 3),
        )
        
    def forward(self, source_imu, source_mag):
        
        ### step 1
        h_imu = self.imu_layer(source_imu)
        h_imu = self.pos_encoder(h_imu)
        
        h_mag = self.mag_layer(source_mag)
        h_mag = self.pos_encoder(h_mag)
        
        ### step 2
        z = self.encoder(h_imu)
        z_imu = self.nn(z)
        
        ### step 3
        pred_latent = self.decoder(h_mag, z)
        pred_mag = self.mag_last(pred_latent)
        
        return z_imu, pred_mag

# %%
class Locator(nn.Module):
    def __init__(self, seq_len=60):
        super().__init__()
        
        self.lstm = nn.LSTM(input_size=3, hidden_size=32, num_layers=3, batch_first=True, bidirectional=False)
        
        self.last = nn.Sequential(
            nn.Linear(32, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 8),
            nn.LeakyReLU(),
            nn.Linear(8, 2),
        )
        
    def forward(self, features):
        h, _ = self.lstm(features)
        
        pos = self.last(h[:, -1])
        
        return pos

# %%
def train(dataloader):
    model.train()

    mse_loss = []
    l1_loss = []

    for sequences, gt_pos in dataloader:
        optimizer.zero_grad()
        
        sequences = sequences.to(device)
        gt_pos = gt_pos.to(device)
        
        # localization
        pred_pos = model(sequences[:, :, 2:5])
        
        # loss
        loss = MSE_Loss(pred_pos, gt_pos)
        
        # backward
        loss.backward()
        optimizer.step()
        
        # record loss
        mse_loss.append(loss.item())
        l1_loss.append(L1_loss(pred_pos, gt_pos).item())
    
    return np.mean(mse_loss), np.mean(l1_loss)

# %%
def evaluate(dataloader, calibrate=False):
    model.eval()

    mse_loss = []
    l1_loss = []

    with torch.no_grad():
        for sequences, gt_pos in dataloader:
            optimizer.zero_grad()
            
            sequences = sequences.to(device)
            gt_pos = gt_pos.to(device)

            # localization
            pred_pos = model(sequences[:, :, 2:5])

            # loss
            loss = MSE_Loss(pred_pos, gt_pos)

            # record loss
            mse_loss.append(loss.item())
            l1_loss.append(L1_loss(pred_pos, gt_pos).item())
    
    return np.mean(mse_loss), np.mean(l1_loss)

# %%
EPOCH = 10000
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
MSE_Loss = torch.nn.MSELoss()
L1_loss = torch.nn.L1Loss()

# %%
model = Locator().to(device)
# calibration = NotSimpleTransformer().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
from torchinfo import summary
summary(model, input_size=[(1, 20, 3)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Locator                                  [1, 2]                    --
# ├─LSTM: 1-1                              [1, 20, 32]               21,632
# ├─Sequential: 1-2                        [1, 2]                    --
# │    └─Linear: 2-1                       [1, 16]                   528
# │    └─LeakyReLU: 2-2                    [1, 16]                   --
# │    └─Linear: 2-3                       [1, 8]                    136
# │    └─LeakyReLU: 2-4                    [1, 8]                    --
# │    └─Linear: 2-5                       [1, 2]                    18
# ==========================================================================================
# Total params: 22,314
# Trainable params: 22,314
# Non-trainable params: 0
# Total mult-adds (M): 0.43
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ==========================================================================================

# %%
pos=['train', 'valid', 'front pocket', 'horizontal', 'pocket', 'swing']
for epoch in range(EPOCH):
    
    train_loss, train_l1 = train(train_loader)
#     train_loss, train_l1 = train(target_loader)
    
    if (epoch + 1) % 100 == 0:
        ep = str(epoch + 1).zfill(5)
        front_pocket_loss, front_pocket_l1 = evaluate(front_pocket_loader)
        horizontal_loss, horizontal_l1 = evaluate(horizontal_loader)
        pocket_loss, pocket_l1 = evaluate(pocket_loader)
        swing_loss, swing_l1 = evaluate(swing_loader)
        c_front_pocket_loss, c_front_pocket_l1 = evaluate(c_front_pocket_loader)
        c_horizontal_loss, c_horizontal_l1 = evaluate(c_horizontal_loader)
        c_pocket_loss, c_pocket_l1 = evaluate(c_pocket_loader)
        c_swing_loss, c_swing_l1 = evaluate(c_swing_loader)
        target_loss, target_l1 = evaluate(target_loader)
        print(f'{ep:>5}:   {pos[0]:>13} mse loss: {train_loss:>6.3f}, l1 loss: {train_l1:>6.3f}\t      valid mse loss: {target_loss:>6.3f}, l1 loss: {target_l1:>6.3f}')
        print(f'         {pos[2]:>13} mse loss: {front_pocket_loss:>6.3f}, l1 loss: {front_pocket_l1:>6.3f}\t calibrated mse loss: {c_front_pocket_loss:>6.3f}, l1 loss: {c_front_pocket_l1:>6.3f}')
        print(f'         {pos[3]:>13} mse loss: {horizontal_loss:>6.3f}, l1 loss: {horizontal_l1:>6.3f}\t calibrated mse loss: {c_horizontal_loss:>6.3f}, l1 loss: {c_horizontal_l1:>6.3f}')
        print(f'         {pos[4]:>13} mse loss: {pocket_loss:>6.3f}, l1 loss: {pocket_l1:>6.3f}\t calibrated mse loss: {c_pocket_loss:>6.3f}, l1 loss: {c_pocket_l1:>6.3f}')
        print(f'         {pos[5]:>13} mse loss: {swing_loss:>6.3f}, l1 loss: {swing_l1:>6.3f}\t calibrated mse loss: {c_swing_loss:>6.3f}, l1 loss: {c_swing_l1:>6.3f}')
#         print(f'{ep:>5}:  train mse loss: {train_loss: >6.3f}, l1 loss: {train_l1: >6.3f}     horizontal mse loss: {horizontal_loss: >6.3f}, l1 loss: {horizontal_l1: >6.3f}')  
#         print(f'        swing mse loss: {swing_loss: >6.3f}, l1 loss: {swing_l1: >6.3f}   front_pocket mse loss: {front_pocket_loss: >6.3f}, l1 loss: {front_pocket_l1: >6.3f}')
#         print(f'       pocket mse loss: {pocket_loss: >6.3f}, l1 loss: {pocket_l1: >6.3f}         target mse loss: {target_loss: >6.3f}, l1 loss: {target_l1: >6.3f}')
# Out:
# 00100:           train mse loss: 12.988, l1 loss:  3.057	      valid mse loss: 13.143, l1 loss:  3.104
#           front pocket mse loss: 19.119, l1 loss:  3.768	 calibrated mse loss: 13.203, l1 loss:  3.065
#             horizontal mse loss: 17.142, l1 loss:  3.499	 calibrated mse loss: 12.831, l1 loss:  3.049
#                 pocket mse loss: 18.150, l1 loss:  3.683	 calibrated mse loss: 12.889, l1 loss:  3.074
#                  swing mse loss: 19.343, l1 loss:  3.723	 calibrated mse loss: 12.813, l1 loss:  3.052
# 00200:           train mse loss:  8.630, l1 loss:  2.346	      valid mse loss:  9.424, l1 loss:  2.415
#           front pocket mse loss: 23.131, l1 loss:  3.872	 calibrated mse loss:  9.736, l1 loss:  2.485
#             horizontal mse loss: 18.581, l1 loss:  3.527	 calibrated mse loss: 10.089, l1 loss:  2.594
#                 pocket mse loss: 23.234, l1 loss:  3.877	 calibrated mse loss:  9.879, l1 loss:  2.565
#                  swing mse loss: 22.791, l1 loss:  3.874	 calibrated mse loss:  9.380, l1 loss:  2.479
# 00300:           train mse loss:  6.838, l1 loss:  2.045	      valid mse loss:  7.693, l1 loss:  2.195
#           front pocket mse loss: 23.419, l1 loss:  3.841	 calibrated mse loss:  8.235, l1 loss:  2.294
#             horizontal mse loss: 17.064, l1 loss:  3.409	 calibrated mse loss:  8.327, l1 loss:  2.331
#                 pocket mse loss: 25.243, l1 loss:  3.970	 calibrated mse loss:  8.472, l1 loss:  2.371
#                  swing mse loss: 24.317, l1 loss:  4.022	 calibrated mse loss:  7.692, l1 loss:  2.240
# 00400:           train mse loss:  5.328, l1 loss:  1.788	      valid mse loss:  6.496, l1 loss:  2.014
#           front pocket mse loss: 22.840, l1 loss:  3.832	 calibrated mse loss:  7.025, l1 loss:  2.097
#             horizontal mse loss: 17.119, l1 loss:  3.365	 calibrated mse loss:  7.391, l1 loss:  2.164
#                 pocket mse loss: 24.139, l1 loss:  3.906	 calibrated mse loss:  7.405, l1 loss:  2.187
#                  swing mse loss: 26.374, l1 loss:  4.211	 calibrated mse loss:  6.871, l1 loss:  2.098
# 00500:           train mse loss:  3.684, l1 loss:  1.441	      valid mse loss:  5.510, l1 loss:  1.763
#           front pocket mse loss: 23.982, l1 loss:  3.997	 calibrated mse loss:  5.414, l1 loss:  1.741
#             horizontal mse loss: 19.607, l1 loss:  3.581	 calibrated mse loss:  6.045, l1 loss:  1.895
#                 pocket mse loss: 23.250, l1 loss:  3.854	 calibrated mse loss:  5.821, l1 loss:  1.849
#                  swing mse loss: 28.772, l1 loss:  4.369	 calibrated mse loss:  5.253, l1 loss:  1.769
# 00600:           train mse loss:  2.711, l1 loss:  1.210	      valid mse loss:  4.449, l1 loss:  1.506
#           front pocket mse loss: 27.878, l1 loss:  4.283	 calibrated mse loss:  5.894, l1 loss:  1.800
#             horizontal mse loss: 20.719, l1 loss:  3.659	 calibrated mse loss:  6.109, l1 loss:  1.868
#                 pocket mse loss: 26.369, l1 loss:  4.122	 calibrated mse loss:  6.226, l1 loss:  1.906
#                  swing mse loss: 29.927, l1 loss:  4.484	 calibrated mse loss:  5.578, l1 loss:  1.777
# 00700:           train mse loss:  2.178, l1 loss:  1.067	      valid mse loss:  4.083, l1 loss:  1.405
#           front pocket mse loss: 28.955, l1 loss:  4.382	 calibrated mse loss:  6.309, l1 loss:  1.814
#             horizontal mse loss: 20.584, l1 loss:  3.655	 calibrated mse loss:  6.446, l1 loss:  1.888
#                 pocket mse loss: 27.395, l1 loss:  4.217	 calibrated mse loss:  6.666, l1 loss:  1.948
#                  swing mse loss: 30.044, l1 loss:  4.502	 calibrated mse loss:  5.961, l1 loss:  1.804
# 00800:           train mse loss:  1.811, l1 loss:  0.966	      valid mse loss:  2.327, l1 loss:  1.173
#           front pocket mse loss: 28.713, l1 loss:  4.401	 calibrated mse loss:  5.294, l1 loss:  1.649
#             horizontal mse loss: 22.269, l1 loss:  3.798	 calibrated mse loss:  5.728, l1 loss:  1.748
#                 pocket mse loss: 26.898, l1 loss:  4.200	 calibrated mse loss:  5.537, l1 loss:  1.743
#                  swing mse loss: 29.393, l1 loss:  4.456	 calibrated mse loss:  4.796, l1 loss:  1.603
# 00900:           train mse loss:  1.566, l1 loss:  0.899	      valid mse loss:  1.998, l1 loss:  1.093
#           front pocket mse loss: 28.572, l1 loss:  4.421	 calibrated mse loss:  5.343, l1 loss:  1.635
#             horizontal mse loss: 22.555, l1 loss:  3.820	 calibrated mse loss:  5.608, l1 loss:  1.717
#                 pocket mse loss: 27.244, l1 loss:  4.251	 calibrated mse loss:  5.336, l1 loss:  1.681
#                  swing mse loss: 29.151, l1 loss:  4.475	 calibrated mse loss:  4.532, l1 loss:  1.523
# 01000:           train mse loss:  1.293, l1 loss:  0.792	      valid mse loss:  1.491, l1 loss:  0.931
#           front pocket mse loss: 28.358, l1 loss:  4.403	 calibrated mse loss:  5.364, l1 loss:  1.611
#             horizontal mse loss: 22.012, l1 loss:  3.784	 calibrated mse loss:  5.644, l1 loss:  1.708
#                 pocket mse loss: 27.156, l1 loss:  4.253	 calibrated mse loss:  5.291, l1 loss:  1.668
#                  swing mse loss: 29.845, l1 loss:  4.528	 calibrated mse loss:  4.633, l1 loss:  1.524
# 01100:           train mse loss:  1.149, l1 loss:  0.737	      valid mse loss:  1.417, l1 loss:  0.880
#           front pocket mse loss: 29.177, l1 loss:  4.462	 calibrated mse loss:  4.697, l1 loss:  1.528
#             horizontal mse loss: 21.908, l1 loss:  3.777	 calibrated mse loss:  5.265, l1 loss:  1.630
#                 pocket mse loss: 27.610, l1 loss:  4.279	 calibrated mse loss:  4.721, l1 loss:  1.559
#                  swing mse loss: 30.212, l1 loss:  4.561	 calibrated mse loss:  4.231, l1 loss:  1.436
# 01200:           train mse loss:  1.018, l1 loss:  0.676	      valid mse loss:  1.257, l1 loss:  0.811
#           front pocket mse loss: 30.412, l1 loss:  4.537	 calibrated mse loss:  4.581, l1 loss:  1.510
#             horizontal mse loss: 22.278, l1 loss:  3.826	 calibrated mse loss:  5.324, l1 loss:  1.638
#                 pocket mse loss: 28.799, l1 loss:  4.359	 calibrated mse loss:  4.857, l1 loss:  1.582
#                  swing mse loss: 30.987, l1 loss:  4.603	 calibrated mse loss:  4.327, l1 loss:  1.455
# 01300:           train mse loss:  0.967, l1 loss:  0.662	      valid mse loss:  1.232, l1 loss:  0.792
#           front pocket mse loss: 31.344, l1 loss:  4.607	 calibrated mse loss:  4.655, l1 loss:  1.530
#             horizontal mse loss: 22.326, l1 loss:  3.830	 calibrated mse loss:  5.443, l1 loss:  1.650
#                 pocket mse loss: 29.415, l1 loss:  4.406	 calibrated mse loss:  5.082, l1 loss:  1.619
#                  swing mse loss: 31.616, l1 loss:  4.642	 calibrated mse loss:  4.396, l1 loss:  1.459
# 01400:           train mse loss:  0.921, l1 loss:  0.643	      valid mse loss:  1.396, l1 loss:  0.893
#           front pocket mse loss: 32.325, l1 loss:  4.667	 calibrated mse loss:  4.286, l1 loss:  1.459
#             horizontal mse loss: 22.222, l1 loss:  3.842	 calibrated mse loss:  5.335, l1 loss:  1.615
#                 pocket mse loss: 29.809, l1 loss:  4.429	 calibrated mse loss:  4.669, l1 loss:  1.565
#                  swing mse loss: 32.297, l1 loss:  4.685	 calibrated mse loss:  4.228, l1 loss:  1.416
# 01500:           train mse loss:  0.810, l1 loss:  0.595	      valid mse loss:  1.381, l1 loss:  0.865
#           front pocket mse loss: 32.624, l1 loss:  4.708	 calibrated mse loss:  3.814, l1 loss:  1.360
#             horizontal mse loss: 22.399, l1 loss:  3.877	 calibrated mse loss:  5.129, l1 loss:  1.564
#                 pocket mse loss: 29.877, l1 loss:  4.436	 calibrated mse loss:  4.278, l1 loss:  1.485
#                  swing mse loss: 32.732, l1 loss:  4.714	 calibrated mse loss:  3.892, l1 loss:  1.349
# 01600:           train mse loss:  0.758, l1 loss:  0.584	      valid mse loss:  1.275, l1 loss:  0.827
#           front pocket mse loss: 32.951, l1 loss:  4.721	 calibrated mse loss:  4.799, l1 loss:  1.488
#             horizontal mse loss: 21.927, l1 loss:  3.820	 calibrated mse loss:  5.528, l1 loss:  1.643
#                 pocket mse loss: 30.489, l1 loss:  4.485	 calibrated mse loss:  5.177, l1 loss:  1.642
#                  swing mse loss: 32.727, l1 loss:  4.716	 calibrated mse loss:  4.657, l1 loss:  1.472
# 01700:           train mse loss:  0.602, l1 loss:  0.489	      valid mse loss:  1.305, l1 loss:  0.836
#           front pocket mse loss: 33.284, l1 loss:  4.781	 calibrated mse loss:  3.893, l1 loss:  1.344
#             horizontal mse loss: 22.032, l1 loss:  3.836	 calibrated mse loss:  5.168, l1 loss:  1.557
#                 pocket mse loss: 30.423, l1 loss:  4.483	 calibrated mse loss:  4.204, l1 loss:  1.467
#                  swing mse loss: 32.864, l1 loss:  4.724	 calibrated mse loss:  3.805, l1 loss:  1.338
# 01800:           train mse loss:  0.563, l1 loss:  0.485	      valid mse loss:  0.986, l1 loss:  0.702
#           front pocket mse loss: 34.516, l1 loss:  4.865	 calibrated mse loss:  4.195, l1 loss:  1.367
#             horizontal mse loss: 21.794, l1 loss:  3.803	 calibrated mse loss:  5.134, l1 loss:  1.558
#                 pocket mse loss: 31.616, l1 loss:  4.580	 calibrated mse loss:  4.585, l1 loss:  1.526
#                  swing mse loss: 33.502, l1 loss:  4.775	 calibrated mse loss:  3.880, l1 loss:  1.349
# 01900:           train mse loss:  0.478, l1 loss:  0.436	      valid mse loss:  1.061, l1 loss:  0.737
#           front pocket mse loss: 35.350, l1 loss:  4.943	 calibrated mse loss:  4.024, l1 loss:  1.338
#             horizontal mse loss: 22.098, l1 loss:  3.822	 calibrated mse loss:  5.218, l1 loss:  1.560
#                 pocket mse loss: 32.391, l1 loss:  4.651	 calibrated mse loss:  4.383, l1 loss:  1.494
#                  swing mse loss: 33.792, l1 loss:  4.806	 calibrated mse loss:  3.834, l1 loss:  1.334
# 02000:           train mse loss:  0.428, l1 loss:  0.413	      valid mse loss:  1.010, l1 loss:  0.735
#           front pocket mse loss: 35.758, l1 loss:  4.990	 calibrated mse loss:  4.157, l1 loss:  1.352
#             horizontal mse loss: 21.951, l1 loss:  3.790	 calibrated mse loss:  5.323, l1 loss:  1.567
#                 pocket mse loss: 33.097, l1 loss:  4.717	 calibrated mse loss:  4.457, l1 loss:  1.487
#                  swing mse loss: 34.236, l1 loss:  4.839	 calibrated mse loss:  4.070, l1 loss:  1.348
# 02100:           train mse loss:  0.409, l1 loss:  0.412	      valid mse loss:  1.243, l1 loss:  0.782
#           front pocket mse loss: 35.949, l1 loss:  5.007	 calibrated mse loss:  3.837, l1 loss:  1.292
#             horizontal mse loss: 21.675, l1 loss:  3.778	 calibrated mse loss:  5.231, l1 loss:  1.538
#                 pocket mse loss: 33.915, l1 loss:  4.796	 calibrated mse loss:  4.100, l1 loss:  1.411
#                  swing mse loss: 34.459, l1 loss:  4.874	 calibrated mse loss:  3.683, l1 loss:  1.290
# 02200:           train mse loss:  0.344, l1 loss:  0.368	      valid mse loss:  0.805, l1 loss:  0.598
#           front pocket mse loss: 35.818, l1 loss:  5.008	 calibrated mse loss:  3.861, l1 loss:  1.294
#             horizontal mse loss: 21.720, l1 loss:  3.781	 calibrated mse loss:  5.171, l1 loss:  1.538
#                 pocket mse loss: 34.264, l1 loss:  4.842	 calibrated mse loss:  4.236, l1 loss:  1.437
#                  swing mse loss: 34.357, l1 loss:  4.870	 calibrated mse loss:  3.612, l1 loss:  1.283
# 02300:           train mse loss:  0.367, l1 loss:  0.397	      valid mse loss:  0.787, l1 loss:  0.635
#           front pocket mse loss: 36.178, l1 loss:  5.016	 calibrated mse loss:  3.522, l1 loss:  1.247
#             horizontal mse loss: 21.967, l1 loss:  3.824	 calibrated mse loss:  5.147, l1 loss:  1.489
#                 pocket mse loss: 34.633, l1 loss:  4.897	 calibrated mse loss:  3.994, l1 loss:  1.397
#                  swing mse loss: 35.122, l1 loss:  4.937	 calibrated mse loss:  3.328, l1 loss:  1.227
# 02400:           train mse loss:  0.255, l1 loss:  0.307	      valid mse loss:  0.760, l1 loss:  0.585
#           front pocket mse loss: 36.236, l1 loss:  5.020	 calibrated mse loss:  4.027, l1 loss:  1.307
#             horizontal mse loss: 21.573, l1 loss:  3.764	 calibrated mse loss:  5.442, l1 loss:  1.588
#                 pocket mse loss: 34.974, l1 loss:  4.927	 calibrated mse loss:  4.483, l1 loss:  1.483
#                  swing mse loss: 35.446, l1 loss:  4.971	 calibrated mse loss:  3.850, l1 loss:  1.310
# 02500:           train mse loss:  0.241, l1 loss:  0.311	      valid mse loss:  0.796, l1 loss:  0.604
#           front pocket mse loss: 36.203, l1 loss:  5.033	 calibrated mse loss:  3.945, l1 loss:  1.289
#             horizontal mse loss: 21.235, l1 loss:  3.741	 calibrated mse loss:  5.509, l1 loss:  1.587
#                 pocket mse loss: 34.983, l1 loss:  4.926	 calibrated mse loss:  4.429, l1 loss:  1.471
#                  swing mse loss: 35.528, l1 loss:  4.997	 calibrated mse loss:  3.683, l1 loss:  1.296
# 02600:           train mse loss:  0.233, l1 loss:  0.314	      valid mse loss:  0.651, l1 loss:  0.521
#           front pocket mse loss: 36.222, l1 loss:  5.048	 calibrated mse loss:  3.953, l1 loss:  1.295
#             horizontal mse loss: 20.967, l1 loss:  3.704	 calibrated mse loss:  5.487, l1 loss:  1.597
#                 pocket mse loss: 34.970, l1 loss:  4.929	 calibrated mse loss:  4.624, l1 loss:  1.517
#                  swing mse loss: 35.596, l1 loss:  5.006	 calibrated mse loss:  3.838, l1 loss:  1.313
# 02700:           train mse loss:  0.207, l1 loss:  0.299	      valid mse loss:  0.771, l1 loss:  0.569
#           front pocket mse loss: 36.145, l1 loss:  5.041	 calibrated mse loss:  3.450, l1 loss:  1.223
#             horizontal mse loss: 21.048, l1 loss:  3.737	 calibrated mse loss:  5.199, l1 loss:  1.531
#                 pocket mse loss: 35.474, l1 loss:  4.957	 calibrated mse loss:  4.042, l1 loss:  1.396
#                  swing mse loss: 35.493, l1 loss:  4.983	 calibrated mse loss:  3.144, l1 loss:  1.198
# 02800:           train mse loss:  0.164, l1 loss:  0.273	      valid mse loss:  0.668, l1 loss:  0.554
#           front pocket mse loss: 36.814, l1 loss:  5.081	 calibrated mse loss:  4.079, l1 loss:  1.320
#             horizontal mse loss: 20.490, l1 loss:  3.673	 calibrated mse loss:  5.404, l1 loss:  1.587
#                 pocket mse loss: 36.148, l1 loss:  5.005	 calibrated mse loss:  4.543, l1 loss:  1.495
#                  swing mse loss: 35.674, l1 loss:  5.004	 calibrated mse loss:  3.718, l1 loss:  1.276
# 02900:           train mse loss:  0.137, l1 loss:  0.258	      valid mse loss:  0.610, l1 loss:  0.526
#           front pocket mse loss: 37.584, l1 loss:  5.130	 calibrated mse loss:  3.753, l1 loss:  1.278
#             horizontal mse loss: 20.530, l1 loss:  3.686	 calibrated mse loss:  5.253, l1 loss:  1.561
#                 pocket mse loss: 36.918, l1 loss:  5.056	 calibrated mse loss:  4.303, l1 loss:  1.456
#                  swing mse loss: 35.992, l1 loss:  5.020	 calibrated mse loss:  3.334, l1 loss:  1.225
# 03000:           train mse loss:  0.113, l1 loss:  0.235	      valid mse loss:  0.675, l1 loss:  0.539
#           front pocket mse loss: 37.779, l1 loss:  5.141	 calibrated mse loss:  4.026, l1 loss:  1.308
#             horizontal mse loss: 20.084, l1 loss:  3.654	 calibrated mse loss:  5.202, l1 loss:  1.571
#                 pocket mse loss: 37.257, l1 loss:  5.071	 calibrated mse loss:  4.544, l1 loss:  1.486
#                  swing mse loss: 36.093, l1 loss:  5.030	 calibrated mse loss:  3.481, l1 loss:  1.247
# 03100:           train mse loss:  0.086, l1 loss:  0.208	      valid mse loss:  0.541, l1 loss:  0.474
#           front pocket mse loss: 38.219, l1 loss:  5.162	 calibrated mse loss:  3.642, l1 loss:  1.245
#             horizontal mse loss: 20.319, l1 loss:  3.678	 calibrated mse loss:  4.960, l1 loss:  1.519
#                 pocket mse loss: 37.410, l1 loss:  5.073	 calibrated mse loss:  4.269, l1 loss:  1.438
#                  swing mse loss: 36.329, l1 loss:  5.038	 calibrated mse loss:  3.225, l1 loss:  1.189
# 03200:           train mse loss:  0.074, l1 loss:  0.197	      valid mse loss:  0.568, l1 loss:  0.486
#           front pocket mse loss: 38.962, l1 loss:  5.210	 calibrated mse loss:  3.571, l1 loss:  1.236
#             horizontal mse loss: 20.357, l1 loss:  3.692	 calibrated mse loss:  4.949, l1 loss:  1.512
#                 pocket mse loss: 38.055, l1 loss:  5.117	 calibrated mse loss:  4.167, l1 loss:  1.418
#                  swing mse loss: 36.808, l1 loss:  5.072	 calibrated mse loss:  3.066, l1 loss:  1.170
# 03300:           train mse loss:  0.074, l1 loss:  0.196	      valid mse loss:  0.538, l1 loss:  0.498
#           front pocket mse loss: 39.604, l1 loss:  5.242	 calibrated mse loss:  3.858, l1 loss:  1.287
#             horizontal mse loss: 20.208, l1 loss:  3.657	 calibrated mse loss:  5.093, l1 loss:  1.540
#                 pocket mse loss: 38.364, l1 loss:  5.132	 calibrated mse loss:  4.456, l1 loss:  1.485
#                  swing mse loss: 37.061, l1 loss:  5.089	 calibrated mse loss:  3.456, l1 loss:  1.228
# 03400:           train mse loss:  0.058, l1 loss:  0.176	      valid mse loss:  0.510, l1 loss:  0.470
#           front pocket mse loss: 39.521, l1 loss:  5.235	 calibrated mse loss:  3.444, l1 loss:  1.219
#             horizontal mse loss: 20.361, l1 loss:  3.694	 calibrated mse loss:  4.785, l1 loss:  1.474
#                 pocket mse loss: 38.203, l1 loss:  5.115	 calibrated mse loss:  4.076, l1 loss:  1.404
#                  swing mse loss: 37.055, l1 loss:  5.086	 calibrated mse loss:  2.916, l1 loss:  1.130
# 03500:           train mse loss:  0.103, l1 loss:  0.239	      valid mse loss:  0.544, l1 loss:  0.496
#           front pocket mse loss: 38.919, l1 loss:  5.201	 calibrated mse loss:  3.362, l1 loss:  1.209
#             horizontal mse loss: 20.390, l1 loss:  3.690	 calibrated mse loss:  4.763, l1 loss:  1.480
#                 pocket mse loss: 37.670, l1 loss:  5.086	 calibrated mse loss:  3.969, l1 loss:  1.393
#                  swing mse loss: 36.530, l1 loss:  5.042	 calibrated mse loss:  2.839, l1 loss:  1.123
# 03600:           train mse loss:  0.065, l1 loss:  0.187	      valid mse loss:  0.554, l1 loss:  0.486
#           front pocket mse loss: 39.044, l1 loss:  5.205	 calibrated mse loss:  3.136, l1 loss:  1.167
#             horizontal mse loss: 20.541, l1 loss:  3.716	 calibrated mse loss:  4.508, l1 loss:  1.427
#                 pocket mse loss: 37.820, l1 loss:  5.092	 calibrated mse loss:  3.800, l1 loss:  1.351
#                  swing mse loss: 36.720, l1 loss:  5.056	 calibrated mse loss:  2.623, l1 loss:  1.083
# 03700:           train mse loss:  0.051, l1 loss:  0.167	      valid mse loss:  0.506, l1 loss:  0.477
#           front pocket mse loss: 39.063, l1 loss:  5.206	 calibrated mse loss:  3.299, l1 loss:  1.200
#             horizontal mse loss: 20.145, l1 loss:  3.669	 calibrated mse loss:  4.862, l1 loss:  1.485
#                 pocket mse loss: 37.455, l1 loss:  5.060	 calibrated mse loss:  3.987, l1 loss:  1.383
#                  swing mse loss: 36.701, l1 loss:  5.050	 calibrated mse loss:  2.870, l1 loss:  1.127
# 03800:           train mse loss:  0.039, l1 loss:  0.147	      valid mse loss:  0.447, l1 loss:  0.467
#           front pocket mse loss: 39.394, l1 loss:  5.227	 calibrated mse loss:  3.553, l1 loss:  1.239
#             horizontal mse loss: 19.999, l1 loss:  3.646	 calibrated mse loss:  4.856, l1 loss:  1.499
#                 pocket mse loss: 37.600, l1 loss:  5.067	 calibrated mse loss:  4.172, l1 loss:  1.424
#                  swing mse loss: 36.780, l1 loss:  5.055	 calibrated mse loss:  3.103, l1 loss:  1.164
# 03900:           train mse loss:  0.068, l1 loss:  0.192	      valid mse loss:  0.426, l1 loss:  0.428
#           front pocket mse loss: 38.610, l1 loss:  5.167	 calibrated mse loss:  3.250, l1 loss:  1.195
#             horizontal mse loss: 19.924, l1 loss:  3.643	 calibrated mse loss:  4.758, l1 loss:  1.473
#                 pocket mse loss: 36.893, l1 loss:  5.016	 calibrated mse loss:  3.964, l1 loss:  1.387
#                  swing mse loss: 36.430, l1 loss:  5.024	 calibrated mse loss:  2.807, l1 loss:  1.120
# 04000:           train mse loss:  0.061, l1 loss:  0.184	      valid mse loss:  0.606, l1 loss:  0.562
#           front pocket mse loss: 38.899, l1 loss:  5.181	 calibrated mse loss:  3.840, l1 loss:  1.292
#             horizontal mse loss: 19.655, l1 loss:  3.600	 calibrated mse loss:  5.161, l1 loss:  1.536
#                 pocket mse loss: 37.112, l1 loss:  5.031	 calibrated mse loss:  4.521, l1 loss:  1.507
#                  swing mse loss: 36.801, l1 loss:  5.055	 calibrated mse loss:  3.356, l1 loss:  1.229
# 04100:           train mse loss:  0.032, l1 loss:  0.131	      valid mse loss:  0.411, l1 loss:  0.410
#           front pocket mse loss: 38.817, l1 loss:  5.172	 calibrated mse loss:  3.326, l1 loss:  1.201
#             horizontal mse loss: 19.824, l1 loss:  3.631	 calibrated mse loss:  4.743, l1 loss:  1.461
#                 pocket mse loss: 37.004, l1 loss:  5.027	 calibrated mse loss:  4.095, l1 loss:  1.412
#                  swing mse loss: 36.804, l1 loss:  5.045	 calibrated mse loss:  2.895, l1 loss:  1.132
# 04200:           train mse loss:  0.062, l1 loss:  0.185	      valid mse loss:  0.437, l1 loss:  0.420
#           front pocket mse loss: 38.402, l1 loss:  5.150	 calibrated mse loss:  3.065, l1 loss:  1.149
#             horizontal mse loss: 19.788, l1 loss:  3.633	 calibrated mse loss:  4.558, l1 loss:  1.433
#                 pocket mse loss: 36.408, l1 loss:  4.991	 calibrated mse loss:  3.831, l1 loss:  1.353
#                  swing mse loss: 36.518, l1 loss:  5.019	 calibrated mse loss:  2.701, l1 loss:  1.088
# 04300:           train mse loss:  0.060, l1 loss:  0.180	      valid mse loss:  0.411, l1 loss:  0.427
#           front pocket mse loss: 38.419, l1 loss:  5.151	 calibrated mse loss:  3.010, l1 loss:  1.148
#             horizontal mse loss: 19.856, l1 loss:  3.634	 calibrated mse loss:  4.483, l1 loss:  1.423
#                 pocket mse loss: 36.520, l1 loss:  4.992	 calibrated mse loss:  3.733, l1 loss:  1.351
#                  swing mse loss: 36.371, l1 loss:  5.001	 calibrated mse loss:  2.612, l1 loss:  1.076
# 04400:           train mse loss:  0.064, l1 loss:  0.185	      valid mse loss:  0.417, l1 loss:  0.426
#           front pocket mse loss: 38.366, l1 loss:  5.137	 calibrated mse loss:  3.188, l1 loss:  1.190
#             horizontal mse loss: 19.727, l1 loss:  3.626	 calibrated mse loss:  4.695, l1 loss:  1.461
#                 pocket mse loss: 36.279, l1 loss:  4.964	 calibrated mse loss:  3.941, l1 loss:  1.392
#                  swing mse loss: 36.328, l1 loss:  4.993	 calibrated mse loss:  2.681, l1 loss:  1.100
# 04500:           train mse loss:  0.028, l1 loss:  0.124	      valid mse loss:  0.371, l1 loss:  0.398
#           front pocket mse loss: 38.178, l1 loss:  5.128	 calibrated mse loss:  3.189, l1 loss:  1.173
#             horizontal mse loss: 19.356, l1 loss:  3.588	 calibrated mse loss:  4.677, l1 loss:  1.439
#                 pocket mse loss: 36.090, l1 loss:  4.964	 calibrated mse loss:  3.978, l1 loss:  1.390
#                  swing mse loss: 36.408, l1 loss:  5.008	 calibrated mse loss:  2.847, l1 loss:  1.120
# 04600:           train mse loss:  0.051, l1 loss:  0.168	      valid mse loss:  0.414, l1 loss:  0.409
#           front pocket mse loss: 38.365, l1 loss:  5.137	 calibrated mse loss:  3.330, l1 loss:  1.199
#             horizontal mse loss: 19.636, l1 loss:  3.601	 calibrated mse loss:  4.608, l1 loss:  1.437
#                 pocket mse loss: 36.127, l1 loss:  4.958	 calibrated mse loss:  4.058, l1 loss:  1.413
#                  swing mse loss: 36.382, l1 loss:  5.004	 calibrated mse loss:  2.789, l1 loss:  1.120
# 04700:           train mse loss:  0.032, l1 loss:  0.134	      valid mse loss:  0.405, l1 loss:  0.393
#           front pocket mse loss: 37.721, l1 loss:  5.097	 calibrated mse loss:  3.024, l1 loss:  1.144
#             horizontal mse loss: 19.685, l1 loss:  3.613	 calibrated mse loss:  4.506, l1 loss:  1.416
#                 pocket mse loss: 35.084, l1 loss:  4.897	 calibrated mse loss:  3.759, l1 loss:  1.343
#                  swing mse loss: 36.059, l1 loss:  4.975	 calibrated mse loss:  2.651, l1 loss:  1.084
# 04800:           train mse loss:  0.022, l1 loss:  0.111	      valid mse loss:  0.365, l1 loss:  0.392
#           front pocket mse loss: 37.910, l1 loss:  5.111	 calibrated mse loss:  3.213, l1 loss:  1.174
#             horizontal mse loss: 19.628, l1 loss:  3.600	 calibrated mse loss:  4.616, l1 loss:  1.431
#                 pocket mse loss: 35.119, l1 loss:  4.892	 calibrated mse loss:  3.993, l1 loss:  1.397
#                  swing mse loss: 36.161, l1 loss:  4.981	 calibrated mse loss:  2.803, l1 loss:  1.118
# 04900:           train mse loss:  0.047, l1 loss:  0.160	      valid mse loss:  0.416, l1 loss:  0.464
#           front pocket mse loss: 37.788, l1 loss:  5.106	 calibrated mse loss:  3.363, l1 loss:  1.204
#             horizontal mse loss: 19.644, l1 loss:  3.598	 calibrated mse loss:  4.647, l1 loss:  1.441
#                 pocket mse loss: 34.850, l1 loss:  4.879	 calibrated mse loss:  4.093, l1 loss:  1.418
#                  swing mse loss: 36.082, l1 loss:  4.979	 calibrated mse loss:  2.959, l1 loss:  1.146
# 05000:           train mse loss:  0.023, l1 loss:  0.115	      valid mse loss:  0.333, l1 loss:  0.376
#           front pocket mse loss: 37.773, l1 loss:  5.104	 calibrated mse loss:  3.135, l1 loss:  1.162
#             horizontal mse loss: 19.311, l1 loss:  3.570	 calibrated mse loss:  4.634, l1 loss:  1.433
#                 pocket mse loss: 34.571, l1 loss:  4.859	 calibrated mse loss:  3.932, l1 loss:  1.384
#                  swing mse loss: 36.120, l1 loss:  4.978	 calibrated mse loss:  2.776, l1 loss:  1.110
# 05100:           train mse loss:  0.023, l1 loss:  0.109	      valid mse loss:  0.344, l1 loss:  0.391
#           front pocket mse loss: 37.947, l1 loss:  5.121	 calibrated mse loss:  3.234, l1 loss:  1.179
#             horizontal mse loss: 19.587, l1 loss:  3.590	 calibrated mse loss:  4.551, l1 loss:  1.421
#                 pocket mse loss: 34.582, l1 loss:  4.858	 calibrated mse loss:  4.008, l1 loss:  1.405
#                  swing mse loss: 35.960, l1 loss:  4.963	 calibrated mse loss:  2.842, l1 loss:  1.127
# 05200:           train mse loss:  0.023, l1 loss:  0.113	      valid mse loss:  0.354, l1 loss:  0.407
#           front pocket mse loss: 37.802, l1 loss:  5.109	 calibrated mse loss:  2.958, l1 loss:  1.128
#             horizontal mse loss: 19.704, l1 loss:  3.609	 calibrated mse loss:  4.352, l1 loss:  1.375
#                 pocket mse loss: 34.335, l1 loss:  4.845	 calibrated mse loss:  3.717, l1 loss:  1.341
#                  swing mse loss: 36.029, l1 loss:  4.966	 calibrated mse loss:  2.543, l1 loss:  1.059
# 05300:           train mse loss:  0.016, l1 loss:  0.094	      valid mse loss:  0.316, l1 loss:  0.361
#           front pocket mse loss: 37.705, l1 loss:  5.104	 calibrated mse loss:  3.031, l1 loss:  1.147
#             horizontal mse loss: 19.166, l1 loss:  3.558	 calibrated mse loss:  4.548, l1 loss:  1.414
#                 pocket mse loss: 33.903, l1 loss:  4.807	 calibrated mse loss:  3.850, l1 loss:  1.370
#                  swing mse loss: 35.835, l1 loss:  4.949	 calibrated mse loss:  2.664, l1 loss:  1.087
# 05400:           train mse loss:  0.046, l1 loss:  0.163	      valid mse loss:  0.335, l1 loss:  0.381
#           front pocket mse loss: 36.839, l1 loss:  5.052	 calibrated mse loss:  3.043, l1 loss:  1.146
#             horizontal mse loss: 19.583, l1 loss:  3.592	 calibrated mse loss:  4.480, l1 loss:  1.406
#                 pocket mse loss: 33.455, l1 loss:  4.778	 calibrated mse loss:  3.866, l1 loss:  1.375
#                  swing mse loss: 35.224, l1 loss:  4.914	 calibrated mse loss:  2.775, l1 loss:  1.116
# 05500:           train mse loss:  0.014, l1 loss:  0.089	      valid mse loss:  0.336, l1 loss:  0.374
#           front pocket mse loss: 37.617, l1 loss:  5.105	 calibrated mse loss:  2.894, l1 loss:  1.126
#             horizontal mse loss: 19.696, l1 loss:  3.607	 calibrated mse loss:  4.342, l1 loss:  1.386
#                 pocket mse loss: 33.836, l1 loss:  4.806	 calibrated mse loss:  3.659, l1 loss:  1.338
#                  swing mse loss: 35.582, l1 loss:  4.930	 calibrated mse loss:  2.549, l1 loss:  1.072
# 05600:           train mse loss:  0.025, l1 loss:  0.118	      valid mse loss:  0.345, l1 loss:  0.403
#           front pocket mse loss: 37.529, l1 loss:  5.098	 calibrated mse loss:  3.021, l1 loss:  1.150
#             horizontal mse loss: 19.250, l1 loss:  3.571	 calibrated mse loss:  4.619, l1 loss:  1.425
#                 pocket mse loss: 33.733, l1 loss:  4.804	 calibrated mse loss:  3.884, l1 loss:  1.383
#                  swing mse loss: 35.803, l1 loss:  4.950	 calibrated mse loss:  2.757, l1 loss:  1.112
# 05700:           train mse loss:  0.020, l1 loss:  0.104	      valid mse loss:  0.328, l1 loss:  0.368
#           front pocket mse loss: 37.513, l1 loss:  5.099	 calibrated mse loss:  2.958, l1 loss:  1.131
#             horizontal mse loss: 19.540, l1 loss:  3.589	 calibrated mse loss:  4.391, l1 loss:  1.388
#                 pocket mse loss: 33.416, l1 loss:  4.776	 calibrated mse loss:  3.762, l1 loss:  1.362
#                  swing mse loss: 35.519, l1 loss:  4.921	 calibrated mse loss:  2.691, l1 loss:  1.103
# 05800:           train mse loss:  0.016, l1 loss:  0.096	      valid mse loss:  0.304, l1 loss:  0.335
#           front pocket mse loss: 37.598, l1 loss:  5.105	 calibrated mse loss:  2.920, l1 loss:  1.122
#             horizontal mse loss: 19.468, l1 loss:  3.579	 calibrated mse loss:  4.382, l1 loss:  1.386
#                 pocket mse loss: 33.492, l1 loss:  4.790	 calibrated mse loss:  3.680, l1 loss:  1.341
#                  swing mse loss: 35.658, l1 loss:  4.933	 calibrated mse loss:  2.607, l1 loss:  1.078
# 05900:           train mse loss:  0.019, l1 loss:  0.104	      valid mse loss:  0.306, l1 loss:  0.355
#           front pocket mse loss: 37.945, l1 loss:  5.118	 calibrated mse loss:  3.090, l1 loss:  1.149
#             horizontal mse loss: 19.354, l1 loss:  3.560	 calibrated mse loss:  4.512, l1 loss:  1.401
#                 pocket mse loss: 33.818, l1 loss:  4.811	 calibrated mse loss:  3.877, l1 loss:  1.380
#                  swing mse loss: 35.800, l1 loss:  4.945	 calibrated mse loss:  2.784, l1 loss:  1.120
# 06000:           train mse loss:  0.011, l1 loss:  0.079	      valid mse loss:  0.334, l1 loss:  0.365
#           front pocket mse loss: 37.700, l1 loss:  5.108	 calibrated mse loss:  2.807, l1 loss:  1.102
#             horizontal mse loss: 19.491, l1 loss:  3.584	 calibrated mse loss:  4.286, l1 loss:  1.362
#                 pocket mse loss: 33.450, l1 loss:  4.783	 calibrated mse loss:  3.542, l1 loss:  1.314
#                  swing mse loss: 35.637, l1 loss:  4.922	 calibrated mse loss:  2.492, l1 loss:  1.055
# 06100:           train mse loss:  0.035, l1 loss:  0.137	      valid mse loss:  0.445, l1 loss:  0.459
#           front pocket mse loss: 37.193, l1 loss:  5.082	 calibrated mse loss:  2.562, l1 loss:  1.059
#             horizontal mse loss: 19.637, l1 loss:  3.596	 calibrated mse loss:  4.177, l1 loss:  1.351
#                 pocket mse loss: 32.525, l1 loss:  4.718	 calibrated mse loss:  3.287, l1 loss:  1.255
#                  swing mse loss: 35.145, l1 loss:  4.885	 calibrated mse loss:  2.402, l1 loss:  1.042
# 06200:           train mse loss:  0.024, l1 loss:  0.115	      valid mse loss:  0.317, l1 loss:  0.352
#           front pocket mse loss: 37.611, l1 loss:  5.100	 calibrated mse loss:  2.970, l1 loss:  1.140
#             horizontal mse loss: 19.455, l1 loss:  3.568	 calibrated mse loss:  4.365, l1 loss:  1.396
#                 pocket mse loss: 32.983, l1 loss:  4.736	 calibrated mse loss:  3.650, l1 loss:  1.346
#                  swing mse loss: 35.316, l1 loss:  4.897	 calibrated mse loss:  2.653, l1 loss:  1.101
# 06300:           train mse loss:  0.011, l1 loss:  0.082	      valid mse loss:  0.295, l1 loss:  0.340
#           front pocket mse loss: 38.014, l1 loss:  5.127	 calibrated mse loss:  2.858, l1 loss:  1.110
#             horizontal mse loss: 19.411, l1 loss:  3.572	 calibrated mse loss:  4.338, l1 loss:  1.375
#                 pocket mse loss: 33.387, l1 loss:  4.776	 calibrated mse loss:  3.616, l1 loss:  1.326
#                  swing mse loss: 35.602, l1 loss:  4.914	 calibrated mse loss:  2.532, l1 loss:  1.062
# 06400:           train mse loss:  0.015, l1 loss:  0.095	      valid mse loss:  0.314, l1 loss:  0.379
#           front pocket mse loss: 38.127, l1 loss:  5.132	 calibrated mse loss:  3.124, l1 loss:  1.156
#             horizontal mse loss: 19.409, l1 loss:  3.556	 calibrated mse loss:  4.556, l1 loss:  1.405
#                 pocket mse loss: 33.498, l1 loss:  4.777	 calibrated mse loss:  3.887, l1 loss:  1.390
#                  swing mse loss: 35.533, l1 loss:  4.911	 calibrated mse loss:  2.809, l1 loss:  1.131
# 06500:           train mse loss:  0.011, l1 loss:  0.078	      valid mse loss:  0.307, l1 loss:  0.341
#           front pocket mse loss: 37.807, l1 loss:  5.112	 calibrated mse loss:  2.742, l1 loss:  1.088
#             horizontal mse loss: 19.443, l1 loss:  3.579	 calibrated mse loss:  4.233, l1 loss:  1.358
#                 pocket mse loss: 33.115, l1 loss:  4.752	 calibrated mse loss:  3.441, l1 loss:  1.287
#                  swing mse loss: 35.506, l1 loss:  4.904	 calibrated mse loss:  2.388, l1 loss:  1.029
# 06600:           train mse loss:  0.007, l1 loss:  0.061	      valid mse loss:  0.309, l1 loss:  0.340
#           front pocket mse loss: 37.940, l1 loss:  5.122	 calibrated mse loss:  2.789, l1 loss:  1.098
#             horizontal mse loss: 19.404, l1 loss:  3.571	 calibrated mse loss:  4.257, l1 loss:  1.358
#                 pocket mse loss: 33.181, l1 loss:  4.754	 calibrated mse loss:  3.467, l1 loss:  1.300
#                  swing mse loss: 35.447, l1 loss:  4.899	 calibrated mse loss:  2.463, l1 loss:  1.047
# 06700:           train mse loss:  0.024, l1 loss:  0.116	      valid mse loss:  0.282, l1 loss:  0.340
#           front pocket mse loss: 38.073, l1 loss:  5.132	 calibrated mse loss:  2.966, l1 loss:  1.128
#             horizontal mse loss: 19.098, l1 loss:  3.530	 calibrated mse loss:  4.539, l1 loss:  1.404
#                 pocket mse loss: 32.961, l1 loss:  4.736	 calibrated mse loss:  3.724, l1 loss:  1.350
#                  swing mse loss: 35.284, l1 loss:  4.882	 calibrated mse loss:  2.736, l1 loss:  1.100
# 06800:           train mse loss:  0.011, l1 loss:  0.082	      valid mse loss:  0.290, l1 loss:  0.322
#           front pocket mse loss: 38.152, l1 loss:  5.134	 calibrated mse loss:  2.865, l1 loss:  1.112
#             horizontal mse loss: 19.375, l1 loss:  3.562	 calibrated mse loss:  4.230, l1 loss:  1.360
#                 pocket mse loss: 33.096, l1 loss:  4.737	 calibrated mse loss:  3.520, l1 loss:  1.311
#                  swing mse loss: 35.327, l1 loss:  4.883	 calibrated mse loss:  2.521, l1 loss:  1.063
# 06900:           train mse loss:  0.017, l1 loss:  0.095	      valid mse loss:  0.322, l1 loss:  0.363
#           front pocket mse loss: 38.113, l1 loss:  5.131	 calibrated mse loss:  2.826, l1 loss:  1.099
#             horizontal mse loss: 19.542, l1 loss:  3.580	 calibrated mse loss:  4.221, l1 loss:  1.350
#                 pocket mse loss: 32.988, l1 loss:  4.737	 calibrated mse loss:  3.516, l1 loss:  1.312
#                  swing mse loss: 35.463, l1 loss:  4.892	 calibrated mse loss:  2.492, l1 loss:  1.053
# 07000:           train mse loss:  0.011, l1 loss:  0.080	      valid mse loss:  0.287, l1 loss:  0.329
#           front pocket mse loss: 38.134, l1 loss:  5.127	 calibrated mse loss:  2.757, l1 loss:  1.084
#             horizontal mse loss: 19.245, l1 loss:  3.554	 calibrated mse loss:  4.299, l1 loss:  1.361
#                 pocket mse loss: 33.003, l1 loss:  4.725	 calibrated mse loss:  3.418, l1 loss:  1.286
#                  swing mse loss: 35.314, l1 loss:  4.875	 calibrated mse loss:  2.446, l1 loss:  1.040
# 07100:           train mse loss:  0.009, l1 loss:  0.069	      valid mse loss:  0.309, l1 loss:  0.329
#           front pocket mse loss: 38.092, l1 loss:  5.128	 calibrated mse loss:  2.711, l1 loss:  1.077
#             horizontal mse loss: 19.447, l1 loss:  3.569	 calibrated mse loss:  4.209, l1 loss:  1.344
#                 pocket mse loss: 32.860, l1 loss:  4.718	 calibrated mse loss:  3.362, l1 loss:  1.277
#                  swing mse loss: 35.306, l1 loss:  4.876	 calibrated mse loss:  2.385, l1 loss:  1.028
# 07200:           train mse loss:  0.016, l1 loss:  0.093	      valid mse loss:  0.305, l1 loss:  0.369
#           front pocket mse loss: 38.127, l1 loss:  5.119	 calibrated mse loss:  2.912, l1 loss:  1.113
#             horizontal mse loss: 19.420, l1 loss:  3.568	 calibrated mse loss:  4.401, l1 loss:  1.379
#                 pocket mse loss: 33.152, l1 loss:  4.734	 calibrated mse loss:  3.588, l1 loss:  1.326
#                  swing mse loss: 35.398, l1 loss:  4.884	 calibrated mse loss:  2.525, l1 loss:  1.064
# 07300:           train mse loss:  0.014, l1 loss:  0.086	      valid mse loss:  0.303, l1 loss:  0.344
#           front pocket mse loss: 38.113, l1 loss:  5.130	 calibrated mse loss:  2.862, l1 loss:  1.108
#             horizontal mse loss: 19.483, l1 loss:  3.565	 calibrated mse loss:  4.184, l1 loss:  1.342
#                 pocket mse loss: 33.128, l1 loss:  4.723	 calibrated mse loss:  3.492, l1 loss:  1.307
#                  swing mse loss: 35.321, l1 loss:  4.878	 calibrated mse loss:  2.468, l1 loss:  1.052
# 07400:           train mse loss:  0.014, l1 loss:  0.090	      valid mse loss:  0.285, l1 loss:  0.340
#           front pocket mse loss: 38.021, l1 loss:  5.113	 calibrated mse loss:  2.751, l1 loss:  1.088
#             horizontal mse loss: 19.320, l1 loss:  3.558	 calibrated mse loss:  4.228, l1 loss:  1.347
#                 pocket mse loss: 32.836, l1 loss:  4.689	 calibrated mse loss:  3.394, l1 loss:  1.285
#                  swing mse loss: 35.343, l1 loss:  4.879	 calibrated mse loss:  2.380, l1 loss:  1.031
# 07500:           train mse loss:  0.014, l1 loss:  0.088	      valid mse loss:  0.292, l1 loss:  0.331
#           front pocket mse loss: 37.947, l1 loss:  5.116	 calibrated mse loss:  2.685, l1 loss:  1.074
#             horizontal mse loss: 19.318, l1 loss:  3.554	 calibrated mse loss:  4.203, l1 loss:  1.343
#                 pocket mse loss: 32.661, l1 loss:  4.662	 calibrated mse loss:  3.334, l1 loss:  1.270
#                  swing mse loss: 35.523, l1 loss:  4.894	 calibrated mse loss:  2.349, l1 loss:  1.018
# 07600:           train mse loss:  0.007, l1 loss:  0.065	      valid mse loss:  0.293, l1 loss:  0.339
#           front pocket mse loss: 38.235, l1 loss:  5.132	 calibrated mse loss:  2.913, l1 loss:  1.113
#             horizontal mse loss: 19.360, l1 loss:  3.548	 calibrated mse loss:  4.391, l1 loss:  1.367
#                 pocket mse loss: 32.890, l1 loss:  4.683	 calibrated mse loss:  3.569, l1 loss:  1.323
#                  swing mse loss: 35.487, l1 loss:  4.891	 calibrated mse loss:  2.591, l1 loss:  1.068
# 07700:           train mse loss:  0.017, l1 loss:  0.098	      valid mse loss:  0.275, l1 loss:  0.319
#           front pocket mse loss: 37.963, l1 loss:  5.112	 calibrated mse loss:  2.811, l1 loss:  1.092
#             horizontal mse loss: 19.380, l1 loss:  3.554	 calibrated mse loss:  4.256, l1 loss:  1.353
#                 pocket mse loss: 32.532, l1 loss:  4.646	 calibrated mse loss:  3.388, l1 loss:  1.283
#                  swing mse loss: 35.411, l1 loss:  4.880	 calibrated mse loss:  2.478, l1 loss:  1.045
# 07800:           train mse loss:  0.015, l1 loss:  0.092	      valid mse loss:  0.300, l1 loss:  0.339
#           front pocket mse loss: 37.659, l1 loss:  5.087	 calibrated mse loss:  2.735, l1 loss:  1.084
#             horizontal mse loss: 19.411, l1 loss:  3.555	 calibrated mse loss:  4.179, l1 loss:  1.340
#                 pocket mse loss: 32.304, l1 loss:  4.621	 calibrated mse loss:  3.408, l1 loss:  1.292
#                  swing mse loss: 35.537, l1 loss:  4.894	 calibrated mse loss:  2.424, l1 loss:  1.039
# 07900:           train mse loss:  0.016, l1 loss:  0.094	      valid mse loss:  0.309, l1 loss:  0.358
#           front pocket mse loss: 37.999, l1 loss:  5.102	 calibrated mse loss:  2.765, l1 loss:  1.090
#             horizontal mse loss: 19.335, l1 loss:  3.545	 calibrated mse loss:  4.289, l1 loss:  1.362
#                 pocket mse loss: 32.138, l1 loss:  4.600	 calibrated mse loss:  3.424, l1 loss:  1.292
#                  swing mse loss: 35.928, l1 loss:  4.921	 calibrated mse loss:  2.406, l1 loss:  1.033
# 08000:           train mse loss:  0.006, l1 loss:  0.059	      valid mse loss:  0.284, l1 loss:  0.322
#           front pocket mse loss: 38.100, l1 loss:  5.118	 calibrated mse loss:  2.715, l1 loss:  1.078
#             horizontal mse loss: 19.363, l1 loss:  3.551	 calibrated mse loss:  4.265, l1 loss:  1.352
#                 pocket mse loss: 31.868, l1 loss:  4.582	 calibrated mse loss:  3.359, l1 loss:  1.283
#                  swing mse loss: 35.863, l1 loss:  4.923	 calibrated mse loss:  2.411, l1 loss:  1.034
# 08100:           train mse loss:  0.006, l1 loss:  0.057	      valid mse loss:  0.294, l1 loss:  0.332
#           front pocket mse loss: 38.147, l1 loss:  5.122	 calibrated mse loss:  2.780, l1 loss:  1.083
#             horizontal mse loss: 19.333, l1 loss:  3.552	 calibrated mse loss:  4.252, l1 loss:  1.345
#                 pocket mse loss: 31.821, l1 loss:  4.570	 calibrated mse loss:  3.395, l1 loss:  1.284
#                  swing mse loss: 35.939, l1 loss:  4.932	 calibrated mse loss:  2.417, l1 loss:  1.033
# 08200:           train mse loss:  0.020, l1 loss:  0.105	      valid mse loss:  0.362, l1 loss:  0.383
#           front pocket mse loss: 38.290, l1 loss:  5.125	 calibrated mse loss:  2.755, l1 loss:  1.088
#             horizontal mse loss: 19.631, l1 loss:  3.571	 calibrated mse loss:  4.103, l1 loss:  1.324
#                 pocket mse loss: 32.090, l1 loss:  4.585	 calibrated mse loss:  3.392, l1 loss:  1.283
#                  swing mse loss: 36.058, l1 loss:  4.937	 calibrated mse loss:  2.355, l1 loss:  1.020
# 08300:           train mse loss:  0.013, l1 loss:  0.087	      valid mse loss:  0.294, l1 loss:  0.322
#           front pocket mse loss: 38.245, l1 loss:  5.124	 calibrated mse loss:  2.742, l1 loss:  1.082
#             horizontal mse loss: 19.372, l1 loss:  3.545	 calibrated mse loss:  4.161, l1 loss:  1.326
#                 pocket mse loss: 32.346, l1 loss:  4.600	 calibrated mse loss:  3.323, l1 loss:  1.274
#                  swing mse loss: 36.052, l1 loss:  4.932	 calibrated mse loss:  2.371, l1 loss:  1.024
# 08400:           train mse loss:  0.008, l1 loss:  0.069	      valid mse loss:  0.283, l1 loss:  0.316
#           front pocket mse loss: 38.381, l1 loss:  5.121	 calibrated mse loss:  2.699, l1 loss:  1.072
#             horizontal mse loss: 19.341, l1 loss:  3.539	 calibrated mse loss:  4.264, l1 loss:  1.345
#                 pocket mse loss: 32.446, l1 loss:  4.592	 calibrated mse loss:  3.290, l1 loss:  1.268
#                  swing mse loss: 36.416, l1 loss:  4.952	 calibrated mse loss:  2.363, l1 loss:  1.027
# 08500:           train mse loss:  0.015, l1 loss:  0.093	      valid mse loss:  0.301, l1 loss:  0.324
#           front pocket mse loss: 38.169, l1 loss:  5.104	 calibrated mse loss:  2.573, l1 loss:  1.046
#             horizontal mse loss: 19.464, l1 loss:  3.553	 calibrated mse loss:  4.069, l1 loss:  1.308
#                 pocket mse loss: 32.229, l1 loss:  4.570	 calibrated mse loss:  3.143, l1 loss:  1.231
#                  swing mse loss: 36.299, l1 loss:  4.935	 calibrated mse loss:  2.247, l1 loss:  0.993
# 08600:           train mse loss:  0.013, l1 loss:  0.085	      valid mse loss:  0.291, l1 loss:  0.323
#           front pocket mse loss: 38.236, l1 loss:  5.100	 calibrated mse loss:  2.831, l1 loss:  1.091
#             horizontal mse loss: 19.321, l1 loss:  3.533	 calibrated mse loss:  4.320, l1 loss:  1.350
#                 pocket mse loss: 32.118, l1 loss:  4.555	 calibrated mse loss:  3.450, l1 loss:  1.297
#                  swing mse loss: 36.268, l1 loss:  4.921	 calibrated mse loss:  2.502, l1 loss:  1.052
# 08700:           train mse loss:  0.003, l1 loss:  0.042	      valid mse loss:  0.296, l1 loss:  0.318
#           front pocket mse loss: 37.974, l1 loss:  5.081	 calibrated mse loss:  2.581, l1 loss:  1.053
#             horizontal mse loss: 19.172, l1 loss:  3.531	 calibrated mse loss:  4.173, l1 loss:  1.328
#                 pocket mse loss: 31.967, l1 loss:  4.539	 calibrated mse loss:  3.177, l1 loss:  1.242
#                  swing mse loss: 36.151, l1 loss:  4.904	 calibrated mse loss:  2.281, l1 loss:  1.005
# 08800:           train mse loss:  0.006, l1 loss:  0.058	      valid mse loss:  0.279, l1 loss:  0.327
#           front pocket mse loss: 38.114, l1 loss:  5.085	 calibrated mse loss:  2.626, l1 loss:  1.064
#             horizontal mse loss: 19.377, l1 loss:  3.546	 calibrated mse loss:  4.158, l1 loss:  1.329
#                 pocket mse loss: 32.190, l1 loss:  4.554	 calibrated mse loss:  3.249, l1 loss:  1.258
#                  swing mse loss: 36.246, l1 loss:  4.906	 calibrated mse loss:  2.311, l1 loss:  1.017
# 08900:           train mse loss:  0.017, l1 loss:  0.097	      valid mse loss:  0.300, l1 loss:  0.354
#           front pocket mse loss: 38.443, l1 loss:  5.111	 calibrated mse loss:  2.705, l1 loss:  1.080
#             horizontal mse loss: 19.172, l1 loss:  3.525	 calibrated mse loss:  4.222, l1 loss:  1.342
#                 pocket mse loss: 32.289, l1 loss:  4.560	 calibrated mse loss:  3.308, l1 loss:  1.268
#                  swing mse loss: 36.293, l1 loss:  4.908	 calibrated mse loss:  2.299, l1 loss:  1.016
# 09000:           train mse loss:  0.007, l1 loss:  0.065	      valid mse loss:  0.286, l1 loss:  0.314
#           front pocket mse loss: 38.143, l1 loss:  5.089	 calibrated mse loss:  2.580, l1 loss:  1.048
#             horizontal mse loss: 19.232, l1 loss:  3.531	 calibrated mse loss:  4.140, l1 loss:  1.320
#                 pocket mse loss: 32.110, l1 loss:  4.550	 calibrated mse loss:  3.157, l1 loss:  1.236
#                  swing mse loss: 36.267, l1 loss:  4.906	 calibrated mse loss:  2.240, l1 loss:  0.993
# 09100:           train mse loss:  0.022, l1 loss:  0.112	      valid mse loss:  0.316, l1 loss:  0.329
#           front pocket mse loss: 37.820, l1 loss:  5.067	 calibrated mse loss:  2.417, l1 loss:  1.025
#             horizontal mse loss: 19.231, l1 loss:  3.540	 calibrated mse loss:  4.058, l1 loss:  1.310
#                 pocket mse loss: 31.832, l1 loss:  4.530	 calibrated mse loss:  3.013, l1 loss:  1.197
#                  swing mse loss: 36.011, l1 loss:  4.884	 calibrated mse loss:  2.127, l1 loss:  0.966
# 09200:           train mse loss:  0.026, l1 loss:  0.118	      valid mse loss:  0.306, l1 loss:  0.344
#           front pocket mse loss: 38.054, l1 loss:  5.088	 calibrated mse loss:  2.467, l1 loss:  1.030
#             horizontal mse loss: 19.323, l1 loss:  3.544	 calibrated mse loss:  4.102, l1 loss:  1.304
#                 pocket mse loss: 32.126, l1 loss:  4.553	 calibrated mse loss:  3.090, l1 loss:  1.221
#                  swing mse loss: 36.269, l1 loss:  4.900	 calibrated mse loss:  2.167, l1 loss:  0.984
# 09300:           train mse loss:  0.007, l1 loss:  0.063	      valid mse loss:  0.284, l1 loss:  0.310
#           front pocket mse loss: 38.320, l1 loss:  5.105	 calibrated mse loss:  2.624, l1 loss:  1.058
#             horizontal mse loss: 19.185, l1 loss:  3.521	 calibrated mse loss:  4.233, l1 loss:  1.335
#                 pocket mse loss: 32.017, l1 loss:  4.538	 calibrated mse loss:  3.197, l1 loss:  1.243
#                  swing mse loss: 36.247, l1 loss:  4.898	 calibrated mse loss:  2.288, l1 loss:  1.006
# 09400:           train mse loss:  0.010, l1 loss:  0.076	      valid mse loss:  0.284, l1 loss:  0.317
#           front pocket mse loss: 38.339, l1 loss:  5.112	 calibrated mse loss:  2.717, l1 loss:  1.073
#             horizontal mse loss: 19.252, l1 loss:  3.525	 calibrated mse loss:  4.203, l1 loss:  1.336
#                 pocket mse loss: 31.826, l1 loss:  4.522	 calibrated mse loss:  3.308, l1 loss:  1.267
#                  swing mse loss: 36.043, l1 loss:  4.880	 calibrated mse loss:  2.357, l1 loss:  1.022
# 09500:           train mse loss:  0.011, l1 loss:  0.077	      valid mse loss:  0.288, l1 loss:  0.319
#           front pocket mse loss: 38.423, l1 loss:  5.110	 calibrated mse loss:  2.510, l1 loss:  1.039
#             horizontal mse loss: 19.300, l1 loss:  3.531	 calibrated mse loss:  4.106, l1 loss:  1.317
#                 pocket mse loss: 32.227, l1 loss:  4.551	 calibrated mse loss:  3.123, l1 loss:  1.235
#                  swing mse loss: 36.271, l1 loss:  4.895	 calibrated mse loss:  2.181, l1 loss:  0.988
# 09600:           train mse loss:  0.008, l1 loss:  0.066	      valid mse loss:  0.290, l1 loss:  0.319
#           front pocket mse loss: 38.293, l1 loss:  5.105	 calibrated mse loss:  2.572, l1 loss:  1.047
#             horizontal mse loss: 19.145, l1 loss:  3.522	 calibrated mse loss:  4.114, l1 loss:  1.312
#                 pocket mse loss: 32.085, l1 loss:  4.542	 calibrated mse loss:  3.175, l1 loss:  1.240
#                  swing mse loss: 36.156, l1 loss:  4.887	 calibrated mse loss:  2.199, l1 loss:  0.989
# 09700:           train mse loss:  0.007, l1 loss:  0.061	      valid mse loss:  0.284, l1 loss:  0.320
#           front pocket mse loss: 38.306, l1 loss:  5.102	 calibrated mse loss:  2.659, l1 loss:  1.059
#             horizontal mse loss: 19.063, l1 loss:  3.513	 calibrated mse loss:  4.216, l1 loss:  1.329
#                 pocket mse loss: 32.042, l1 loss:  4.537	 calibrated mse loss:  3.269, l1 loss:  1.257
#                  swing mse loss: 36.172, l1 loss:  4.892	 calibrated mse loss:  2.306, l1 loss:  1.009
# 09800:           train mse loss:  0.003, l1 loss:  0.040	      valid mse loss:  0.297, l1 loss:  0.320
#           front pocket mse loss: 38.188, l1 loss:  5.100	 calibrated mse loss:  2.491, l1 loss:  1.032
#             horizontal mse loss: 19.184, l1 loss:  3.529	 calibrated mse loss:  4.120, l1 loss:  1.313
#                 pocket mse loss: 31.988, l1 loss:  4.535	 calibrated mse loss:  3.078, l1 loss:  1.215
#                  swing mse loss: 36.064, l1 loss:  4.884	 calibrated mse loss:  2.155, l1 loss:  0.979
# 09900:           train mse loss:  0.006, l1 loss:  0.057	      valid mse loss:  0.309, l1 loss:  0.319
#           front pocket mse loss: 38.243, l1 loss:  5.104	 calibrated mse loss:  2.547, l1 loss:  1.040
#             horizontal mse loss: 19.250, l1 loss:  3.529	 calibrated mse loss:  4.094, l1 loss:  1.303
#                 pocket mse loss: 31.989, l1 loss:  4.536	 calibrated mse loss:  3.155, l1 loss:  1.231
#                  swing mse loss: 36.059, l1 loss:  4.881	 calibrated mse loss:  2.191, l1 loss:  0.983
# 10000:           train mse loss:  0.012, l1 loss:  0.080	      valid mse loss:  0.285, l1 loss:  0.307
#           front pocket mse loss: 38.189, l1 loss:  5.099	 calibrated mse loss:  2.577, l1 loss:  1.045
#             horizontal mse loss: 19.044, l1 loss:  3.509	 calibrated mse loss:  4.108, l1 loss:  1.312
#                 pocket mse loss: 31.959, l1 loss:  4.527	 calibrated mse loss:  3.187, l1 loss:  1.244
#                  swing mse loss: 35.897, l1 loss:  4.868	 calibrated mse loss:  2.241, l1 loss:  0.992

# %%
# torch.save({
#     'locator_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     }, f'/root/Mag/Experiments/0712/loc/m_A_gpr_model.pt')

# %%
def pred_sequence_pos(dataloader):
    model.eval()

    pred_poses = []
    gt_poses = []
    pairs = []
    pp = nn.PairwiseDistance(p=2)
    
    with torch.no_grad():
        for sequences, gt_pos in dataloader:
            optimizer.zero_grad()
            
            sequences = sequences.to(device)
            gt_pos = gt_pos.to(device)

            # localization
            pred_pos = model(sequences[:, :, 2:5])
            pair = pp(pred_pos, gt_pos)
            
            gt_poses.extend(gt_pos.detach().cpu().numpy())
            pred_poses.extend(pred_pos.detach().cpu().numpy())
            pairs.extend(pair.detach().cpu().numpy())
    
    return np.array(gt_poses), np.array(pred_poses), np.array(pairs)

# %%
def visualize(data_loader, trajectory, skip=50):
    gt_poses, pred_poses, pairs = pred_sequence_pos(data_loader)
    print(gt_poses.shape, pred_poses.shape, pairs.shape, trajectory.shape)
    print(f'Mean: {np.mean(pairs):>6.3f}\tMedian: {np.median(pairs):>6.3f}')
    test_seq = trajectory[::skip, :, :2]

    plt.figure(figsize=(12, 8))

    plt.plot(test_seq[:, :, 1].T, test_seq[:, :, 0].T, alpha=0.25)

    # plt.scatter(test_seq[:, -1, 1], test_seq[:, -1, 0])
    plt.scatter(gt_poses[::skip, 1], gt_poses[::skip, 0])
    plt.scatter(pred_poses[::skip, 1], pred_poses[::skip, 0])


    for i in range(0, len(gt_poses), skip):
        plt.annotate(int(i/skip), (gt_poses[i, 1], gt_poses[i, 0]))
        plt.annotate(int(i/skip), (pred_poses[i, 1], pred_poses[i, 0]))

    plt.axis('equal')
    plt.gca().invert_yaxis()
    plt.show()

# %%
valid_loader = DataLoader(train_dataset, batch_size=32)
visualize(valid_loader, prep_valid_target_traj[(np.arange(prep_valid_target_traj.shape[0])) % 10 != 0, :, :])
# Out:
# (606, 2) (606, 2) (606,) (606, 20, 8)
# Mean:  0.117	Median:  0.104

# %%
visualize(target_loader, prep_valid_target_traj[::10, :, :], 6)
# Out:
# (68, 2) (68, 2) (68,) (68, 20, 8)
# Mean:  0.482	Median:  0.310

# %%
visualize(front_pocket_loader, prep_valid_front_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  8.066	Median:  8.061

# %%
visualize(c_front_pocket_loader, cali_valid_front_pocket_traj, 25)
# Out:
# (337, 2) (337, 2) (337,) (337, 20, 8)
# Mean:  1.696	Median:  1.208

# %%
visualize(horizontal_loader, prep_valid_horizontal_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  5.538	Median:  5.281

# %%
visualize(c_horizontal_loader, cali_valid_horizontal_traj, 25)
# Out:
# (337, 2) (337, 2) (337,) (337, 20, 8)
# Mean:  2.174	Median:  1.573

# %%
visualize(pocket_loader, prep_valid_pocket_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  7.180	Median:  6.884

# %%
visualize(c_pocket_loader, cali_valid_pocket_traj, 25)
# Out:
# (337, 2) (337, 2) (337,) (337, 20, 8)
# Mean:  1.989	Median:  1.614

# %%
visualize(swing_loader, prep_valid_swing_traj)
# Out:
# (674, 2) (674, 2) (674,) (674, 20, 8)
# Mean:  7.451	Median:  7.320

# %%
visualize(c_swing_loader, cali_valid_swing_traj, 25)
# Out:
# (337, 2) (337, 2) (337,) (337, 20, 8)
# Mean:  1.617	Median:  1.171
