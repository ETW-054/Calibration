# %% [markdown]
# ```python
# file1 \_ |-----------------------------------|   -+-
# file2 \_ |-----------------------------------|    |   training data
# file3 \_ |-----------------------------------|    |        80%
# file4 \_ |-----------------------------------|    |
#                                                  -+-
# file5 \_ |-----------------------------------|    |  validation data
# file6 \_ |-----------------------------------|    |        20%
#          |-----------------------------------|   -+-
# ```

# %%
import os

import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
from tqdm import tqdm
import math

# %% [markdown]
# # 解壓縮資料

# %%
def unzip_data(path):
    for folder, _, files in os.walk(path):
        for file in files:
            if file.endswith('zip'):
                file_path = os.path.join(folder, file)
                print(file_path)

                sotre_path = os.path.join(folder, file.rsplit('.')[0])
                # 開啟 ZIP 壓縮檔 
                with zipfile.ZipFile(file_path, 'r') as zf:
                    # 解壓縮所有檔案至 /my/folder 目錄
                    zf.extractall(path=sotre_path)

# %%
# unzip_data('./swing')

# %%
def convert_csv(path):
    acc_df = pd.read_csv(os.path.join(path, 'Accelerometer.csv'), delimiter=',')
    gyo_df = pd.read_csv(os.path.join(path, 'Gyroscope.csv'), delimiter=',')
    linacc_df = pd.read_csv(os.path.join(path, 'Linear Accelerometer.csv'), delimiter=',')
    mag_df = pd.read_csv(os.path.join(path, 'Magnetometer.csv'), delimiter=',')
    device_df = pd.read_csv(os.path.join(path, 'meta', 'device.csv'), delimiter=',')
    time_df = pd.read_csv(os.path.join(path, 'meta', 'time.csv'), delimiter=',')
    
    acc_df.to_csv(os.path.join(path, 'Accelerometer.csv'), index=False, sep=';')
    gyo_df.to_csv(os.path.join(path, 'Gyroscope.csv'), index=False, sep=';')
    linacc_df.to_csv(os.path.join(path, 'Linear Accelerometer.csv'), index=False, sep=';')
    mag_df.to_csv(os.path.join(path, 'Magnetometer.csv'), index=False, sep=';')
    device_df.to_csv(os.path.join(path, 'meta', 'device.csv'), index=False, sep=';')
    time_df.to_csv(os.path.join(path, 'meta', 'time.csv'), index=False, sep=';')

# %%
# convert_csv('./pocket/202301101952/target')
# convert_csv('./pocket/202301101952/source')

# %% [markdown]
# # 讀檔

# %%
def rename_data(df):
    new_names = ['system_time', 'acc_times', 'acc_x', 'acc_y', 'acc_z', 'gyo_times', 'gyo_x', 'gyo_y', 'gyo_z', 'lin_acc_times', 'lin_acc_x', 'lin_acc_y', 'lin_acc_z', 'mag_times', 'mag_x', 'mag_y', 'mag_z']
    df.columns = new_names
    
    return df


def device_start_system_time(path):
    time_df = pd.read_csv(path, delimiter=';', index_col=0)
    time = time_df.T.loc['system time', 'START']
    
    return time


def load_original_data(path):
    acc_df = pd.read_csv(os.path.join(path, 'Accelerometer.csv'), delimiter=';')
    gyo_df = pd.read_csv(os.path.join(path, 'Gyroscope.csv'), delimiter=';')
    linacc_df = pd.read_csv(os.path.join(path, 'Linear Accelerometer.csv'), delimiter=';')
    mag_df = pd.read_csv(os.path.join(path, 'Magnetometer.csv'), delimiter=';')
    start_time = device_start_system_time(os.path.join(path, 'meta/time.csv'))
    time_df = acc_df.iloc[:, 0] + start_time
    
    total_df = pd.concat([time_df, acc_df, gyo_df, linacc_df, mag_df], axis=1)
    total_df = rename_data(total_df)
    
    return total_df

# %%
def align_data(source_df, target_df):
    source_start_time = source_df.loc[0, 'system_time']
    target_start_time = target_df.loc[0, 'system_time']
    
    # align start time
    if source_start_time > target_start_time:  # source start time > target start time
        target_start_idx = np.argmin(np.abs(target_df.system_time - source_start_time))
        target_df = target_df.iloc[target_start_idx:].reset_index(drop=True)
    else:  # source start time < target start time
        source_start_idx = np.argmin(np.abs(source_df.system_time - target_start_time))
        source_df = source_df.iloc[source_start_idx:].reset_index(drop=True)
        
    # align end idx
    end_idx = min(len(source_df), len(target_df))
    source_df = source_df.iloc[:end_idx]
    target_df = target_df.iloc[:end_idx]
    
    return source_df, target_df


def bound_range(df):
    start = datapoint_per_second * 35
    end = len(df) - datapoint_per_second * 20
    
    return df.iloc[start:end].reset_index(drop=True)


def split_segments(df, chunk_size=5, seq_len=25):
    length = chunk_size * seq_len
    num_of_segs = int(np.floor(len(df) / length))
    
    segments = []
    for i in range(num_of_segs):
        seg = df.iloc[int(i * length):int((i + 1) * length)].to_numpy()
        segments.append(np.array(np.split(seg, chunk_size)))
        
    return segments

def split_segments_overlap(df, chunk_size=5, seq_len=25):
    num_of_chunk = int(np.floor(len(df) / seq_len))
    
    segments = []
    for i in range(num_of_chunk - chunk_size):
        seg = df.iloc[int(i * seq_len):int((i + chunk_size) * seq_len)].to_numpy()
        segments.append(np.array(np.split(seg, chunk_size)))
        
    return segments

# def split_segments_overlap(df, chunk_size=5, seq_len=25):
#     total_length = chunk_size * seq_len
    
#     segments = []
#     for i in range(0, len(df) - total_length, 5):
#         seg = df.iloc[i:i + total_length].to_numpy()
#         segments.append(np.array(np.split(seg, chunk_size)))
        
#     return segments


def select_data(df):
    return df[['lin_acc_x', 'lin_acc_y', 'lin_acc_z', 'gyo_x', 'gyo_y', 'gyo_z', 'mag_x', 'mag_y', 'mag_z', 'system_time']]


def preprocess_data(df, chunk_size=5, seq_len=25, is_train_data=False):
    pre_df = select_data(df)
    
    if is_train_data:
        segs = split_segments_overlap(pre_df, chunk_size, seq_len)
    else:
        segs = split_segments(pre_df, chunk_size, seq_len)
    
    return segs

# %%
def device_version(path):
    device_df = pd.read_csv(path, delimiter=';', index_col=0)
    version = device_df.loc['deviceRelease'].value
    
    return version


def check_data_device(source_path, target_path):
    while True:
        source_version = device_version(os.path.join(source_path, 'meta/device.csv'))
        target_version = device_version(os.path.join(target_path, 'meta/device.csv'))

        print(source_path, target_path)

        if source_version[:2] == '15' and target_version[:2] == '16':
            return source_path, target_path
        elif source_version[:2] == '16' and target_version[:2] == '15':
            source_path = os.path.join(folder_path, 'target')
            target_path = os.path.join(folder_path, 'source')
            print('--- GG ---')
            continue
        else:
            raise


def load_pair_data(root_folder, class_num, file_index=None, is_train_data=False):
    pair_data = []
    files = os.listdir(root_folder)
    if file_index is not None:
        files = files[file_index[0]:file_index[1]]

    for folder in files:
        if folder.startswith('.'):
            continue

        folder_path = os.path.join(root_folder, folder)
        source_path = os.path.join(folder_path, 'source')
        target_path = os.path.join(folder_path, 'target')
        
        print(folder_path)
        
        #########################
        ##### check devices #####
        #########################
        source_path, target_path = check_data_device(source_path, target_path)
        
        ####################################
        ##### load and preprocess data #####
        ####################################
        source_df = load_original_data(source_path)
        target_df = load_original_data(target_path)
        
#         print(source_df.system_time[0], target_df.system_time[0])
        
        source_df, target_df = align_data(source_df, target_df)
        source_df, target_df = bound_range(source_df), bound_range(target_df)
        
#         print(source_df.system_time[0], target_df.system_time[0])
#         print(source_df.system_time[len(source_df) - 1], target_df.system_time[len(target_df) - 1])
#         print(len(source_df), len(target_df))
        
#         plt.figure(figsize=(30, 5))
#         plt.plot(np.arange(len(source_df)), source_df.acc_x)
#         plt.plot(np.arange(len(target_df)), target_df.acc_y)
#         plt.show()
        
        source_segs = preprocess_data(source_df, chunk_size, seq_len, is_train_data)
        target_segs = preprocess_data(target_df, chunk_size, seq_len, is_train_data)
        
        idx = min(len(source_segs), len(target_segs))
        source_tags = [class_num] * idx
        target_tags = [0] * idx
        
        pair_data.extend(zip(source_segs[:idx], source_tags, target_segs[:idx], target_tags))
        
    return pair_data

# %%
datapoint_per_second = 20
duration = 2
chunk_size = 7
seq_len = 21
classes = {0: 'target', 1: 'front_pocket', 2: 'pocket', 3: 'swing'}

# %%
source_device_version = device_version('./front_pocket/202302071523/source/meta/device.csv')
target_device_version = device_version('./front_pocket/202302071523/target/meta/device.csv')
print(f"source device version: {source_device_version}")  # source version: 15.4
print(f"target device version: {target_device_version}")  # target version: 16.3
# Out:
# source device version: 15.4
# target device version: 16.3

# %%
train_front_pocket_pair_data = load_pair_data('./front_pocket', class_num=1, file_index=[0, 8], is_train_data=True)
valid_front_pocket_pair_data = load_pair_data('./front_pocket', class_num=1, file_index=[8, 10], is_train_data=False)

train_pocket_pair_data = load_pair_data('./pocket', class_num=2, file_index=[0, 8], is_train_data=True)
valid_pocket_pair_data = load_pair_data('./pocket', class_num=2, file_index=[8, 10], is_train_data=False)

train_swing_pair_data = load_pair_data('./swing', class_num=3, file_index=[0, 8], is_train_data=True)
valid_swing_pair_data = load_pair_data('./swing', class_num=3, file_index=[8, 10], is_train_data=False)
# Out:
# ./front_pocket/202302071628
# ./front_pocket/202302071628/source ./front_pocket/202302071628/target
# ./front_pocket/202302071652
# ./front_pocket/202302071652/source ./front_pocket/202302071652/target
# ./front_pocket/202302071523
# ./front_pocket/202302071523/source ./front_pocket/202302071523/target
# ./front_pocket/202302071531
# ./front_pocket/202302071531/source ./front_pocket/202302071531/target
# ./front_pocket/202302071715
# ./front_pocket/202302071715/source ./front_pocket/202302071715/target
# ./front_pocket/202302071641
# ./front_pocket/202302071641/source ./front_pocket/202302071641/target
# ./front_pocket/202302071541
# ./front_pocket/202302071541/source ./front_pocket/202302071541/target
# ./front_pocket/202302071619
# ./front_pocket/202302071619/source ./front_pocket/202302071619/target
# ./front_pocket/202302071704
# ./front_pocket/202302071704/source ./front_pocket/202302071704/target
# ./pocket/202302132108
# ./pocket/202302132108/source ./pocket/202302132108/target
# ./pocket/202302131750
# ./pocket/202302131750/source ./pocket/202302131750/target
# ./pocket/202302131601
# ./pocket/202302131601/source ./pocket/202302131601/target
# ./pocket/202302071606
# ./pocket/202302071606/source ./pocket/202302071606/target
# ./pocket/202302132053
# ./pocket/202302132053/source ./pocket/202302132053/target
# ./pocket/202302122132
# ./pocket/202302122132/source ./pocket/202302122132/target
# ./pocket/202302132116
# ./pocket/202302132116/source ./pocket/202302132116/target
# ./pocket/202302131643
# ./pocket/202302131643/source ./pocket/202302131643/target
# ./pocket/202301101952
# ./pocket/202301101952/source ./pocket/202301101952/target
# ./swing/202302142339
# ./swing/202302142339/source ./swing/202302142339/target
# ./swing/202302132131
# ./swing/202302132131/source ./swing/202302132131/target
# ./swing/202302142117
# ./swing/202302142117/source ./swing/202302142117/target
# ./swing/202302132124
# ./swing/202302132124/source ./swing/202302132124/target
# ./swing/202302121947
# ./swing/202302121947/source ./swing/202302121947/target
# ./swing/202302121857
# ./swing/202302121857/source ./swing/202302121857/target
# ./swing/202302142128
# ./swing/202302142128/source ./swing/202302142128/target
# ./swing/202302121920
# ./swing/202302121920/source ./swing/202302121920/target
# ./swing/202302121909
# ./swing/202302121909/source ./swing/202302121909/target

# %%
print(len(train_front_pocket_pair_data), len(train_pocket_pair_data), len(train_swing_pair_data))
# Out:
# 1880 1838 1782

# %%
train_front_pocket_pair_data[0][0][0, -1], train_front_pocket_pair_data[0][2][0, -1]
# Out:
# (array([-1.46666997e+00,  3.02090550e-02,  1.02965024e+00, -4.78252917e-01,
#         -3.82730037e-01,  1.22318631e-02,  8.28334045e+00, -1.33542404e+01,
#          4.17045288e+01,  1.67575811e+09]),
#  array([ 1.25826234e-01, -1.58992693e+00, -1.53935553e+00, -6.28472567e-02,
#          3.16822752e-02,  2.58390278e-01, -3.71943283e+01,  1.32483292e+00,
#         -2.49790649e+01,  1.67575811e+09]))

# %% [markdown]
# # 建立dataloader

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score

# %%
class PairDataset(Dataset):
    def __init__(self, source_data, source_label, target_data, target_label):
        self.source_data = source_data
        self.source_label = source_label
        self.target_data = target_data
        self.target_label = target_label

    def __len__(self):
        return len(self.source_data)

    def __getitem__(self, idx):
        return self.source_data[idx], self.source_label[idx], self.target_data[idx], self.target_label[idx]

# %%
class FirstDerivativeLoss(nn.Module):
    def __init__(self, weight=None, size_average=None, reduce=None, reduction='mean', chunk_size=5):
        super(FirstDerivativeLoss, self).__init__()
        self.chunk_size = chunk_size

    def forward(self, source, target):
        # calculate the first derivative
        source_o = torch.reshape(source, (len(source), self.chunk_size, -1))
        target_o = torch.reshape(target, (len(target), self.chunk_size, -1))
        d_source = source_o[1:] - source_o[:-1]
        d_target = target_o[1:] - target_o[:-1]
        deriv = d_source - d_target

        # calculate the loss as the mean squared error of the derivative
        loss = torch.mean(torch.pow(deriv, 2))

        return loss

# %%
def generator_loss(z_imu, target_imu, predict_mag, target_mag):
    imu_loss = mse_loss(z_imu, target_imu)
    mag_loss = mse_loss(predict_mag, target_mag)
    d1_loss = div_loss(predict_mag, target_mag)

    total_loss = imu_loss + mag_loss #+ d1_loss
    return total_loss, imu_loss, mag_loss, d1_loss

# def discriminator_loss(d_real, d_fake):
#     real_loss = bce_loss(d_real, torch.ones_like(d_real))
#     fake_loss = bce_loss(d_fake, torch.zeros_like(d_fake))

#     return real_loss + fake_loss

# %%
train_data = train_front_pocket_pair_data + train_pocket_pair_data + train_swing_pair_data
valid_data = valid_front_pocket_pair_data + valid_pocket_pair_data + valid_swing_pair_data

# train
train_source_data = np.array([d[0] for d in train_data])
train_source_label = np.array([d[1] for d in train_data])
train_target_data = np.array([d[2] for d in train_data])
train_target_label = np.array([d[3] for d in train_data])
train_dataset = PairDataset(
                    source_data = torch.tensor(train_source_data, dtype=torch.float),
                    source_label = train_source_label,
                    target_data = torch.tensor(train_target_data, dtype=torch.float),
                    target_label = train_target_label,
                )
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)

# valid
valid_source_data = np.array([d[0] for d in valid_data])
valid_source_label = np.array([d[1] for d in valid_data])
valid_target_data = np.array([d[2] for d in valid_data])
valid_target_label = np.array([d[3] for d in valid_data])
valid_dataset = PairDataset(
                    source_data = torch.tensor(valid_source_data, dtype=torch.float),
                    source_label = valid_source_label,
                    target_data = torch.tensor(valid_target_data, dtype=torch.float),
                    target_label = valid_target_label,
                )
valid_loader = DataLoader(valid_dataset, batch_size=512)

# %%
batch = next(iter(train_loader))

# %%
def get_tgt_mask(size) -> torch.tensor:
    # Generates a squeare matrix where the each row allows one word more to be seen
    mask = torch.tril(torch.ones(size, size) == 1) # Lower triangular matrix
    mask = mask.float()
    mask = mask.masked_fill(mask == 0, float('-inf')) # Convert zeros to -inf
    mask = mask.masked_fill(mask == 1, float(0.0)) # Convert ones to 0

    # EX for size=5:
    # [[0., -inf, -inf, -inf, -inf],
    #  [0.,   0., -inf, -inf, -inf],
    #  [0.,   0.,   0., -inf, -inf],
    #  [0.,   0.,   0.,   0., -inf],
    #  [0.,   0.,   0.,   0.,   0.]]

    return mask

# %%
class Classifier(nn.Module):
    def __init__(self, chunk_size=5, seq_len=21, num_of_classes=2):
        super(Classifier, self).__init__()
        
        self.chunk_size = chunk_size
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        
        self.cnn = nn.Sequential(
            nn.Conv1d(6, 16, kernel_size=5),
            nn.LeakyReLU(),
            nn.Conv1d(16, 16, kernel_size=5),
            nn.LeakyReLU(),
        )
        
        # 16 * (seq_len-8)
        self.rnn = nn.RNN(input_size=16 * (seq_len - 8), hidden_size=64, num_layers=2, batch_first=True)
        
        self.last = nn.Sequential(
            nn.Linear(64, 16),
            nn.Tanh(),
            nn.Linear(16, num_of_classes),
            nn.Softmax(dim=2),
        )
        
    def forward(self, x):  # input: (bs, chunk_size, seq_len, 9)
        h = torch.reshape(x, (len(x) * self.chunk_size, self.seq_len, -1))  # (bs, chunk_size, seq_len, 9) -> (bs * chunk_size, seq_len, 9)
        h = torch.permute(h, (0, 2, 1))  # (bs * chunk_size, seq_len, 9) -> (bs * chunk_size, 9, seq_len) [CNN要對最後一個維度做卷積]
        
        h = self.cnn(h)

        h = torch.permute(h, (0, 2, 1))
        h = torch.reshape(h, (len(x), self.chunk_size, -1))
        
        hz, _ = self.rnn(h)
        out = self.last(hz)

        out = torch.reshape(out, (len(x), self.chunk_size, self.num_of_classes))
        
        return out, hz
    
    def predict_label(self, x):
        predict_probability, _ = self(x)
        predict_probability = predict_probability.reshape((-1, self.num_of_classes))
        _, predict_classes = torch.max(predict_probability, 1)
        one_hot = F.one_hot(predict_classes, num_classes=self.num_of_classes).to(device).float()
        class_result = one_hot.reshape(-1, self.chunk_size, self.num_of_classes)
        
        return class_result


class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :].to(x.device)
        return self.dropout(x)
    

class NotSimpleTransformer(nn.Module):
    def __init__(self, chunk_size=5, seq_len=21, num_of_classes=2):
        super(NotSimpleTransformer, self).__init__()
        
        self.chunk_size = chunk_size
        self.seq_len = seq_len
        self.num_of_classes = num_of_classes
        
        self.imu_layer = nn.Sequential(
            nn.Linear(6, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 64),
            nn.LeakyReLU(),
        )
        self.mag_layer = nn.Sequential(
            nn.Linear(3, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 64),
            nn.LeakyReLU(),
        )
        self.pos_encoder = PositionalEncoding(64 * self.seq_len, 0.1)
        
        self.encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=64 * self.seq_len, nhead=8, dropout=0.1, batch_first=True), num_layers=4)
        self.nn = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 6),
            nn.LeakyReLU(),
        )
        
        self.task_controller_net = nn.Sequential(
            nn.Linear(1348, 128),
            nn.LeakyReLU(),
            nn.Linear(128, 64),
            nn.LeakyReLU(), 
            nn.Linear(64, 64),
            nn.LeakyReLU(),
        )
        
        self.decoder = nn.TransformerDecoder(nn.TransformerDecoderLayer(d_model=64* self.seq_len, nhead=8, dropout=0.1, batch_first=True), num_layers=4)
        
        self.mag_last = nn.Sequential(
            nn.Linear(64, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 3),
        )
        
    def forward(self, source_imu, source_mag, class_result):
        
        ### step 1
        h_imu = self.imu_layer(source_imu)
        h_imu = h_imu.reshape((len(source_imu), self.chunk_size, -1))
        h_imu = self.pos_encoder(h_imu)
        
        h_mag = self.mag_layer(source_mag)
        h_mag = h_mag.reshape((len(source_mag), self.chunk_size, -1))
        h_mag = self.pos_encoder(h_mag)
        
        ### step 2
        z = self.encoder(h_imu)
        z_imu = z.reshape((len(source_imu), self.chunk_size, self.seq_len, -1))
        z_imu = self.nn(z_imu)
        
        z_class = torch.concat([z, class_result], dim=-1)
        task_latent = self.task_controller_net(z_class)
        
        ### step 3
        pred_latent = self.decoder(h_mag, z)
        pred_mag = pred_latent.reshape((len(source_mag), self.chunk_size, self.seq_len, -1))
        
        pred_mag = pred_mag + task_latent[:, :, None, :]
        pred_mag = self.mag_last(pred_mag)
        
        
        return z_imu, pred_mag

# %%
# class Discriminator(nn.Module):
#     def __init__(self, chunk_size=5, seq_len=21):
#         super(Discriminator, self).__init__()
        
#         self.chunk_size = chunk_size
#         self.seq_len = seq_len
        
#         self.feature_extractor = nn.Sequential(
#             nn.Linear(3, 16),
#             nn.LeakyReLU(),
#             nn.Linear(16, 32),
#             nn.LeakyReLU(),
#         )
        
#         self.lstm = nn.LSTM(input_size=32 * self.seq_len, hidden_size=32 * self.seq_len, num_layers=2, batch_first=True, bidirectional=True)
#         self.lstm = nn.LSTM(input_size=32 * self.seq_len, hidden_size=32 * self.seq_len, num_layers=2, batch_first=True, bidirectional=True)
        
#         self.discriminant_layer = nn.Sequential(
#             nn.Linear(64 * self.seq_len, 16),
#             nn.LeakyReLU(),
#             nn.Linear(16, 1),
#             nn.Sigmoid(),
#         )
        
#     def forward(self, x):
#         h = self.feature_extractor(x)  # (bs, chunk_size, seq_len, 3) -> (bs, chunk_size, seq_len, 16)
        
#         h = h.reshape((len(x), self.chunk_size, -1))  # (bs, chunk_size, seq_len, 16) -> (bs, chunk_size, seq_len * 16)
#         hz, _ = self.lstm(h)  # (bs, chunk_size, seq_len * 16) -> (bs, chunk_size, seq_len * 16 * 2)
        
#         out = self.discriminant_layer(hz)
        
#         return out

# %%
EPOCH = 2000
num_of_classes = 4
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
ce_loss = torch.nn.CrossEntropyLoss()
mse_loss = torch.nn.MSELoss()
bce_loss = torch.nn.BCELoss()
div_loss = FirstDerivativeLoss(chunk_size=chunk_size)

# %% [markdown]
# # Train classifier

# %%
classifier = Classifier(chunk_size=chunk_size, seq_len=seq_len, num_of_classes=num_of_classes).to(device)
optimizer_C = torch.optim.Adam(classifier.parameters(), lr=0.00005)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_C, T_max=50, eta_min=0.0000001)

# %%
def train_C(model, dataloader, optimizer):
    model.train()

    losses = []
    accuracies = []

    for source_data, source_label, target_data, target_label in dataloader:
        optimizer.zero_grad()

        sequences = torch.concat([source_data[:, :, :, :6], target_data[::3, :, :, :6]])
        labels = torch.concat([source_label, target_label[::3]])
        
        sequences = sequences.to(device)
        one_hot = F.one_hot(labels, num_classes=num_of_classes).to(device).float()
        one_hot = one_hot[:, None, :].repeat((1, chunk_size, 1)).float()

        #############
        # generator #
        #############
        predict_probability, _ = model(sequences)
        
        predict_probability = predict_probability.reshape((-1, num_of_classes))
        one_hot = one_hot.reshape((-1, num_of_classes))
        loss = ce_loss(predict_probability, one_hot)
        
        # backward
        loss.backward()
        optimizer.step()
        
        _, predict_classes = torch.max(predict_probability, 1)
        predict_classes = predict_classes.cpu().detach().numpy()
        _, labels = torch.max(one_hot, 1)
        labels = labels.cpu().detach().numpy()
        
        losses.append(loss.item())
        accuracies.append(accuracy_score(labels, predict_classes))
    
    return np.mean(losses), np.mean(accuracies)

# %%
def evalute_C(model, dataloader):
    model.eval()

    losses = []
    accuracies = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            
            sequences = torch.concat([source_data[:, :, :, :6], target_data[:, :, :, :6]])
            labels = torch.concat([source_label, target_label])
            
            sequences = sequences.to(device)
            one_hot = F.one_hot(labels, num_classes=num_of_classes).to(device).float()
            one_hot = one_hot[:, None, :].repeat((1, chunk_size, 1)).float()

            #############
            # generator #
            #############
            predict_probability, _ = model(sequences[:, :, :, :9])
            
            predict_probability = predict_probability.reshape((-1, num_of_classes))
            one_hot = one_hot.reshape((-1, num_of_classes))
            loss = ce_loss(predict_probability, one_hot)

            _, predict_classes = torch.max(predict_probability, 1)
            predict_classes = predict_classes.cpu().detach().numpy()
            _, labels = torch.max(one_hot, 1)
            labels = labels.cpu().detach().numpy()
            
            losses.append(loss.item())
            accuracies.append(accuracy_score(labels, predict_classes))
    
    return np.mean(losses), np.mean(accuracies)

# %%
for epoch in range(500):
    train_loss, train_acc = train_C(classifier, train_loader, optimizer_C)
    lr_scheduler.step()
    valid_loss, valid_acc = evalute_C(classifier, valid_loader)
    
    ep = str(epoch).zfill(5)

    print(f'{ep}: train loss: {train_loss:2.3f}, acc: {train_acc:2.3f}   valid loss: {valid_loss:2.3f}, acc: {valid_acc:2.3f}')
# Out:
# 00000: train loss: 1.386, acc: 0.230   valid loss: 1.399, acc: 0.156
# 00001: train loss: 1.383, acc: 0.249   valid loss: 1.397, acc: 0.170
# 00002: train loss: 1.379, acc: 0.271   valid loss: 1.395, acc: 0.184
# 00003: train loss: 1.376, acc: 0.289   valid loss: 1.393, acc: 0.191
# 00004: train loss: 1.373, acc: 0.295   valid loss: 1.389, acc: 0.179
# 00005: train loss: 1.368, acc: 0.287   valid loss: 1.384, acc: 0.176
# 00006: train loss: 1.363, acc: 0.278   valid loss: 1.378, acc: 0.174
# 00007: train loss: 1.358, acc: 0.286   valid loss: 1.370, acc: 0.199
# 00008: train loss: 1.351, acc: 0.312   valid loss: 1.360, acc: 0.261
# 00009: train loss: 1.342, acc: 0.370   valid loss: 1.348, acc: 0.369
# 00010: train loss: 1.332, acc: 0.467   valid loss: 1.335, acc: 0.555
# 00011: train loss: 1.322, acc: 0.553   valid loss: 1.322, acc: 0.647
# 00012: train loss: 1.310, acc: 0.609   valid loss: 1.310, acc: 0.671
# 00013: train loss: 1.299, acc: 0.646   valid loss: 1.298, acc: 0.683
# 00014: train loss: 1.288, acc: 0.679   valid loss: 1.288, acc: 0.692
# 00015: train loss: 1.279, acc: 0.706   valid loss: 1.279, acc: 0.711
# 00016: train loss: 1.269, acc: 0.735   valid loss: 1.272, acc: 0.729
# 00017: train loss: 1.260, acc: 0.763   valid loss: 1.265, acc: 0.753
# 00018: train loss: 1.252, acc: 0.789   valid loss: 1.259, acc: 0.772
# 00019: train loss: 1.244, acc: 0.811   valid loss: 1.254, acc: 0.786
# 00020: train loss: 1.237, acc: 0.830   valid loss: 1.249, acc: 0.806
# 00021: train loss: 1.230, acc: 0.844   valid loss: 1.245, acc: 0.819
# 00022: train loss: 1.223, acc: 0.857   valid loss: 1.241, acc: 0.850
# 00023: train loss: 1.218, acc: 0.865   valid loss: 1.237, acc: 0.869
# 00024: train loss: 1.212, acc: 0.873   valid loss: 1.234, acc: 0.882
# 00025: train loss: 1.207, acc: 0.874   valid loss: 1.231, acc: 0.888
# 00026: train loss: 1.202, acc: 0.879   valid loss: 1.229, acc: 0.892
# 00027: train loss: 1.198, acc: 0.881   valid loss: 1.226, acc: 0.883
# 00028: train loss: 1.194, acc: 0.879   valid loss: 1.224, acc: 0.871
# 00029: train loss: 1.191, acc: 0.879   valid loss: 1.222, acc: 0.855
# 00030: train loss: 1.187, acc: 0.875   valid loss: 1.221, acc: 0.842
# 00031: train loss: 1.184, acc: 0.871   valid loss: 1.219, acc: 0.825
# 00032: train loss: 1.182, acc: 0.864   valid loss: 1.217, acc: 0.811
# 00033: train loss: 1.180, acc: 0.858   valid loss: 1.216, acc: 0.797
# 00034: train loss: 1.178, acc: 0.857   valid loss: 1.215, acc: 0.789
# 00035: train loss: 1.176, acc: 0.853   valid loss: 1.214, acc: 0.778
# 00036: train loss: 1.174, acc: 0.851   valid loss: 1.213, acc: 0.771
# 00037: train loss: 1.173, acc: 0.848   valid loss: 1.213, acc: 0.768
# 00038: train loss: 1.172, acc: 0.848   valid loss: 1.212, acc: 0.765
# 00039: train loss: 1.171, acc: 0.847   valid loss: 1.211, acc: 0.765
# 00040: train loss: 1.170, acc: 0.849   valid loss: 1.211, acc: 0.764
# 00041: train loss: 1.169, acc: 0.844   valid loss: 1.210, acc: 0.761
# 00042: train loss: 1.169, acc: 0.843   valid loss: 1.210, acc: 0.760
# 00043: train loss: 1.168, acc: 0.844   valid loss: 1.210, acc: 0.760
# 00044: train loss: 1.168, acc: 0.845   valid loss: 1.210, acc: 0.761
# 00045: train loss: 1.168, acc: 0.846   valid loss: 1.210, acc: 0.760
# 00046: train loss: 1.167, acc: 0.847   valid loss: 1.209, acc: 0.761
# 00047: train loss: 1.167, acc: 0.845   valid loss: 1.209, acc: 0.760
# 00048: train loss: 1.167, acc: 0.844   valid loss: 1.209, acc: 0.760
# 00049: train loss: 1.167, acc: 0.845   valid loss: 1.209, acc: 0.760
# 00050: train loss: 1.167, acc: 0.845   valid loss: 1.209, acc: 0.760
# 00051: train loss: 1.167, acc: 0.846   valid loss: 1.209, acc: 0.760
# 00052: train loss: 1.167, acc: 0.847   valid loss: 1.209, acc: 0.760
# 00053: train loss: 1.167, acc: 0.846   valid loss: 1.209, acc: 0.760
# 00054: train loss: 1.167, acc: 0.844   valid loss: 1.209, acc: 0.759
# 00055: train loss: 1.167, acc: 0.847   valid loss: 1.209, acc: 0.760
# 00056: train loss: 1.167, acc: 0.845   valid loss: 1.209, acc: 0.761
# 00057: train loss: 1.166, acc: 0.845   valid loss: 1.209, acc: 0.760
# 00058: train loss: 1.166, acc: 0.846   valid loss: 1.208, acc: 0.760
# 00059: train loss: 1.166, acc: 0.844   valid loss: 1.208, acc: 0.760
# 00060: train loss: 1.165, acc: 0.848   valid loss: 1.208, acc: 0.761
# 00061: train loss: 1.164, acc: 0.846   valid loss: 1.207, acc: 0.762
# 00062: train loss: 1.163, acc: 0.844   valid loss: 1.206, acc: 0.763
# 00063: train loss: 1.162, acc: 0.846   valid loss: 1.206, acc: 0.761
# 00064: train loss: 1.161, acc: 0.846   valid loss: 1.205, acc: 0.761
# 00065: train loss: 1.159, acc: 0.846   valid loss: 1.204, acc: 0.767
# 00066: train loss: 1.158, acc: 0.852   valid loss: 1.203, acc: 0.778
# 00067: train loss: 1.156, acc: 0.856   valid loss: 1.201, acc: 0.798
# 00068: train loss: 1.154, acc: 0.858   valid loss: 1.200, acc: 0.805
# 00069: train loss: 1.152, acc: 0.864   valid loss: 1.198, acc: 0.825
# 00070: train loss: 1.149, acc: 0.873   valid loss: 1.196, acc: 0.849
# 00071: train loss: 1.147, acc: 0.880   valid loss: 1.194, acc: 0.871
# 00072: train loss: 1.144, acc: 0.890   valid loss: 1.192, acc: 0.887
# 00073: train loss: 1.141, acc: 0.899   valid loss: 1.189, acc: 0.906
# 00074: train loss: 1.138, acc: 0.904   valid loss: 1.186, acc: 0.920
# 00075: train loss: 1.134, acc: 0.914   valid loss: 1.181, acc: 0.936
# 00076: train loss: 1.130, acc: 0.921   valid loss: 1.177, acc: 0.948
# 00077: train loss: 1.125, acc: 0.924   valid loss: 1.172, acc: 0.955
# 00078: train loss: 1.121, acc: 0.927   valid loss: 1.166, acc: 0.964
# 00079: train loss: 1.115, acc: 0.931   valid loss: 1.159, acc: 0.967
# 00080: train loss: 1.109, acc: 0.936   valid loss: 1.151, acc: 0.968
# 00081: train loss: 1.103, acc: 0.935   valid loss: 1.142, acc: 0.965
# 00082: train loss: 1.096, acc: 0.937   valid loss: 1.131, acc: 0.964
# 00083: train loss: 1.088, acc: 0.938   valid loss: 1.120, acc: 0.962
# 00084: train loss: 1.080, acc: 0.938   valid loss: 1.108, acc: 0.960
# 00085: train loss: 1.070, acc: 0.941   valid loss: 1.094, acc: 0.963
# 00086: train loss: 1.061, acc: 0.943   valid loss: 1.081, acc: 0.966
# 00087: train loss: 1.052, acc: 0.946   valid loss: 1.067, acc: 0.970
# 00088: train loss: 1.042, acc: 0.950   valid loss: 1.054, acc: 0.975
# 00089: train loss: 1.032, acc: 0.955   valid loss: 1.041, acc: 0.980
# 00090: train loss: 1.024, acc: 0.957   valid loss: 1.030, acc: 0.981
# 00091: train loss: 1.016, acc: 0.960   valid loss: 1.020, acc: 0.984
# 00092: train loss: 1.008, acc: 0.961   valid loss: 1.012, acc: 0.980
# 00093: train loss: 1.001, acc: 0.963   valid loss: 1.004, acc: 0.980
# 00094: train loss: 0.994, acc: 0.963   valid loss: 0.998, acc: 0.978
# 00095: train loss: 0.988, acc: 0.964   valid loss: 0.992, acc: 0.978
# 00096: train loss: 0.982, acc: 0.965   valid loss: 0.986, acc: 0.978
# 00097: train loss: 0.976, acc: 0.966   valid loss: 0.983, acc: 0.974
# 00098: train loss: 0.971, acc: 0.967   valid loss: 0.977, acc: 0.975
# 00099: train loss: 0.965, acc: 0.968   valid loss: 0.975, acc: 0.970
# 00100: train loss: 0.959, acc: 0.972   valid loss: 0.973, acc: 0.964
# 00101: train loss: 0.954, acc: 0.978   valid loss: 0.970, acc: 0.961
# 00102: train loss: 0.948, acc: 0.983   valid loss: 0.965, acc: 0.961
# 00103: train loss: 0.942, acc: 0.986   valid loss: 0.961, acc: 0.960
# 00104: train loss: 0.937, acc: 0.988   valid loss: 0.955, acc: 0.964
# 00105: train loss: 0.933, acc: 0.990   valid loss: 0.952, acc: 0.959
# 00106: train loss: 0.928, acc: 0.991   valid loss: 0.948, acc: 0.960
# 00107: train loss: 0.924, acc: 0.991   valid loss: 0.943, acc: 0.962
# 00108: train loss: 0.921, acc: 0.992   valid loss: 0.940, acc: 0.962
# 00109: train loss: 0.917, acc: 0.992   valid loss: 0.937, acc: 0.960
# 00110: train loss: 0.914, acc: 0.993   valid loss: 0.933, acc: 0.962
# 00111: train loss: 0.910, acc: 0.993   valid loss: 0.931, acc: 0.960
# 00112: train loss: 0.907, acc: 0.994   valid loss: 0.927, acc: 0.962
# 00113: train loss: 0.905, acc: 0.994   valid loss: 0.925, acc: 0.961
# 00114: train loss: 0.902, acc: 0.994   valid loss: 0.923, acc: 0.960
# 00115: train loss: 0.900, acc: 0.995   valid loss: 0.922, acc: 0.959
# 00116: train loss: 0.898, acc: 0.995   valid loss: 0.918, acc: 0.963
# 00117: train loss: 0.895, acc: 0.995   valid loss: 0.916, acc: 0.963
# 00118: train loss: 0.894, acc: 0.995   valid loss: 0.915, acc: 0.960
# 00119: train loss: 0.892, acc: 0.995   valid loss: 0.913, acc: 0.960
# 00120: train loss: 0.890, acc: 0.995   valid loss: 0.912, acc: 0.961
# 00121: train loss: 0.888, acc: 0.996   valid loss: 0.910, acc: 0.960
# 00122: train loss: 0.887, acc: 0.996   valid loss: 0.909, acc: 0.961
# 00123: train loss: 0.885, acc: 0.996   valid loss: 0.907, acc: 0.963
# 00124: train loss: 0.884, acc: 0.996   valid loss: 0.906, acc: 0.961
# 00125: train loss: 0.883, acc: 0.996   valid loss: 0.906, acc: 0.959
# 00126: train loss: 0.882, acc: 0.996   valid loss: 0.904, acc: 0.960
# 00127: train loss: 0.881, acc: 0.996   valid loss: 0.903, acc: 0.960
# 00128: train loss: 0.880, acc: 0.996   valid loss: 0.902, acc: 0.960
# 00129: train loss: 0.879, acc: 0.996   valid loss: 0.901, acc: 0.961
# 00130: train loss: 0.878, acc: 0.996   valid loss: 0.901, acc: 0.960
# 00131: train loss: 0.877, acc: 0.996   valid loss: 0.900, acc: 0.960
# 00132: train loss: 0.877, acc: 0.996   valid loss: 0.899, acc: 0.961
# 00133: train loss: 0.876, acc: 0.996   valid loss: 0.899, acc: 0.961
# 00134: train loss: 0.876, acc: 0.997   valid loss: 0.898, acc: 0.961
# 00135: train loss: 0.875, acc: 0.996   valid loss: 0.898, acc: 0.961
# 00136: train loss: 0.875, acc: 0.997   valid loss: 0.898, acc: 0.961
# 00137: train loss: 0.874, acc: 0.996   valid loss: 0.897, acc: 0.961
# 00138: train loss: 0.874, acc: 0.997   valid loss: 0.897, acc: 0.961
# 00139: train loss: 0.873, acc: 0.997   valid loss: 0.897, acc: 0.961
# 00140: train loss: 0.874, acc: 0.996   valid loss: 0.897, acc: 0.961
# 00141: train loss: 0.873, acc: 0.996   valid loss: 0.897, acc: 0.961
# 00142: train loss: 0.873, acc: 0.996   valid loss: 0.897, acc: 0.961
# 00143: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00144: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00145: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00146: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00147: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00148: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00149: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00150: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00151: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00152: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00153: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00154: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00155: train loss: 0.873, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00156: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00157: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.960
# 00158: train loss: 0.873, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00159: train loss: 0.872, acc: 0.996   valid loss: 0.896, acc: 0.961
# 00160: train loss: 0.872, acc: 0.997   valid loss: 0.896, acc: 0.961
# 00161: train loss: 0.872, acc: 0.997   valid loss: 0.895, acc: 0.960
# 00162: train loss: 0.872, acc: 0.997   valid loss: 0.895, acc: 0.961
# 00163: train loss: 0.871, acc: 0.997   valid loss: 0.895, acc: 0.960
# 00164: train loss: 0.871, acc: 0.996   valid loss: 0.894, acc: 0.961
# 00165: train loss: 0.871, acc: 0.997   valid loss: 0.894, acc: 0.961
# 00166: train loss: 0.870, acc: 0.997   valid loss: 0.893, acc: 0.961
# 00167: train loss: 0.870, acc: 0.997   valid loss: 0.893, acc: 0.961
# 00168: train loss: 0.869, acc: 0.997   valid loss: 0.893, acc: 0.960
# 00169: train loss: 0.869, acc: 0.997   valid loss: 0.892, acc: 0.961
# 00170: train loss: 0.868, acc: 0.997   valid loss: 0.891, acc: 0.961
# 00171: train loss: 0.867, acc: 0.997   valid loss: 0.890, acc: 0.961
# 00172: train loss: 0.866, acc: 0.997   valid loss: 0.890, acc: 0.961
# 00173: train loss: 0.866, acc: 0.997   valid loss: 0.889, acc: 0.961
# 00174: train loss: 0.865, acc: 0.997   valid loss: 0.888, acc: 0.961
# 00175: train loss: 0.864, acc: 0.997   valid loss: 0.887, acc: 0.961
# 00176: train loss: 0.863, acc: 0.997   valid loss: 0.887, acc: 0.961
# 00177: train loss: 0.862, acc: 0.997   valid loss: 0.885, acc: 0.963
# 00178: train loss: 0.861, acc: 0.997   valid loss: 0.885, acc: 0.960
# 00179: train loss: 0.860, acc: 0.997   valid loss: 0.884, acc: 0.961
# 00180: train loss: 0.859, acc: 0.997   valid loss: 0.882, acc: 0.961
# 00181: train loss: 0.858, acc: 0.997   valid loss: 0.881, acc: 0.963
# 00182: train loss: 0.857, acc: 0.997   valid loss: 0.881, acc: 0.961
# 00183: train loss: 0.856, acc: 0.997   valid loss: 0.879, acc: 0.962
# 00184: train loss: 0.855, acc: 0.997   valid loss: 0.877, acc: 0.964
# 00185: train loss: 0.853, acc: 0.998   valid loss: 0.877, acc: 0.962
# 00186: train loss: 0.852, acc: 0.997   valid loss: 0.877, acc: 0.960
# 00187: train loss: 0.851, acc: 0.997   valid loss: 0.875, acc: 0.961
# 00188: train loss: 0.850, acc: 0.998   valid loss: 0.873, acc: 0.962
# 00189: train loss: 0.849, acc: 0.998   valid loss: 0.873, acc: 0.961
# 00190: train loss: 0.847, acc: 0.998   valid loss: 0.872, acc: 0.961
# 00191: train loss: 0.846, acc: 0.998   valid loss: 0.871, acc: 0.961
# 00192: train loss: 0.845, acc: 0.998   valid loss: 0.869, acc: 0.962
# 00193: train loss: 0.844, acc: 0.998   valid loss: 0.868, acc: 0.963
# 00194: train loss: 0.843, acc: 0.998   valid loss: 0.867, acc: 0.962
# 00195: train loss: 0.842, acc: 0.998   valid loss: 0.866, acc: 0.963
# 00196: train loss: 0.840, acc: 0.998   valid loss: 0.865, acc: 0.962
# 00197: train loss: 0.839, acc: 0.998   valid loss: 0.864, acc: 0.962
# 00198: train loss: 0.838, acc: 0.998   valid loss: 0.863, acc: 0.964
# 00199: train loss: 0.837, acc: 0.998   valid loss: 0.862, acc: 0.963
# 00200: train loss: 0.836, acc: 0.998   valid loss: 0.862, acc: 0.961
# 00201: train loss: 0.835, acc: 0.998   valid loss: 0.861, acc: 0.961
# 00202: train loss: 0.834, acc: 0.998   valid loss: 0.859, acc: 0.963
# 00203: train loss: 0.833, acc: 0.998   valid loss: 0.859, acc: 0.962
# 00204: train loss: 0.832, acc: 0.998   valid loss: 0.858, acc: 0.962
# 00205: train loss: 0.831, acc: 0.998   valid loss: 0.857, acc: 0.962
# 00206: train loss: 0.830, acc: 0.999   valid loss: 0.857, acc: 0.961
# 00207: train loss: 0.829, acc: 0.998   valid loss: 0.855, acc: 0.963
# 00208: train loss: 0.829, acc: 0.998   valid loss: 0.854, acc: 0.964
# 00209: train loss: 0.828, acc: 0.998   valid loss: 0.854, acc: 0.962
# 00210: train loss: 0.827, acc: 0.999   valid loss: 0.854, acc: 0.961
# 00211: train loss: 0.826, acc: 0.998   valid loss: 0.852, acc: 0.962
# 00212: train loss: 0.825, acc: 0.999   valid loss: 0.852, acc: 0.961
# 00213: train loss: 0.825, acc: 0.998   valid loss: 0.852, acc: 0.961
# 00214: train loss: 0.824, acc: 0.999   valid loss: 0.851, acc: 0.961
# 00215: train loss: 0.823, acc: 0.999   valid loss: 0.850, acc: 0.963
# 00216: train loss: 0.823, acc: 0.999   valid loss: 0.849, acc: 0.962
# 00217: train loss: 0.822, acc: 0.999   valid loss: 0.849, acc: 0.961
# 00218: train loss: 0.821, acc: 0.999   valid loss: 0.848, acc: 0.963
# 00219: train loss: 0.821, acc: 0.999   valid loss: 0.848, acc: 0.963
# 00220: train loss: 0.820, acc: 0.999   valid loss: 0.847, acc: 0.962
# 00221: train loss: 0.820, acc: 0.999   valid loss: 0.847, acc: 0.963
# 00222: train loss: 0.820, acc: 0.999   valid loss: 0.846, acc: 0.965
# 00223: train loss: 0.819, acc: 0.999   valid loss: 0.846, acc: 0.963
# 00224: train loss: 0.819, acc: 0.999   valid loss: 0.846, acc: 0.963
# 00225: train loss: 0.818, acc: 0.999   valid loss: 0.846, acc: 0.963
# 00226: train loss: 0.818, acc: 0.999   valid loss: 0.845, acc: 0.963
# 00227: train loss: 0.818, acc: 0.999   valid loss: 0.845, acc: 0.963
# 00228: train loss: 0.817, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00229: train loss: 0.817, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00230: train loss: 0.817, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00231: train loss: 0.817, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00232: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.962
# 00233: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.962
# 00234: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00235: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.962
# 00236: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00237: train loss: 0.816, acc: 0.999   valid loss: 0.844, acc: 0.963
# 00238: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00239: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00240: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00241: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00242: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00243: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00244: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00245: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00246: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00247: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00248: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00249: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00250: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00251: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00252: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00253: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00254: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00255: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00256: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00257: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00258: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00259: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00260: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00261: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00262: train loss: 0.815, acc: 0.999   valid loss: 0.843, acc: 0.963
# 00263: train loss: 0.815, acc: 0.999   valid loss: 0.842, acc: 0.963
# 00264: train loss: 0.814, acc: 0.999   valid loss: 0.842, acc: 0.963
# 00265: train loss: 0.814, acc: 0.999   valid loss: 0.842, acc: 0.963
# 00266: train loss: 0.814, acc: 0.999   valid loss: 0.842, acc: 0.963
# 00267: train loss: 0.814, acc: 0.999   valid loss: 0.842, acc: 0.963
# 00268: train loss: 0.814, acc: 0.999   valid loss: 0.841, acc: 0.963
# 00269: train loss: 0.814, acc: 0.999   valid loss: 0.841, acc: 0.963
# 00270: train loss: 0.813, acc: 0.999   valid loss: 0.841, acc: 0.963
# 00271: train loss: 0.813, acc: 0.999   valid loss: 0.841, acc: 0.963
# 00272: train loss: 0.813, acc: 0.999   valid loss: 0.841, acc: 0.962
# 00273: train loss: 0.813, acc: 0.999   valid loss: 0.841, acc: 0.963
# 00274: train loss: 0.812, acc: 0.999   valid loss: 0.840, acc: 0.963
# 00275: train loss: 0.812, acc: 0.999   valid loss: 0.840, acc: 0.963
# 00276: train loss: 0.811, acc: 0.999   valid loss: 0.840, acc: 0.961
# 00277: train loss: 0.811, acc: 0.999   valid loss: 0.839, acc: 0.963
# 00278: train loss: 0.811, acc: 0.999   valid loss: 0.838, acc: 0.964
# 00279: train loss: 0.810, acc: 0.999   valid loss: 0.838, acc: 0.963
# 00280: train loss: 0.810, acc: 0.999   valid loss: 0.838, acc: 0.963
# 00281: train loss: 0.810, acc: 0.999   valid loss: 0.838, acc: 0.963
# 00282: train loss: 0.809, acc: 0.999   valid loss: 0.838, acc: 0.963
# 00283: train loss: 0.809, acc: 0.999   valid loss: 0.837, acc: 0.964
# 00284: train loss: 0.808, acc: 0.999   valid loss: 0.836, acc: 0.964
# 00285: train loss: 0.808, acc: 0.999   valid loss: 0.835, acc: 0.965
# 00286: train loss: 0.807, acc: 0.999   valid loss: 0.835, acc: 0.965
# 00287: train loss: 0.807, acc: 0.999   valid loss: 0.834, acc: 0.964
# 00288: train loss: 0.806, acc: 0.999   valid loss: 0.834, acc: 0.964
# 00289: train loss: 0.806, acc: 0.999   valid loss: 0.835, acc: 0.963
# 00290: train loss: 0.805, acc: 0.999   valid loss: 0.833, acc: 0.964
# 00291: train loss: 0.804, acc: 0.999   valid loss: 0.832, acc: 0.965
# 00292: train loss: 0.804, acc: 0.999   valid loss: 0.832, acc: 0.965
# 00293: train loss: 0.803, acc: 0.999   valid loss: 0.832, acc: 0.965
# 00294: train loss: 0.803, acc: 0.999   valid loss: 0.832, acc: 0.963
# 00295: train loss: 0.802, acc: 0.999   valid loss: 0.831, acc: 0.964
# 00296: train loss: 0.802, acc: 0.999   valid loss: 0.829, acc: 0.965
# 00297: train loss: 0.801, acc: 0.999   valid loss: 0.829, acc: 0.965
# 00298: train loss: 0.801, acc: 0.999   valid loss: 0.829, acc: 0.965
# 00299: train loss: 0.800, acc: 0.999   valid loss: 0.828, acc: 0.966
# 00300: train loss: 0.800, acc: 0.999   valid loss: 0.828, acc: 0.965
# 00301: train loss: 0.799, acc: 0.999   valid loss: 0.829, acc: 0.964
# 00302: train loss: 0.799, acc: 0.999   valid loss: 0.827, acc: 0.965
# 00303: train loss: 0.798, acc: 0.999   valid loss: 0.827, acc: 0.965
# 00304: train loss: 0.798, acc: 0.999   valid loss: 0.826, acc: 0.966
# 00305: train loss: 0.797, acc: 0.999   valid loss: 0.825, acc: 0.966
# 00306: train loss: 0.797, acc: 0.999   valid loss: 0.825, acc: 0.966
# 00307: train loss: 0.797, acc: 0.999   valid loss: 0.825, acc: 0.965
# 00308: train loss: 0.796, acc: 0.999   valid loss: 0.825, acc: 0.964
# 00309: train loss: 0.796, acc: 0.999   valid loss: 0.824, acc: 0.966
# 00310: train loss: 0.795, acc: 0.999   valid loss: 0.823, acc: 0.966
# 00311: train loss: 0.795, acc: 0.999   valid loss: 0.823, acc: 0.967
# 00312: train loss: 0.795, acc: 0.999   valid loss: 0.823, acc: 0.966
# 00313: train loss: 0.794, acc: 0.999   valid loss: 0.823, acc: 0.966
# 00314: train loss: 0.794, acc: 0.999   valid loss: 0.822, acc: 0.966
# 00315: train loss: 0.793, acc: 0.999   valid loss: 0.822, acc: 0.966
# 00316: train loss: 0.793, acc: 0.999   valid loss: 0.822, acc: 0.966
# 00317: train loss: 0.793, acc: 0.999   valid loss: 0.822, acc: 0.966
# 00318: train loss: 0.792, acc: 0.999   valid loss: 0.822, acc: 0.964
# 00319: train loss: 0.792, acc: 0.999   valid loss: 0.821, acc: 0.966
# 00320: train loss: 0.792, acc: 0.999   valid loss: 0.820, acc: 0.967
# 00321: train loss: 0.792, acc: 0.999   valid loss: 0.820, acc: 0.967
# 00322: train loss: 0.791, acc: 0.999   valid loss: 0.820, acc: 0.967
# 00323: train loss: 0.791, acc: 0.999   valid loss: 0.819, acc: 0.968
# 00324: train loss: 0.791, acc: 0.999   valid loss: 0.819, acc: 0.967
# 00325: train loss: 0.791, acc: 0.999   valid loss: 0.819, acc: 0.967
# 00326: train loss: 0.791, acc: 0.999   valid loss: 0.819, acc: 0.967
# 00327: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.968
# 00328: train loss: 0.790, acc: 0.999   valid loss: 0.819, acc: 0.967
# 00329: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00330: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.968
# 00331: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.968
# 00332: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.968
# 00333: train loss: 0.790, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00334: train loss: 0.789, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00335: train loss: 0.789, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00336: train loss: 0.789, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00337: train loss: 0.789, acc: 0.999   valid loss: 0.818, acc: 0.967
# 00338: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00339: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00340: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00341: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00342: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00343: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00344: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00345: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00346: train loss: 0.789, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00347: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00348: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00349: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00350: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00351: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00352: train loss: 0.789, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00353: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00354: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00355: train loss: 0.789, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00356: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00357: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00358: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00359: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00360: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00361: train loss: 0.789, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00362: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00363: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00364: train loss: 0.789, acc: 0.999   valid loss: 0.817, acc: 0.967
# 00365: train loss: 0.788, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00366: train loss: 0.788, acc: 1.000   valid loss: 0.817, acc: 0.967
# 00367: train loss: 0.788, acc: 0.999   valid loss: 0.816, acc: 0.968
# 00368: train loss: 0.788, acc: 0.999   valid loss: 0.816, acc: 0.968
# 00369: train loss: 0.788, acc: 1.000   valid loss: 0.816, acc: 0.968
# 00370: train loss: 0.788, acc: 1.000   valid loss: 0.816, acc: 0.967
# 00371: train loss: 0.788, acc: 1.000   valid loss: 0.816, acc: 0.967
# 00372: train loss: 0.788, acc: 1.000   valid loss: 0.816, acc: 0.967
# 00373: train loss: 0.788, acc: 0.999   valid loss: 0.816, acc: 0.967
# 00374: train loss: 0.787, acc: 1.000   valid loss: 0.816, acc: 0.967
# 00375: train loss: 0.787, acc: 1.000   valid loss: 0.815, acc: 0.968
# 00376: train loss: 0.787, acc: 1.000   valid loss: 0.815, acc: 0.969
# 00377: train loss: 0.787, acc: 1.000   valid loss: 0.815, acc: 0.968
# 00378: train loss: 0.787, acc: 1.000   valid loss: 0.815, acc: 0.967
# 00379: train loss: 0.786, acc: 1.000   valid loss: 0.814, acc: 0.968
# 00380: train loss: 0.786, acc: 1.000   valid loss: 0.815, acc: 0.967
# 00381: train loss: 0.786, acc: 0.999   valid loss: 0.814, acc: 0.968
# 00382: train loss: 0.786, acc: 1.000   valid loss: 0.813, acc: 0.969
# 00383: train loss: 0.785, acc: 1.000   valid loss: 0.814, acc: 0.967
# 00384: train loss: 0.785, acc: 1.000   valid loss: 0.813, acc: 0.967
# 00385: train loss: 0.785, acc: 1.000   valid loss: 0.813, acc: 0.967
# 00386: train loss: 0.784, acc: 1.000   valid loss: 0.813, acc: 0.968
# 00387: train loss: 0.784, acc: 1.000   valid loss: 0.812, acc: 0.968
# 00388: train loss: 0.784, acc: 1.000   valid loss: 0.811, acc: 0.970
# 00389: train loss: 0.784, acc: 1.000   valid loss: 0.812, acc: 0.968
# 00390: train loss: 0.783, acc: 1.000   valid loss: 0.812, acc: 0.967
# 00391: train loss: 0.783, acc: 0.999   valid loss: 0.812, acc: 0.967
# 00392: train loss: 0.783, acc: 1.000   valid loss: 0.810, acc: 0.969
# 00393: train loss: 0.782, acc: 1.000   valid loss: 0.811, acc: 0.968
# 00394: train loss: 0.782, acc: 1.000   valid loss: 0.810, acc: 0.969
# 00395: train loss: 0.782, acc: 1.000   valid loss: 0.809, acc: 0.970
# 00396: train loss: 0.781, acc: 1.000   valid loss: 0.809, acc: 0.970
# 00397: train loss: 0.781, acc: 1.000   valid loss: 0.810, acc: 0.968
# 00398: train loss: 0.781, acc: 1.000   valid loss: 0.809, acc: 0.969
# 00399: train loss: 0.781, acc: 1.000   valid loss: 0.808, acc: 0.969
# 00400: train loss: 0.780, acc: 1.000   valid loss: 0.807, acc: 0.970
# 00401: train loss: 0.780, acc: 1.000   valid loss: 0.807, acc: 0.969
# 00402: train loss: 0.780, acc: 1.000   valid loss: 0.808, acc: 0.969
# 00403: train loss: 0.779, acc: 1.000   valid loss: 0.808, acc: 0.968
# 00404: train loss: 0.779, acc: 1.000   valid loss: 0.808, acc: 0.968
# 00405: train loss: 0.779, acc: 1.000   valid loss: 0.806, acc: 0.970
# 00406: train loss: 0.779, acc: 1.000   valid loss: 0.806, acc: 0.969
# 00407: train loss: 0.778, acc: 1.000   valid loss: 0.806, acc: 0.970
# 00408: train loss: 0.778, acc: 1.000   valid loss: 0.807, acc: 0.968
# 00409: train loss: 0.778, acc: 1.000   valid loss: 0.806, acc: 0.968
# 00410: train loss: 0.778, acc: 1.000   valid loss: 0.806, acc: 0.968
# 00411: train loss: 0.777, acc: 1.000   valid loss: 0.807, acc: 0.968
# 00412: train loss: 0.777, acc: 1.000   valid loss: 0.806, acc: 0.968
# 00413: train loss: 0.777, acc: 1.000   valid loss: 0.806, acc: 0.968
# 00414: train loss: 0.777, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00415: train loss: 0.776, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00416: train loss: 0.776, acc: 1.000   valid loss: 0.804, acc: 0.970
# 00417: train loss: 0.776, acc: 1.000   valid loss: 0.804, acc: 0.969
# 00418: train loss: 0.776, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00419: train loss: 0.776, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00420: train loss: 0.776, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00421: train loss: 0.775, acc: 1.000   valid loss: 0.805, acc: 0.968
# 00422: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00423: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00424: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00425: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00426: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00427: train loss: 0.775, acc: 1.000   valid loss: 0.804, acc: 0.968
# 00428: train loss: 0.775, acc: 1.000   valid loss: 0.803, acc: 0.968
# 00429: train loss: 0.775, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00430: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.970
# 00431: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00432: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00433: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00434: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00435: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00436: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00437: train loss: 0.774, acc: 1.000   valid loss: 0.803, acc: 0.969
# 00438: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00439: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00440: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00441: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00442: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00443: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00444: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00445: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00446: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00447: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00448: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00449: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00450: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00451: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00452: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00453: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00454: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00455: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00456: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00457: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00458: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00459: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00460: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00461: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00462: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00463: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00464: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00465: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00466: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00467: train loss: 0.774, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00468: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00469: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00470: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00471: train loss: 0.773, acc: 1.000   valid loss: 0.801, acc: 0.969
# 00472: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00473: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.969
# 00474: train loss: 0.773, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00475: train loss: 0.773, acc: 1.000   valid loss: 0.801, acc: 0.969
# 00476: train loss: 0.773, acc: 1.000   valid loss: 0.801, acc: 0.969
# 00477: train loss: 0.773, acc: 1.000   valid loss: 0.801, acc: 0.969
# 00478: train loss: 0.772, acc: 1.000   valid loss: 0.802, acc: 0.968
# 00479: train loss: 0.772, acc: 1.000   valid loss: 0.801, acc: 0.968
# 00480: train loss: 0.772, acc: 1.000   valid loss: 0.800, acc: 0.969
# 00481: train loss: 0.772, acc: 1.000   valid loss: 0.800, acc: 0.969
# 00482: train loss: 0.772, acc: 1.000   valid loss: 0.799, acc: 0.970
# 00483: train loss: 0.772, acc: 1.000   valid loss: 0.800, acc: 0.969
# 00484: train loss: 0.771, acc: 1.000   valid loss: 0.799, acc: 0.971
# 00485: train loss: 0.771, acc: 1.000   valid loss: 0.798, acc: 0.971
# 00486: train loss: 0.771, acc: 1.000   valid loss: 0.799, acc: 0.971
# 00487: train loss: 0.771, acc: 1.000   valid loss: 0.799, acc: 0.969
# 00488: train loss: 0.771, acc: 1.000   valid loss: 0.799, acc: 0.970
# 00489: train loss: 0.771, acc: 1.000   valid loss: 0.799, acc: 0.969
# 00490: train loss: 0.770, acc: 1.000   valid loss: 0.799, acc: 0.969
# 00491: train loss: 0.770, acc: 1.000   valid loss: 0.800, acc: 0.967
# 00492: train loss: 0.770, acc: 1.000   valid loss: 0.799, acc: 0.968
# 00493: train loss: 0.770, acc: 1.000   valid loss: 0.798, acc: 0.970
# 00494: train loss: 0.770, acc: 1.000   valid loss: 0.798, acc: 0.969
# 00495: train loss: 0.769, acc: 1.000   valid loss: 0.797, acc: 0.970
# 00496: train loss: 0.769, acc: 1.000   valid loss: 0.798, acc: 0.970
# 00497: train loss: 0.769, acc: 1.000   valid loss: 0.798, acc: 0.969
# 00498: train loss: 0.769, acc: 1.000   valid loss: 0.796, acc: 0.972
# 00499: train loss: 0.769, acc: 1.000   valid loss: 0.797, acc: 0.970

# %% [markdown]
# # Train whole model

# %%
model = NotSimpleTransformer(chunk_size=chunk_size, seq_len=seq_len, num_of_classes=num_of_classes).to(device)
# discriminator = Discriminator(chunk_size=chunk_size, seq_len=seq_len).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
# optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=0.000025)

# %%
def plot_result(result):
    pred_mag = result[0].reshape(-1, 3)
    targ_mag = result[1].reshape(-1, 3)
    x = np.arange(len(pred_mag))
    
    loss = mse_loss(torch.tensor(pred_mag), torch.tensor(targ_mag)).item()
    
    fig = plt.figure(figsize=(15, 5))
    
    for pm, tm, caxis, color in zip(pred_mag.T, targ_mag.T, ['x', 'y', 'z'], ['tab:blue', 'tab:orange', 'tab:green']):
        plt.plot(x, pm, label=f'pred_{caxis}', color=color, linewidth=2.5, zorder=2)
        plt.plot(x, tm, '--', label=f'targ_{caxis}', color=color, linewidth=1, alpha=0.8, zorder=1)
    
    for i in range(0, chunk_size+1):
        plt.axvline(x=int(i * seq_len - 0.5), linewidth=0.5, linestyle='-', color='k', alpha=0.5)
    
    plt.suptitle(f'Loss: {loss:.2f}')
    plt.legend()
    plt.show()

# %%
def train(dataloader, draw=False):
    model.train()
    classifier.eval()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []

    for source_data, source_label, target_data, target_label in dataloader:
        optimizer.zero_grad()

        source_data = source_data.to(device)
        source_imu = source_data[:, :, :, :6]
        source_mag = source_data[:, :, :, 6:9]
        
        target_data = target_data.to(device)
        target_imu = target_data[:, :, :, :6]
        target_mag = target_data[:, :, :, 6:9]

        # generate mag
        class_result = classifier.predict_label(source_imu)
        
        z_imu, predict_mag = model(source_imu, source_mag, class_result)
        
        # generator loss
        gen_loss, imu_loss, mag_loss, d1_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)
        
        # backward
        gen_loss.backward()
        optimizer.step()
        
        # record loss
        g_losses.append(gen_loss.item())
        imu_losses.append(imu_loss.item())
        mag_losses.append(mag_loss.item())
        d1_losses.append(d1_loss.item())
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses)

# %%
def evalute(dataloader, draw=False):
    model.eval()
    classifier.eval()

    g_losses = []
    imu_losses = []
    mag_losses = []
    d1_losses = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_imu = source_data[:, :, :, :6]
            source_mag = source_data[:, :, :, 6:9]

            target_data = target_data.to(device)
            target_imu = target_data[:, :, :, :6]
            target_mag = target_data[:, :, :, 6:9]

            # generate mag
            class_result = classifier.predict_label(source_imu)
            
            z_imu, predict_mag = model(source_imu, source_mag, class_result)

            # generator loss
            gen_loss, imu_loss, mag_loss, d1_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)

            # record loss
            g_losses.append(gen_loss.item())
            imu_losses.append(imu_loss.item())
            mag_losses.append(mag_loss.item())
            d1_losses.append(d1_loss.item())
    
    if draw:
        rs = [predict_mag[0].detach().cpu().numpy(), target_mag[0].cpu().numpy()]
        plot_result(rs)
    
    return np.mean(g_losses), np.mean(imu_losses), np.mean(mag_losses), np.mean(d1_losses)

# %%
from torchinfo import summary
summary(model, input_size=[(1, 7, 21, 6), (1, 7, 21, 3), (1, 7, 4)])
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# NotSimpleTransformer                          [1, 7, 21, 6]             --
# ├─Sequential: 1-1                             [1, 7, 21, 64]            --
# │    └─Linear: 2-1                            [1, 7, 21, 32]            224
# │    └─LeakyReLU: 2-2                         [1, 7, 21, 32]            --
# │    └─Linear: 2-3                            [1, 7, 21, 64]            2,112
# │    └─LeakyReLU: 2-4                         [1, 7, 21, 64]            --
# ├─PositionalEncoding: 1-2                     [1, 7, 1344]              --
# │    └─Dropout: 2-5                           [1, 7, 1344]              --
# ├─Sequential: 1-3                             [1, 7, 21, 64]            --
# │    └─Linear: 2-6                            [1, 7, 21, 16]            64
# │    └─LeakyReLU: 2-7                         [1, 7, 21, 16]            --
# │    └─Linear: 2-8                            [1, 7, 21, 64]            1,088
# │    └─LeakyReLU: 2-9                         [1, 7, 21, 64]            --
# ├─PositionalEncoding: 1-4                     [1, 7, 1344]              --
# │    └─Dropout: 2-10                          [1, 7, 1344]              --
# ├─TransformerEncoder: 1-5                     [1, 7, 1344]              --
# │    └─ModuleList: 2-11                       --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 7, 1344]              12,744,512
# │    │    └─TransformerEncoderLayer: 3-2      [1, 7, 1344]              12,744,512
# │    │    └─TransformerEncoderLayer: 3-3      [1, 7, 1344]              12,744,512
# │    │    └─TransformerEncoderLayer: 3-4      [1, 7, 1344]              12,744,512
# ├─Sequential: 1-6                             [1, 7, 21, 6]             --
# │    └─Linear: 2-12                           [1, 7, 21, 32]            2,080
# │    └─LeakyReLU: 2-13                        [1, 7, 21, 32]            --
# │    └─Linear: 2-14                           [1, 7, 21, 6]             198
# │    └─LeakyReLU: 2-15                        [1, 7, 21, 6]             --
# ├─Sequential: 1-7                             [1, 7, 64]                --
# │    └─Linear: 2-16                           [1, 7, 128]               172,672
# │    └─LeakyReLU: 2-17                        [1, 7, 128]               --
# │    └─Linear: 2-18                           [1, 7, 64]                8,256
# │    └─LeakyReLU: 2-19                        [1, 7, 64]                --
# │    └─Linear: 2-20                           [1, 7, 64]                4,160
# │    └─LeakyReLU: 2-21                        [1, 7, 64]                --
# ├─TransformerDecoder: 1-8                     [1, 7, 1344]              --
# │    └─ModuleList: 2-22                       --                        --
# │    │    └─TransformerDecoderLayer: 3-5      [1, 7, 1344]              19,977,920
# │    │    └─TransformerDecoderLayer: 3-6      [1, 7, 1344]              19,977,920
# │    │    └─TransformerDecoderLayer: 3-7      [1, 7, 1344]              19,977,920
# │    │    └─TransformerDecoderLayer: 3-8      [1, 7, 1344]              19,977,920
# ├─Sequential: 1-9                             [1, 7, 21, 3]             --
# │    └─Linear: 2-23                           [1, 7, 21, 16]            1,040
# │    └─LeakyReLU: 2-24                        [1, 7, 21, 16]            --
# │    └─Linear: 2-25                           [1, 7, 21, 3]             51
# ===============================================================================================
# Total params: 131,081,673
# Trainable params: 131,081,673
# Non-trainable params: 0
# Total mult-adds (M): 44.31
# ===============================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.31
# Params size (MB): 177.25
# Estimated Total Size (MB): 180.57
# ===============================================================================================

# %%
for param in classifier.parameters():
    param.requires_grad = False

# %%
def check():
    for source_data, source_label, target_data, target_label in train_loader:
        source_data = source_data.to(device)
        source_imu = source_data[:, :, :, :6]
        source_mag = source_data[:, :, :, 6:9]
        
        predict_probability, _ = classifier(source_imu)
        predict_probability = predict_probability.reshape((-1, num_of_classes))
        _, predict_classes = torch.max(predict_probability, 1)
        one_hot = F.one_hot(predict_classes, num_classes=num_of_classes).to(device).float()
        class_result = one_hot.reshape(-1, chunk_size, num_of_classes)
        
        ### step 1
        h_imu = model.imu_layer(source_imu)
        h_imu = h_imu.reshape((len(source_imu), chunk_size, -1))
        h_imu = model.pos_encoder(h_imu)
        
        h_mag = model.mag_layer(source_mag)
        h_mag = h_mag.reshape((len(source_mag), chunk_size, -1))
        h_mag = model.pos_encoder(h_mag)
        
        ### step 2
        z = model.encoder(h_imu)
        z_imu = z.reshape((len(source_imu), chunk_size, seq_len, -1))
        z_imu = model.nn(z_imu)

        z_class = torch.concat([z, class_result], dim=-1)
        task_latent = model.task_controller_net(z_class)
        
        ### step 3
        pred_latent = model.decoder(h_mag, z)
        pred_mag = pred_latent.reshape((len(source_mag), chunk_size, seq_len, -1))
        
        pred_mag = pred_mag + task_latent[:, :, None, :]
        pred_mag = model.mag_last(pred_mag)
        
        
        return z_imu, pred_mag

# %%
draw = False

for epoch in range(EPOCH):
    
    if (epoch + 1) % 200 == 0:
        draw = True
    
    train_loss, train_imu_loss, train_mag_loss, t_d1_loss = train(train_loader, draw)
    valid_loss, valid_imu_loss, valid_mag_loss, v_d1_loss = evalute(valid_loader, draw)
    
    draw = False
    
    if (epoch + 1) % 20 == 0:
        ep = str(epoch).zfill(5)
        print(f'{ep:>5}: train loss: {train_loss: 2.3f}, imu loss: {train_imu_loss: 2.3f}, mag loss: {train_mag_loss: 2.3f}, div loss: {t_d1_loss: 2.3f}\n' +
              f'{"":>5}  valid loss: {valid_loss: 2.3f}, imu loss: {valid_imu_loss: 2.3f}, mag loss: {valid_mag_loss: 2.3f}, div loss: {v_d1_loss: 2.3f}')
# Out:
# 00019: train loss:  466.682, imu loss:  0.706, mag loss:  465.976, div loss:  901.626
#        valid loss:  469.402, imu loss:  0.458, mag loss:  468.945, div loss:  479.678
# 00039: train loss:  428.184, imu loss:  0.707, mag loss:  427.477, div loss:  858.619
#        valid loss:  448.787, imu loss:  0.458, mag loss:  448.329, div loss:  464.076
# 00059: train loss:  387.935, imu loss:  0.706, mag loss:  387.229, div loss:  772.996
#        valid loss:  441.581, imu loss:  0.457, mag loss:  441.124, div loss:  463.757
# 00079: train loss:  321.978, imu loss:  0.706, mag loss:  321.272, div loss:  629.435
#        valid loss:  446.187, imu loss:  0.457, mag loss:  445.729, div loss:  463.726
# 00099: train loss:  224.757, imu loss:  0.706, mag loss:  224.051, div loss:  446.148
#        valid loss:  482.263, imu loss:  0.457, mag loss:  481.806, div loss:  512.793
# 00119: train loss:  156.493, imu loss:  0.706, mag loss:  155.787, div loss:  308.006
#        valid loss:  555.814, imu loss:  0.457, mag loss:  555.356, div loss:  627.423
# 00139: train loss:  117.918, imu loss:  0.706, mag loss:  117.213, div loss:  233.027
#        valid loss:  577.936, imu loss:  0.457, mag loss:  577.478, div loss:  620.131
# 00159: train loss:  95.439, imu loss:  0.705, mag loss:  94.733, div loss:  188.140
#        valid loss:  585.964, imu loss:  0.457, mag loss:  585.507, div loss:  650.732
# 00179: train loss:  76.524, imu loss:  0.706, mag loss:  75.818, div loss:  151.786
#        valid loss:  587.077, imu loss:  0.457, mag loss:  586.620, div loss:  670.750
# 00199: train loss:  60.467, imu loss:  0.706, mag loss:  59.761, div loss:  119.326
#        valid loss:  598.789, imu loss:  0.457, mag loss:  598.331, div loss:  639.342
# 00219: train loss:  48.639, imu loss:  0.705, mag loss:  47.934, div loss:  95.529
#        valid loss:  559.053, imu loss:  0.457, mag loss:  558.595, div loss:  624.925
# 00239: train loss:  38.857, imu loss:  0.705, mag loss:  38.152, div loss:  76.111
#        valid loss:  534.906, imu loss:  0.457, mag loss:  534.448, div loss:  595.596
# 00259: train loss:  31.346, imu loss:  0.705, mag loss:  30.642, div loss:  61.003
#        valid loss:  551.437, imu loss:  0.457, mag loss:  550.979, div loss:  595.365
# 00279: train loss:  26.117, imu loss:  0.705, mag loss:  25.412, div loss:  50.618
#        valid loss:  539.675, imu loss:  0.457, mag loss:  539.218, div loss:  595.319
# 00299: train loss:  22.030, imu loss:  0.706, mag loss:  21.325, div loss:  42.222
#        valid loss:  523.682, imu loss:  0.457, mag loss:  523.225, div loss:  587.512
# 00319: train loss:  19.074, imu loss:  0.705, mag loss:  18.369, div loss:  36.637
#        valid loss:  511.460, imu loss:  0.457, mag loss:  511.002, div loss:  571.726
# 00339: train loss:  16.593, imu loss:  0.705, mag loss:  15.888, div loss:  31.736
#        valid loss:  517.742, imu loss:  0.457, mag loss:  517.284, div loss:  583.414
# 00359: train loss:  14.764, imu loss:  0.705, mag loss:  14.059, div loss:  28.149
#        valid loss:  496.950, imu loss:  0.458, mag loss:  496.493, div loss:  565.158
# 00379: train loss:  13.376, imu loss:  0.704, mag loss:  12.672, div loss:  25.264
#        valid loss:  514.848, imu loss:  0.457, mag loss:  514.391, div loss:  536.500
# 00399: train loss:  11.925, imu loss:  0.704, mag loss:  11.222, div loss:  22.408
#        valid loss:  487.077, imu loss:  0.458, mag loss:  486.620, div loss:  551.142
# 00419: train loss:  10.941, imu loss:  0.703, mag loss:  10.238, div loss:  20.301
#        valid loss:  481.226, imu loss:  0.458, mag loss:  480.768, div loss:  548.534
# 00439: train loss:  10.054, imu loss:  0.703, mag loss:  9.350, div loss:  18.579
#        valid loss:  468.186, imu loss:  0.458, mag loss:  467.728, div loss:  535.630
# 00459: train loss:  9.137, imu loss:  0.703, mag loss:  8.434, div loss:  16.794
#        valid loss:  473.899, imu loss:  0.458, mag loss:  473.441, div loss:  535.831
# 00479: train loss:  8.619, imu loss:  0.703, mag loss:  7.916, div loss:  15.807
#        valid loss:  472.214, imu loss:  0.458, mag loss:  471.756, div loss:  522.890
# 00499: train loss:  7.889, imu loss:  0.703, mag loss:  7.186, div loss:  14.357
#        valid loss:  465.954, imu loss:  0.458, mag loss:  465.496, div loss:  518.040
# 00519: train loss:  7.401, imu loss:  0.703, mag loss:  6.698, div loss:  13.388
#        valid loss:  458.955, imu loss:  0.458, mag loss:  458.497, div loss:  519.421
# 00539: train loss:  6.976, imu loss:  0.702, mag loss:  6.274, div loss:  12.459
#        valid loss:  459.555, imu loss:  0.458, mag loss:  459.097, div loss:  516.024
# 00559: train loss:  6.539, imu loss:  0.701, mag loss:  5.838, div loss:  11.630
#        valid loss:  449.875, imu loss:  0.458, mag loss:  449.416, div loss:  504.114
# 00579: train loss:  6.182, imu loss:  0.701, mag loss:  5.481, div loss:  10.922
#        valid loss:  442.220, imu loss:  0.458, mag loss:  441.762, div loss:  495.945
# 00599: train loss:  6.118, imu loss:  0.700, mag loss:  5.417, div loss:  10.811
#        valid loss:  428.393, imu loss:  0.458, mag loss:  427.934, div loss:  488.042
# 00619: train loss:  5.503, imu loss:  0.700, mag loss:  4.803, div loss:  9.547
#        valid loss:  425.487, imu loss:  0.459, mag loss:  425.029, div loss:  481.035
# 00639: train loss:  5.241, imu loss:  0.700, mag loss:  4.541, div loss:  9.038
#        valid loss:  431.780, imu loss:  0.459, mag loss:  431.322, div loss:  479.015
# 00659: train loss:  5.019, imu loss:  0.699, mag loss:  4.320, div loss:  8.585
#        valid loss:  423.091, imu loss:  0.459, mag loss:  422.632, div loss:  473.858
# 00679: train loss:  4.790, imu loss:  0.698, mag loss:  4.092, div loss:  8.134
#        valid loss:  421.906, imu loss:  0.459, mag loss:  421.446, div loss:  464.927
# 00699: train loss:  5.865, imu loss:  0.699, mag loss:  5.167, div loss:  10.252
#        valid loss:  420.111, imu loss:  0.459, mag loss:  419.651, div loss:  468.184
# 00719: train loss:  4.425, imu loss:  0.699, mag loss:  3.726, div loss:  7.456
#        valid loss:  414.133, imu loss:  0.459, mag loss:  413.674, div loss:  461.115
# 00739: train loss:  4.181, imu loss:  0.696, mag loss:  3.484, div loss:  6.892
#        valid loss:  406.833, imu loss:  0.460, mag loss:  406.373, div loss:  449.422
# 00759: train loss:  3.995, imu loss:  0.696, mag loss:  3.299, div loss:  6.535
#        valid loss:  403.559, imu loss:  0.460, mag loss:  403.099, div loss:  446.483
# 00779: train loss:  3.846, imu loss:  0.696, mag loss:  3.150, div loss:  6.242
#        valid loss:  404.539, imu loss:  0.460, mag loss:  404.079, div loss:  452.056
# 00799: train loss:  3.699, imu loss:  0.695, mag loss:  3.004, div loss:  5.956
#        valid loss:  395.005, imu loss:  0.460, mag loss:  394.545, div loss:  444.277
# 00819: train loss:  3.566, imu loss:  0.694, mag loss:  2.872, div loss:  5.696
#        valid loss:  393.422, imu loss:  0.461, mag loss:  392.961, div loss:  437.754
# 00839: train loss:  3.443, imu loss:  0.693, mag loss:  2.750, div loss:  5.476
#        valid loss:  388.026, imu loss:  0.461, mag loss:  387.564, div loss:  440.534
# 00859: train loss:  3.332, imu loss:  0.692, mag loss:  2.640, div loss:  5.195
#        valid loss:  393.194, imu loss:  0.462, mag loss:  392.732, div loss:  441.710
# 00879: train loss:  3.206, imu loss:  0.691, mag loss:  2.515, div loss:  4.970
#        valid loss:  383.764, imu loss:  0.463, mag loss:  383.301, div loss:  431.623
# 00899: train loss:  3.101, imu loss:  0.690, mag loss:  2.411, div loss:  4.800
#        valid loss:  383.939, imu loss:  0.463, mag loss:  383.476, div loss:  428.725
# 00919: train loss:  2.991, imu loss:  0.688, mag loss:  2.303, div loss:  4.570
#        valid loss:  380.256, imu loss:  0.464, mag loss:  379.792, div loss:  417.923
# 00939: train loss:  2.963, imu loss:  0.688, mag loss:  2.275, div loss:  4.486
#        valid loss:  372.719, imu loss:  0.465, mag loss:  372.254, div loss:  415.207
# 00959: train loss:  2.814, imu loss:  0.686, mag loss:  2.128, div loss:  4.197
#        valid loss:  373.033, imu loss:  0.465, mag loss:  372.568, div loss:  413.529
# 00979: train loss:  2.734, imu loss:  0.685, mag loss:  2.049, div loss:  4.057
#        valid loss:  373.630, imu loss:  0.466, mag loss:  373.164, div loss:  417.369
# 00999: train loss:  2.658, imu loss:  0.684, mag loss:  1.974, div loss:  3.898
#        valid loss:  373.569, imu loss:  0.467, mag loss:  373.103, div loss:  415.752
# 01019: train loss:  2.731, imu loss:  0.682, mag loss:  2.049, div loss:  4.050
#        valid loss:  351.585, imu loss:  0.466, mag loss:  351.119, div loss:  402.687
# 01039: train loss:  2.715, imu loss:  0.683, mag loss:  2.032, div loss:  4.051
#        valid loss:  318.666, imu loss:  0.468, mag loss:  318.198, div loss:  364.497
# 01059: train loss:  2.537, imu loss:  0.680, mag loss:  1.857, div loss:  3.713
#        valid loss:  328.734, imu loss:  0.469, mag loss:  328.265, div loss:  371.601
# 01079: train loss:  2.447, imu loss:  0.680, mag loss:  1.768, div loss:  3.514
#        valid loss:  331.938, imu loss:  0.470, mag loss:  331.468, div loss:  371.014
# 01099: train loss:  2.380, imu loss:  0.678, mag loss:  1.702, div loss:  3.381
#        valid loss:  335.240, imu loss:  0.471, mag loss:  334.770, div loss:  372.801
# 01119: train loss:  2.315, imu loss:  0.677, mag loss:  1.637, div loss:  3.258
#        valid loss:  337.968, imu loss:  0.471, mag loss:  337.496, div loss:  375.672
# 01139: train loss:  2.281, imu loss:  0.676, mag loss:  1.605, div loss:  3.190
#        valid loss:  344.191, imu loss:  0.472, mag loss:  343.720, div loss:  381.411
# 01159: train loss:  2.221, imu loss:  0.674, mag loss:  1.548, div loss:  3.082
#        valid loss:  349.442, imu loss:  0.472, mag loss:  348.969, div loss:  383.091
# 01179: train loss:  2.184, imu loss:  0.673, mag loss:  1.511, div loss:  3.000
#        valid loss:  352.155, imu loss:  0.474, mag loss:  351.681, div loss:  380.828
# 01199: train loss:  2.149, imu loss:  0.671, mag loss:  1.477, div loss:  2.940
#        valid loss:  351.049, imu loss:  0.475, mag loss:  350.574, div loss:  379.407
# 01219: train loss:  2.097, imu loss:  0.669, mag loss:  1.428, div loss:  2.829
#        valid loss:  349.915, imu loss:  0.476, mag loss:  349.439, div loss:  382.251
# 01239: train loss:  2.071, imu loss:  0.667, mag loss:  1.404, div loss:  2.784
#        valid loss:  357.403, imu loss:  0.477, mag loss:  356.926, div loss:  386.122
# 01259: train loss:  2.007, imu loss:  0.664, mag loss:  1.343, div loss:  2.671
#        valid loss:  359.516, imu loss:  0.478, mag loss:  359.038, div loss:  388.571
# 01279: train loss:  1.984, imu loss:  0.663, mag loss:  1.321, div loss:  2.616
#        valid loss:  357.928, imu loss:  0.478, mag loss:  357.450, div loss:  385.338
# 01299: train loss:  1.930, imu loss:  0.661, mag loss:  1.269, div loss:  2.521
#        valid loss:  360.055, imu loss:  0.479, mag loss:  359.575, div loss:  386.764
# 01319: train loss:  1.892, imu loss:  0.658, mag loss:  1.235, div loss:  2.456
#        valid loss:  356.763, imu loss:  0.481, mag loss:  356.282, div loss:  384.695
# 01339: train loss:  1.904, imu loss:  0.656, mag loss:  1.247, div loss:  2.429
#        valid loss:  363.536, imu loss:  0.482, mag loss:  363.054, div loss:  385.654
# 01359: train loss:  1.829, imu loss:  0.653, mag loss:  1.177, div loss:  2.339
#        valid loss:  359.061, imu loss:  0.484, mag loss:  358.577, div loss:  382.762
# 01379: train loss:  1.830, imu loss:  0.650, mag loss:  1.180, div loss:  2.299
#        valid loss:  367.572, imu loss:  0.485, mag loss:  367.088, div loss:  387.421
# 01399: train loss:  2.032, imu loss:  0.655, mag loss:  1.378, div loss:  2.743
#        valid loss:  282.399, imu loss:  0.485, mag loss:  281.914, div loss:  335.743
# 01419: train loss:  1.843, imu loss:  0.651, mag loss:  1.192, div loss:  2.374
#        valid loss:  307.074, imu loss:  0.486, mag loss:  306.587, div loss:  347.176
# 01439: train loss:  1.783, imu loss:  0.649, mag loss:  1.135, div loss:  2.252
#        valid loss:  317.141, imu loss:  0.487, mag loss:  316.654, div loss:  356.743
# 01459: train loss:  1.737, imu loss:  0.646, mag loss:  1.091, div loss:  2.174
#        valid loss:  321.736, imu loss:  0.488, mag loss:  321.248, div loss:  357.333
# 01479: train loss:  1.704, imu loss:  0.645, mag loss:  1.059, div loss:  2.105
#        valid loss:  330.869, imu loss:  0.488, mag loss:  330.381, div loss:  362.978
# 01499: train loss:  1.677, imu loss:  0.643, mag loss:  1.034, div loss:  2.059
#        valid loss:  335.773, imu loss:  0.489, mag loss:  335.284, div loss:  370.362
# 01519: train loss:  1.657, imu loss:  0.640, mag loss:  1.017, div loss:  2.014
#        valid loss:  338.792, imu loss:  0.491, mag loss:  338.301, div loss:  371.881
# 01539: train loss:  1.636, imu loss:  0.639, mag loss:  0.997, div loss:  1.980
#        valid loss:  345.507, imu loss:  0.491, mag loss:  345.017, div loss:  377.294
# 01559: train loss:  1.636, imu loss:  0.636, mag loss:  0.999, div loss:  1.974
#        valid loss:  345.113, imu loss:  0.491, mag loss:  344.622, div loss:  376.625
# 01579: train loss:  1.602, imu loss:  0.635, mag loss:  0.967, div loss:  1.914
#        valid loss:  349.006, imu loss:  0.493, mag loss:  348.513, div loss:  379.679
# 01599: train loss:  1.579, imu loss:  0.632, mag loss:  0.947, div loss:  1.890
#        valid loss:  350.801, imu loss:  0.494, mag loss:  350.307, div loss:  383.333
# 01619: train loss:  1.559, imu loss:  0.629, mag loss:  0.930, div loss:  1.843
#        valid loss:  353.731, imu loss:  0.495, mag loss:  353.237, div loss:  383.514
# 01639: train loss:  1.552, imu loss:  0.626, mag loss:  0.926, div loss:  1.843
#        valid loss:  353.371, imu loss:  0.495, mag loss:  352.876, div loss:  385.293
# 01659: train loss:  1.598, imu loss:  0.629, mag loss:  0.969, div loss:  1.930
#        valid loss:  305.507, imu loss:  0.490, mag loss:  305.017, div loss:  343.231
# 01679: train loss:  1.525, imu loss:  0.624, mag loss:  0.901, div loss:  1.801
#        valid loss:  324.469, imu loss:  0.493, mag loss:  323.976, div loss:  355.950
# 01699: train loss:  1.507, imu loss:  0.622, mag loss:  0.885, div loss:  1.765
#        valid loss:  325.370, imu loss:  0.494, mag loss:  324.876, div loss:  359.631
# 01719: train loss:  1.484, imu loss:  0.619, mag loss:  0.865, div loss:  1.720
#        valid loss:  331.742, imu loss:  0.497, mag loss:  331.244, div loss:  362.110
# 01739: train loss:  1.461, imu loss:  0.616, mag loss:  0.845, div loss:  1.678
#        valid loss:  336.790, imu loss:  0.498, mag loss:  336.292, div loss:  365.949
# 01759: train loss:  1.442, imu loss:  0.613, mag loss:  0.829, div loss:  1.647
#        valid loss:  340.080, imu loss:  0.499, mag loss:  339.581, div loss:  368.361
# 01779: train loss:  1.423, imu loss:  0.610, mag loss:  0.814, div loss:  1.613
#        valid loss:  341.371, imu loss:  0.501, mag loss:  340.871, div loss:  369.602
# 01799: train loss:  1.410, imu loss:  0.607, mag loss:  0.803, div loss:  1.594
#        valid loss:  349.171, imu loss:  0.501, mag loss:  348.670, div loss:  376.327
# 01819: train loss:  1.398, imu loss:  0.604, mag loss:  0.794, div loss:  1.582
#        valid loss:  351.128, imu loss:  0.503, mag loss:  350.625, div loss:  380.123
# 01839: train loss:  1.387, imu loss:  0.601, mag loss:  0.786, div loss:  1.555
#        valid loss:  358.223, imu loss:  0.504, mag loss:  357.719, div loss:  380.699
# 01859: train loss:  1.367, imu loss:  0.597, mag loss:  0.770, div loss:  1.531
#        valid loss:  358.330, imu loss:  0.504, mag loss:  357.825, div loss:  380.700
# 01879: train loss:  1.343, imu loss:  0.593, mag loss:  0.750, div loss:  1.485
#        valid loss:  355.553, imu loss:  0.507, mag loss:  355.047, div loss:  383.688
# 01899: train loss:  1.327, imu loss:  0.589, mag loss:  0.738, div loss:  1.456
#        valid loss:  369.554, imu loss:  0.508, mag loss:  369.046, div loss:  387.044
# 01919: train loss:  1.381, imu loss:  0.587, mag loss:  0.794, div loss:  1.572
#        valid loss:  365.134, imu loss:  0.514, mag loss:  364.620, div loss:  390.206
# 01939: train loss:  1.386, imu loss:  0.590, mag loss:  0.797, div loss:  1.575
#        valid loss:  292.882, imu loss:  0.513, mag loss:  292.369, div loss:  331.823
# 01959: train loss:  1.323, imu loss:  0.586, mag loss:  0.738, div loss:  1.468
#        valid loss:  303.288, imu loss:  0.514, mag loss:  302.774, div loss:  336.074

# %%
def output_eval(model, dataloader):
    model.eval()
    
    results = []
    class_results = []
    class_labels = []
    
    with torch.no_grad():
        for source_data, source_label, target_data, target_label in dataloader:
            source_data = source_data.to(device)
            source_imu = source_data[:, :, :, :6]
            source_mag = source_data[:, :, :, 6:9]

            target_data = target_data.to(device)
            target_imu = target_data[:, :, :, :6]
            target_mag = target_data[:, :, :, 6:9]
            
            class_result = classifier.predict_label(source_imu)

            # generate mag
            z_imu, predict_mag = model(source_imu, source_mag, class_result)
            

            # generator loss
#             gen_loss, imu_loss, mag_loss = generator_loss(z_imu, target_imu, predict_mag, target_mag)

            # record loss
            predict_mag = predict_mag.detach().cpu().numpy()
            target_mag = target_mag.cpu().numpy()
            source_label = source_label.detach().cpu().numpy()
            
            results.extend(zip(predict_mag, target_mag, source_label))
            
            diff = np.power(predict_mag.reshape(len(predict_mag), -1, 3) - target_mag.reshape(len(target_mag), -1, 3), 2).mean(axis=1)
            class_results.extend(diff)
            class_labels.extend(source_label)
    
    return np.array(results, dtype=object), np.array(class_results), np.array(class_labels)

# %%
def plot_result(result):
    pred_mag = result[0].reshape(-1, 3)
    targ_mag = result[1].reshape(-1, 3)
    source_label = result[2]
    x = np.arange(len(pred_mag))
    
    loss = mse_loss(torch.tensor(pred_mag), torch.tensor(targ_mag)).item()
    
    fig = plt.figure(figsize=(15, 5))
    
    for pm, tm, caxis, color in zip(pred_mag.T, targ_mag.T, ['x', 'y', 'z'], ['tab:blue', 'tab:orange', 'tab:green']):
        plt.plot(x, pm, label=f'pred_{caxis}', color=color, linewidth=2.5, zorder=2)
        plt.plot(x, tm, '--', label=f'targ_{caxis}', color=color, linewidth=1, alpha=0.8, zorder=1)
    
    for i in range(0, chunk_size+1):
        plt.axvline(x=int(i * seq_len - 0.5), linewidth=0.5, linestyle='-', color='k', alpha=0.5)
    
    plt.suptitle(f'{classes[source_label]}   Loss: {loss:.2f}')
    plt.legend()
    plt.show()

# %%
results, cres, clabel = output_eval(model, train_loader)
print(cres.shape, clabel.shape)

print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"diff z":>8} {"avg":>8}')
for class_label, class_name in classes.items():
    if sum(clabel == class_label) <= 0:
        continue
    dx, dy, dz = cres[clabel == class_label].mean(axis=0)
    print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
dx, dy, dz = cres.mean(axis=0)
print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')

for rs in results[::5000]:
    plot_result(rs)

# %%
results, cres, clabel = output_eval(model, valid_loader)
print(cres.shape, clabel.shape)

print(f'{"loss name":>20}| {"diff x":>8} {"diff y":>8} {"diff z":>8} {"avg":>8}')
for class_label, class_name in classes.items():
    if sum(clabel == class_label) <= 0:
        continue
    dx, dy, dz = cres[clabel == class_label].mean(axis=0)
    print(f'{class_name:>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')
dx, dy, dz = cres.mean(axis=0)
print(f'{"average":>15} loss: {dx:>8.2f} {dy:>8.2f} {dz:>8.2f} {np.mean([dx, dy, dz]):>8.2f}')

for rs in results[::50]:
    plot_result(rs)
